# %%
import re
import random
import numpy as np 
import pickle

# %%
def remove_space_from_quatation(string):
    temp = string.split()
    
    final_str = ''
    
    for i in temp:
        
        if i=='’':
            t = final_str[:len(final_str)-1] + "'"
            final_str = t
        else:
            final_str += i
            final_str += ' '
            
    return final_str
            
def get_tokens(statement):
    fs = remove_space_from_quatation(statement)
    count = 0
    ans = re.findall(r'[\'\w]+', fs)
    
    final_tokens = []
    
    for i in ans:
        final_tokens.append( i.lower())
        count += 1
        
    return final_tokens ,count 


def tokenize(file):
    count = 0
    f = open(file)
    lines = f.readlines()
    
    tokens = []
    
    for i in lines:
        temp ,c = get_tokens(i)
        
        count += c
        tokens.append(temp)
        
    return tokens ,count

# %% [markdown]
# ### Adding Padding

# %%
def add_padding(tokens):
    start_token = '<s>'
    end_token = '<e>'

    final_tokens = []

    for i in tokens:
        temp = [start_token] + i + [end_token]
        final_tokens.append(temp)

    return final_tokens

# %%
def preproceesing( filename ):
    tokens , total_tokens = tokenize(filename)
    
    padded_tokens = add_padding(tokens)
    
    return padded_tokens ,total_tokens

# %%
tokens, total_tokens = preproceesing('../text_data/Health_English.txt')

# %% [markdown]
# ### Calculating grams

# %%
def unigram(tokens):
    grams = []
    
    for stmt in tokens:
        for i in stmt:
            temp = tuple([i])
            grams.append(temp)
    
    return grams

def bigram(tokens):
    
    gram = []
    
    for line in tokens:
        for i in range( len(line) - 1):
            temp = tuple( [line[i] ,line[i+1]])
            gram.append( temp)
            
    return gram 


def trigram(tokens):
    
    gram = []
    
    for line in tokens:
        for i in range( len(line) - 2):
            temp = tuple( [line[i] ,line[i+1],line[i+2]])
            gram.append(temp)
            
    return gram


def fourgram(tokens):
    gram = []
    
    for line in tokens:
        for i in range( len(line) - 3):
            temp = tuple( [line[i] ,line[i+1] , line[i+2] ,line[i+3] ])
            gram.append(temp)
    
    return gram


n_grams = [ None ,unigram(tokens) , bigram(tokens) , trigram(tokens) , fourgram(tokens) ]

# %%
def calc_freq( n_grams ):
    freq = [ None , {} ,{} ,{} ,{} ]
    
    for n in range(1,5):
        gram = n_grams[n]
        
        for i in gram:
            if i not in freq[n]:
                freq[n][i] = 1
            else:
                freq[n][i] += 1
                
    return freq

freq = calc_freq(n_grams)

# %%
def kn_recur( word , prev_words , top_order , freq , total_tokens):
    
    ## Base Condition
    if len(prev_words) == 0:
        if top_order == True:
            count = 0
            
            if word in freq[1]:
                count = freq[1][word]
        
            return ( count / total_tokens )
        else:
            num = 0

            for i in freq[2]:
                if i[1] == word:
                    num+=1

            return num / len( freq[2] )

    d = 0.7
    words = prev_words + [word]
    
    ## Compute NUmerator
    look_all = len(words)
    look_prev = len(prev_words)
    key = tuple(words)
    num1 = 0
    
    if top_order == True:
        ## Count For highest Order
        if key in freq[look_all]:
            num1 = max( freq[look_all][key] - d , 0 )
    
    else:
        temp = words[1:]
        
        for i in freq[look_all]:
            t1 = list(i)
            t2 = t1[ 1:len(t1)]
            t3 = tuple(t2)
            
            if t3 == temp:
                num1 += 1
    
    
    ## Computing Denominator
    key = tuple(prev_words)
    deno = 0
    
    if top_order == True:
        if key in freq[look_prev]:
            deno = freq[look_prev][key]
        else:
            deno = 1
    else:
        deno = len(freq[look_all])
    
    
    num2 = 0
    for i in freq[look_all]:
        t1 = list(i)
        t2 = t1[0:len(t1)-1]
        t3 =  tuple(t2)
        
        if t3 == tuple(prev_words):
            num2 += 1
    
    if num1==0 and num2==0:
        ans = random.uniform(0.0001, 0.00001) +  random.uniform(0,1) * kn_recur(word ,prev_words[1:] ,False ,freq ,total_tokens)
        return ans
    
    if num2 == 0:
        return ( num1 / deno )
    
    return (num1/deno) + d*(num2/deno)*kn_recur(word , prev_words[1:] ,False ,freq ,total_tokens)

# %%
def val( gram ,freq):
    ans = 0
    if len(gram) == 0 :
        for i in freq[1].values():
            ans += i
    elif gram in freq[ len(gram)].keys():
        ans = freq[len(gram)][gram]
    else:
        ans = 0
    
    return ans 

def lambdas( gram ,freq):
    
    count = 0
    
    for i in freq[ len(gram)+1 ].keys():
        if i[:-1] == gram:
            count += 1
            
    deno = val(gram ,freq)
        
    deno = deno + count
    
    if deno != 0:
        lam = count/float(deno)
        return lam
    
    return random.uniform(0.00001,0.0001)


def wb( words , freq):
    
    if len(words) == 1 :
        gram = tuple([words])
        num = val(gram ,freq)
        
        deno = 0
        for i in freq[1].values():
            deno += i
        
        return num/float(deno)
    
    gram = tuple(words)
    
    num = val( gram ,freq)
    deno = val( gram[:-1] ,freq)
    
    if deno != 0 :
        
        ans1 = ( 1-lambdas(gram[:-1] , freq) )
        ans2 =  lambdas(gram[:-1] ,freq ) * wb(gram[1:] ,freq)
        
        ans = ans1*(num/deno) + ans2
        
        return ans 
    
    else:
        ans = random.uniform(0.0001, 0.00001) +  (lambdas(gram[:-1] ,freq) * wb(gram[1:] ,freq))
        return ans

# %%
def find_perp( stmt ,freq ,total_tokens ,smoothing):
    
    gram4 = fourgram([stmt])

    probability = 1

    for i in gram4:
        
        cur_word = i[3]
        prev_words = list(i[0:3])
        
        if smoothing == 'kn':
            temp = kn_recur(cur_word, prev_words ,True ,freq ,total_tokens)
        else:
            temp = wb(i ,freq)
            
        if temp < 0.0001:
            temp = 0.1
            
        probability *= temp

    deno = 1/probability
    perplexity = np.power( deno ,1/len(stmt))
    
    return perplexity

# %% [markdown]
# ### Test

# %%
f = open('../text_data/Health_English.txt')
lines = f.readlines()

# %%
idx = random.sample(range(0, len(tokens)), 1000)

test = []
train = [] 
stmts = []

total_tokens = 0
for i in range(0, len(tokens)):
    
    if i in idx:
        test.append( tokens[i] )
        stmts.append( lines[i] )
    else:
        train.append(tokens[i] )
        total_tokens += len(tokens[i])
        
        
n_grams = [ None ,unigram(train) , bigram(train) , trigram(train) , fourgram(train) ]

train_freq = calc_freq(n_grams)

# %%
health_corpus_kney = [] 

for i in range(len(test)):
    perp = find_perp(test[i] , train_freq ,total_tokens ,'kn' )
    
    print(i,test[i] ,perp)
    print()
    health_corpus_kney.append([test[i],perp])
# Out:
# 0 ['<s>', 'drink', 'plenty', 'of', 'water', '<e>'] 1.6944504796910669
#
# 1 ['<s>', 'if', 'fever', 'comes', 'continuously', 'you', 'must', 'get', 'it', 'checked', 'up', '<e>'] 5.623413251869314
#
# 2 ['<s>', 'use', 'warm', 'water', 'for', 'bathing', '<e>'] 3.72759372031494
#
# 3 ['<s>', 'brain', 'exercise', 'works', 'on', 'this', 'very', 'fundamental', '<e>'] 45.9966049853184
#
# 4 ['<s>', 'remembering', 'in', 'chart', 'or', 'short', 'form', 'would', 'also', 'prove', 'helpful', '<e>'] 17.50046259955467
#
# 5 ['<s>', 'brain', 'can', 'also', 'be', 'kept', 'sharpened', 'by', 'adopting', 'some', 'good', 'habits', '<e>'] 5.878016072274913
#
# 6 ['<s>', 'h', 'i', 'v', 'stands', 'for', 'human', 'immuno', 'deficiency', 'virus', "'", '<e>'] 14.616421348529913
#
# 7 ['<s>', 'what', 'happens', 'when', 'a', 'person', 'gets', 'infected', 'with', 'the', 'h', 'i', 'v', '<e>'] 4.964719721123099
#
# 8 ['<s>', 'apart', 'from', 'this', 'some', 'diseases', 'of', 'the', 'internal', 'parts', 'of', 'chest', 'may', 'also', 'be', 'cured', 'by', 'this', 'method', '<e>'] 6.0071855739739775
#
# 9 ['<s>', 'because', 'of', 'only', 'four', 'holes', 'being', 'made', 'the', 'possibility', 'of', 'these', 'wounds', 'getting', 'ripened', 'or', 'infected', 'becomes', 'very', 'less', '<e>'] 12.375881447092183
#
# 10 ['<s>', 'wounds', 'or', 'blisters', 'in', 'mouth', '<e>'] 3.72759372031494
#
# 11 ['<s>', 'although', 'each', 'of', 'the', 'disease', 'is', 'different', 'from', 'the', 'other', 'but', 'basically', 'all', 'the', 'types', 'of', 'cancers', 'occurs', 'as', 'a', 'result', 'of', 'anomaly', 'in', 'some', 'cells', '<e>'] 9.23943432681602
#
# 12 ['<s>', 'not', 'only', 'this', 'the', 'cost', 'of', 'early', 'identification', 'and', 'immediate', 'treatment', 'is', 'also', 'much', 'lower', 'than', 'late', 'treatment', '<e>'] 14.14272395718997
#
# 13 ['<s>', 'testicular', 'gland', 'cancer', 'could', 'be', 'found', 'out', 'by', 'most', 'of', 'the', 'men', 'themselves', '<e>'] 7.418062431061405
#
# 14 ['<s>', 'men', 'can', 'find', 'out', 'any', 'changes', 'in', 'the', 'testicular', 'gland', 'by', 'testing', 'themselves', 'every', 'month', '<e>'] 9.53451414750292
#
# 15 ['<s>', 'you', 'must', 'get', 'tested', 'by', 'a', 'doctor', 'or', 'a', 'dentist', '<e>'] 5.658249020905317
#
# 16 ['<s>', 'if', 'the', 'patient', 'takes', 'medicine', 'in', 'regular', 'cycle', 'and', 'eats', 'healthy', 'food', 'he', 'can', 'recover', 'fully', '<e>'] 10.021206739217348
#
# 17 ['<s>', 'encouraging', 'reforms', 'in', 'rural', 'and', 'urban', 'lifestyle', 'through', 'government', 'and', 'non', 'government', 'department', 'and', 'social', 'organizations', '<e>'] 9.244122847930635
#
# 18 ['<s>', 'it', 'can', 'also', 'spread', 'through', 'a', 'direct', 'contact', 'with', 'chicken', 'pox', 'or', 'herpes', 'because', 'there', 'is', 'contagious', 'liquid', 'in', 'raw', 'wounds', '<e>'] 11.590574563697228
#
# 19 ['<s>', 'use', 'neem', 'oil', 'or', 'mustard', 'oil', 'over', 'body', '<e>'] 4.156317007534475
#
# 20 ['<s>', 'keep', 'the', 'environment', 'clean', 'at', 'home', 'and', 'nearby', '<e>'] 5.011872336272723
#
# 21 ['<s>', 'the', 'chances', 'of', 'bringing', 'the', 'situation', 'back', 'to', 'the', 'pre', 'damage', 'stage', 'or', 'minimizing', 'it', 'increases', 'by', 'finding', 'out', 'the', 'complexities', 'early', 'through', 'regular', 'medical', 'tests', '<e>'] 10.746635895076523
#
# 22 ['<s>', 'as', 'soon', 'as', 'the', 'above', 'mentioned', 'symptoms', 'appear', 'the', 'patient', 'should', 'immediately', 'be', 'admitted', 'for', 'treatment', 'at', 'the', 'nearby', 'primary', 'health', 'center', 'sub', 'divisional', 'government', 'hospital', 'or', 'district', 'hospital', '<e>'] 9.376133192827057
#
# 23 ['<s>', 'the', 'family', 'welfare', 'program', 'was', 'run', 'at', 'the', 'national', 'level', 'in', 'the', 'year', 'of', '1952', '<e>'] 8.684269452856826
#
# 24 ['<s>', 'all', 'the', 'reproduction', 'health', 'safety', 'should', 'be', 'kept', 'in', 'the', 'form', 'of', 'a', 'single', 'element', 'within', 'family', 'planning', 'services', '<e>'] 15.033652155050207
#
# 25 ['<s>', 'this', 'program', 'has', 'been', 'running', 'in', 'uttarakhand', 'since', 'the', 'constitution', 'of', 'the', 'state', '<e>'] 9.116317241434572
#
# 26 ['<s>', '900', 'untrained', 'midwives', 'have', 'been', 'trained', 'in', 'uttarakhand', 'in', 'the', 'year', 'of', '2001', '2002', 'and', '2002', '03', 'to', 'provide', 'services', 'of', 'safe', 'labor', 'to', 'pregnant', 'mothers', '<e>'] 7.940764573374726
#
# 27 ['<s>', 'the', 'm', 'd', 't', 'medicine', 'cures', 'the', 'patient', 'completely', 'by', 'eradicating', 'the', 'leprosy', 'bacteria', 'and', 'prevents', 'the', 'disease', 'from', 'spreading', 'in', 'the', 'society', '<e>'] 12.0600039310084
#
# 28 ['<s>', 'leprosy', 'often', 'starts', 'with', 'a', 'spot', 'or', 'freckle', 'on', 'the', 'body', 'that', 'is', 'numb', '<e>'] 13.56665075516981
#
# 29 ['<s>', 'you', 'must', 'change', 'water', 'collected', 'in', 'pots', 'at', 'home', 'once', 'a', 'week', '<e>'] 8.740770264354358
#
# 30 ['<s>', 'besides', 'this', 'mouth', 'also', 'starts', 'drying', 'up', 'due', 'to', 'mumps', '<e>'] 5.131447564475328
#
# 31 ['<s>', 'live', 'attenuated', 'vaccines', 'of', 'measles', 'mumps', 'and', 'rubella', 'are', 'in', 'the', 'form', 'an', 'amalgamated', 'single', 'vaccine', 'which', 'is', 'called', 'mmr', '<e>'] 46.12869514176901
#
# 32 ['<s>', 'such', 'a', 'system', 'of', 'brain', 'is', 'called', 'mental', 'disorder', '<e>'] 8.749072958563303
#
# 33 ['<s>', 'getting', 'disturbed', 'soon', 'by', 'the', 'small', 'talk', 'of', 'children', '<e>'] 9.564004168434709
#
# 34 ['<s>', 'a', 'little', 'less', 'than', 'half', 'of', 'the', 'pregnant', 'women', 'are', 'able', 'to', 'get', 'pre', 'delivery', 'tests', 'done', 'in', 'uttarakhand', 'while', 'this', 'is', '65', 'percent', 'at', 'the', 'national', 'level', '<e>'] 12.026047411417913
#
# 35 ['<s>', 'swelling', 'in', 'conjuctiva', 'of', 'the', 'eye', '<e>'] 19.383786470146337
#
# 36 ['<s>', 'this', 'is', 'not', 'just', 'a', 'treatment', 'method', 'but', 'a', 'life', 'style', 'according', 'to', 'the', 'internal', 'important', 'powers', 'or', 'natural', 'elements', 'present', 'in', 'the', 'human', 'body', '<e>'] 12.815908691418215
#
# 37 ['<s>', 'there', 'can', 'also', 'be', 'complaint', 'of', 'nausea', 'along', 'with', 'pain', 'and', 'vomiting', '<e>'] 6.808233550153388
#
# 38 ['<s>', 'there', 'should', 'be', 'less', 'amount', 'of', 'protein', 'nitrogen', 'and', 'sodium', 'in', 'diet', '<e>'] 8.827109922632351
#
# 39 ['<s>', 'organ', 'donator', 'can', 'be', 'both', 'alive', 'or', 'dead', '<e>'] 9.92700870086691
#
# 40 ['<s>', 'the', 'person', 'from', 'whose', 'excreta', 'the', 'cyst', 'comes', 'out', 'should', 'not', 'do', 'any', 'work', 'of', 'the', 'kitchen', 'until', 'blood', 'and', 'phlegm', 'has', 'stopped', 'coming', 'through', 'excreta', '<e>'] 21.60721540523406
#
# 41 ['<s>', 'at', 'the', 'same', 'time', 'cent', 'percent', 'patients', 'can', 'be', 'ridden', 'from', 'the', 'disease', 'also', '<e>'] 10.67201245044411
#
# 42 ['<s>', 'in', 'preliminary', 'stage', 'the', 'knot', 'is', 'painless', 'and', 'because', 'of', 'this', 'reason', 'we', 'commit', 'grave', 'mistake', '<e>'] 9.369283452563195
#
# 43 ['<s>', 'if', 'pain', 'occurs', 'in', 'the', 'knot', 'of', 'skin', 'then', 'be', 'attentive', 'and', 'definitely', 'get', 'the', 'cancer', 'test', 'done', '<e>'] 10.34389403028185
#
# 44 ['<s>', 'this', 'fact', 'has', 'only', 'come', 'forward', 'after', 'doing', 'survey', 'that', 'those', 'mothers', 'who', 'move', 'around', 'their', 'children', 'are', 'more', 'sensitive', 'towards', 'their', 'health', '<e>'] 11.88650576833719
#
# 45 ['<s>', 'majority', 'of', 'women', 'feel', 'shy', 'hesitate', 'while', 'talking', 'to', 'their', 'doctor', 'about', 'their', 'uterus', 'and', 'reproductive', 'organs', '<e>'] 13.414886062240937
#
# 46 ['<s>', 'three', 'year', 'old', 'rice', 'is', 'very', 'tasteful', 'and', 'that', 'which', 'produces', 'glow', '<e>'] 7.887225885746532
#
# 47 ['<s>', 'the', 'secret', 'for', 'disease', 'free', 'healthy', 'and', 'long', 'life', 'is', 'nutritional', 'and', 'satvik', 'food', '<e>'] 14.1919322238407
#
# 48 ['<s>', 'the', 'meaning', 'of', 'healing', 'is', 'riddance', 'from', 'disease', 'and', 'the', 'meaning', 'of', 'healer', 'is', 'that', 'person', 'who', 'possesses', 'the', 'ability', 'to', 'cure', 'diseases', 'through', 'supernatural', 'power', '<e>'] 12.481107159097498
# 49 ['<s>', 'reiki', 'is', 'a', 'heavenly', 'power', 'which', 'fills', 'the', 'hands', 'of', 'the', 'channel', 'with', 'life', '<e>'] 13.742475831352227
#
# 50 ['<s>', 'reiki', 'guru', 'connects', 'the', 'student', 'with', 'the', 'universal', 'energy', 'force', 'through', 'the', 'attunement', 'and', 'his', 'life', 'gets', 'transformed', '<e>'] 26.597431896131337
#
# 51 ['<s>', 'some', 'people', 'take', 'energy', 'rich', 'food', 'to', 'maintain', 'health', '<e>'] 5.3366992312063095
#
# 52 ['<s>', 'if', 'gas', 'is', 'blocked', 'in', 'stomach', 'then', 'lightly', 'massage', 'the', 'stomach', 'and', 'foment', 'that', 'place', 'with', 'hot', 'water', 'bottle', 'or', 'by', 'lightly', 'warming', 'cotton', 'cloth', '<e>'] 16.266847868808362
#
# 53 ['<s>', 'ginger', 'tea', 'gives', 'relief', 'in', 'cough', 'cold', '<e>'] 10.75748091541848
#
# 54 ['<s>', 'the', 'wound', 'of', 'burns', 'gets', 'healed', 'by', 'raw', 'peel', 'of', 'potato', '<e>'] 9.984460212607036
#
# 55 ['<s>', 'the', 'paste', 'of', 'hot', 'rice', 'works', 'on', 'the', 'theory', 'of', 'moist', 'heat', 'therapy', 'and', 'it', 'sucks', 'out', 'pain', 'and', 'stiffness', '<e>'] 23.718343184628626
#
# 56 ['<s>', 'ice', 'cubes', 'reduce', 'fever', '<e>'] 9.784446791578914
#
# 57 ['<s>', 'orifice', 'hernia', 'sac', 'and', 'the', 'substance', 'present', 'in', 'it', 'or', 'organs', '<e>'] 5.878016072274913
#
# 58 ['<s>', 'one', 'main', 'cause', 'for', 'occurrence', 'of', 'mental', 'disorders', 'for', 'any', 'person', 'is', 'also', 'not', 'being', 'able', 'to', 'strike', 'a', 'proper', 'balance', 'with', 'his', 'surroundings', '<e>'] 11.899761228662909
#
# 59 ['<s>', 'inguinal', 'hernia', 'this', 'is', 'a', 'swelling', 'connected', 'to', 'the', 'inguinal', 'canal', 'on', 'the', 'inner', 'walls', 'of', 'stomach', 'and', 'therefore', 'it', 'has', 'been', 'given', 'the', 'name', 'of', 'inguinal', 'hernia', '<e>'] 8.579227564055039
#
# 60 ['<s>', 'if', 'the', 'size', 'of', 'this', 'type', 'of', 'hernia', 'is', 'small', 'that', 'is', 'less', 'than', 'half', 'inch', 'then', 'it', 'generally', 'gets', 'closed', 'on', 'its', 'own', 'by', 'the', 'time', 'the', 'child', 'reaches', 'the', 'age', 'of', 'two', 'years', '<e>'] 11.572662629212713
#
# 61 ['<s>', 'he', 'gets', 'working', 'in', 'normal', 'way', 'after', 'just', 'two', 'three', 'days', 'of', 'surgery', 'and', 'within', '5', 'to', '7', 'days', 'he', 'gets', 'to', 'his', 'daily', 'works', '<e>'] 9.950968086482792
#
# 62 ['<s>', 'surgeon', 'gets', 'helped', 'by', 'means', 'of', 'camera', 'in', 'seeing', 'hernia', 'and', 'the', 'adjoining', 'regions', 'on', 'the', 'video', 'screen', '<e>'] 9.826760367819253
#
# 63 ['<s>', 'it', 'is', 'worth', 'mentioning', 'that', 'hernia', 'is', 'such', 'a', 'problem', 'which', 'does', 'not', 'get', 'cured', 'on', 'its', 'own', 'and', 'it', 'keeps', 'on', 'increasing', 'with', 'time', '<e>'] 14.089221216798252
#
# 64 ['<s>', 'then', 'you', 'should', 'choose', 'four', 'tips', 'from', 'the', 'daily', 'food', 'column', 'and', 'the', 'alternative', 'to', 'burn', '500', 'calories', 'daily', 'from', 'the', 'exercise', '2', 'column', '<e>'] 9.518642295850753
#
# 65 ['<s>', 'stop', 'taking', 'any', 'drink', 'which', 'increases', 'calorie', 'like', 'cola', 'alcohol', '<e>'] 30.860968695883955
#
# 66 ['<s>', 'in', 'place', 'of', 'biryani', 'fried', 'rice', 'pulao', 'try', 'eating', 'lemon', 'rice', 'or', 'eat', 'rice', 'cooked', 'in', 'tomato', 'juice', '<e>'] 23.394352189093976
#
# 67 ['<s>', 'walk', '30', 'minutes', 'in', 'morning', '15', 'minutes', 'after', 'lunch', 'and', '30', 'minutes', 'in', 'the', 'evening', '<e>'] 13.67809422265298
#
# 68 ['<s>', 'this', 'is', 'that', 'condition', 'of', 'patient', 'when', 'the', 'insulin', 'is', 'secreted', 'less', 'or', 'not', 'secreted', 'at', 'all', 'because', 'the', 'immune', 'system', 'attacks', 'the', 'cells', 'of', 'pancreas', '<e>'] 10.44424875461991
#
# 69 ['<s>', 'generally', 'school', 'going', 'girls', 'and', 'working', 'women', 'are', 'more', 'prone', 'to', 'this', '<e>'] 9.909798771958092
#
# 70 ['<s>', 'headache', 'is', 'indeed', 'a', 'very', 'common', 'problem', '<e>'] 4.641588833612778
#
# 71 ['<s>', 'hormonal', 'change', '<e>'] 1.7782794100389228
#
# 72 ['<s>', 'many', 'people', 'may', 'have', 'problem', 'with', 'strong', 'sunlight', 'heat', 'or', 'cold', '<e>'] 16.467034706422748
#
# 73 ['<s>', 'onset', 'of', 'nausea', 'and', 'vomiting', 'with', 'intense', 'headache', '<e>'] 8.902627431397061
#
# 74 ['<s>', 'and', 'the', 'remaining', 'half', 'is', 'in', 'tissues', 'and', 'organ', 'cells', '<e>'] 9.639265907441658
#
# 75 ['<s>', 'unhygienic', 'life', 'style', '<e>'] 2.51188643150958
#
# 76 ['<s>', 'gastroenteritis', 'is', 'a', 'serious', 'disease', 'for', 'those', 'who', 'can', 'not', 'digest', 'anything', '<e>'] 6.318167550760955
#
# 77 ['<s>', 'if', 'seen', 'from', 'the', 'point', 'of', 'view', 'of', 'calorie', 'then', 'in', 'approximately', '100', 'gram', 'salad', 'leaves', 'there', 'are', '21', 'calories', '<e>'] 10.328409677933585
#
# 78 ['<s>', 'the', 'greener', 'the', 'salad', 'leaves', 'the', 'more', 'would', 'be', 'the', 'quantity', 'of', 'vitamin', 'c', 'in', 'them', '<e>'] 9.246218607864263
#
# 79 ['<s>', 'salad', 'leaves', 'are', 'very', 'good', 'for', 'brain', 'nervous', 'system', 'and', 'lungs', '<e>'] 5.043873234650623
#
# 80 ['<s>', 'french', 'beans', 'is', 'also', 'very', 'beneficial', 'in', 'diseases', 'related', 'to', 'kidney', '<e>'] 5.286293433053018
#
# 81 ['<s>', 'the', 'yellowish', 'green', 'oil', 'obtained', 'from', 'the', 'fresh', 'leaves', 'is', 'aromatic', 'and', 'bitter', 'in', 'taste', '<e>'] 14.692237185039398
#
# 82 ['<s>', 'corn', 'keeps', 'control', 'of', 'the', 'urinary', 'system', 'keeps', 'the', 'teeth', 'strong', 'and', 'is', 'also', 'beneficial', 'in', 'heart', 'disease', 'when', 'taken', 'in', 'the', 'form', 'of', 'cornflakes', '<e>'] 14.96981874223947
#
# 83 ['<s>', 'through', 'the', 'creative', 'capacity', 'or', 'the', 'assistance', 'of', 'the', 'brain', 'itself', 'einstein', 'c', 'v', 'raman', 'tagore', 'and', 'shakespeare', 'could', 'produce', 'their', 'extreme', 'original', 'and', 'unique', 'ideas', '<e>'] 36.05170660275877
#
# 84 ['<s>', 'this', 'way', 'the', 'signals', 'can', 'be', 'sequenced', 'with', 'respect', 'to', 'time', '<e>'] 9.25970424035536
#
# 85 ['<s>', 'from', 'the', 'point', 'of', 'view', 'of', 'creation', 'we', 'can', 'divide', 'the', 'brain', 'into', 'many', 'parts', '<e>'] 5.603921828020406
#
# 86 ['<s>', 'a', 'sudden', 'jerk', 'or', 'injury', 'on', 'the', 'medulla', 'can', 'therefore', 'lead', 'to', 'death', 'in', 'a', 'moment', '<e>'] 9.159295152615893
#
# 87 ['<s>', 'we', 'do', 'not', 'fall', 'even', 'when', 'fleeing', 'running', 'doing', 'acrobats', 'bending', 'forward', 'backward', '<e>'] 36.99502109510216
#
# 88 ['<s>', 'from', 'the', 'unconscious', 'state', 'we', 'have', 'come', 'to', 'the', 'conscious', 'state', '<e>'] 9.147315640761207
#
# 89 ['<s>', 'only', 'the', 'electric', 'impulses', 'are', 'reaching', 'there', 'through', 'the', 'nerves', '<e>'] 8.1201622055957
#
# 90 ['<s>', 'why', 'not', 'we', 'study', 'a', 'small', 'model', 'of', 'brain', 'before', 'understanding', 'an', 'incredible', 'computer', 'like', 'the', 'human', 'brain', '<e>'] 18.36518428849207
#
# 91 ['<s>', 'both', 'the', 'hemispheres', 'of', 'cerebrum', 'continued', 'fulfilling', 'their', 'responsibility', 'by', 'controlling', 'the', 'respective', 'halves', 'of', 'the', 'body', '<e>'] 19.150888316487848
#
# 92 ['<s>', 'whatever', 'we', 'study', 'in', 'class', 'generally', 'gets', 'accumulated', 'in', 'the', 'right', 'or', 'left', 'hemisphere', 'according', 'to', 'this', 'area', 'division', '<e>'] 12.170995863217726
#
# 93 ['<s>', 'with', 'how', 'much', 'vigor', 'and', 'hard', 'work', 'scientists', 'are', 'engrossed', 'in', 'studying', 'our', 'brain', 'and', 'how', 'thrilling', 'are', 'their', 'experiments', '<e>'] 13.509919682593123
#
# 94 ['<s>', 'the', 'homeopathic', 'doctor', 'minu', 'mehta', 'says', 'that', 'women', 'should', 'get', 'hyper', 'plasia', 'test', 'done', 'right', 'after', 'the', 'age', 'of', '30', 'years', '<e>'] 20.053549443703393
#
# 95 ['<s>', 'breast', 'cancer', 'is', 'engulfing', 'indian', 'women', 'very', 'fast', '<e>'] 8.615532108981524
#
# 96 ['<s>', 'not', 'just', 'this', 'together', 'with', 'this', 'one', 'should', 'also', 'do', 'bsf', 'or', 'breast', 'self', 'exam', '<e>'] 9.00385718331204
# 97 ['<s>', 'in', 'fsh', 'test', 'one', 'can', 'be', 'saved', 'from', 'the', 'diseases', 'happening', 'at', 'the', 'time', 'of', 'or', 'after', 'menopause', '<e>'] 7.580875952845719
#
# 98 ['<s>', 'if', 'any', 'kind', 'of', 'unusual', 'change', 'is', 'happening', 'in', 'these', 'then', 'it', 'can', 'be', 'known', 'through', 'pelvic', 'exam', 'test', '<e>'] 13.196261257068597
#
# 99 ['<s>', 'if', 'you', 'are', 'less', 'than', '45', 'years', 'and', 'you', 'smoke', 'then', 'you', 'take', 'the', 'advice', 'of', 'your', 'doctor', 'regarding', 'this', 'as', 'to', 'when', 'you', 'should', 'get', 'your', 'cholesterol', 'test', 'done', '<e>'] 9.317512121946825
#
# 100 ['<s>', 'flexible', 'sigmoendoscopy', 'must', 'be', 'done', 'once', 'every', 'five', 'years', '<e>'] 4.993629605801215
#
# 101 ['<s>', 'a', 'glass', 'vessel', 'full', 'of', 'blood', 'in', 'which', 'oxygen', 'is', 'released', 'in', 'the', 'form', 'of', 'bubbles', '<e>'] 8.705226181511446
#
# 102 ['<s>', 'the', 'heart', 'can', 'not', 'take', 'nutrients', 'from', 'the', 'blood', 'filled', 'in', 'its', 'chambers', '<e>'] 9.895558181078831
#
# 103 ['<s>', 'coronary', 'arteries', 'distribute', 'oxygen', 'and', 'nutrients', 'to', 'the', 'heart', '<e>'] 16.284901821547326
#
# 104 ['<s>', 'the', 'meaning', 'of', 'coronary', 'is', 'coronation', 'and', 'these', 'arteries', 'are', 'spread', 'like', 'a', 'crown', 'on', 'the', 'heart', '<e>'] 10.656566153125498
#
# 105 ['<s>', 'whether', 'there', 'is', 'kidney', 'or', 'not', 'if', 'there', 'then', 'whether', 'it', 'is', 'working', 'properly', 'or', 'not', 'or', 'if', 'there', 'is', 'any', 'type', 'of', 'cyst', 'stone', 'swelling', 'pus', 'this', 'also', 'is', 'told', 'to', 'us', 'by', 'the', 'ultrasound', 'test', '<e>'] 13.1998838453099
#
# 106 ['<s>', 'the', 'extent', 'to', 'which', 'ultrasonography', 'is', 'useful', 'in', 'the', 'test', 'of', 'foetus', 'in', 'the', 'womb', 'is', 'not', 'anywhere', '<e>'] 5.615705246858172
#
# 107 ['<s>', 'the', 'time', 'required', 'in', 'the', 'lithoptysis', 'technique', 'depends', 'on', 'the', 'size', 'of', 'the', 'stone', 'and', 'its', 'number', '<e>'] 8.305962000165291
#
# 108 ['<s>', 'generally', 'this', 'is', 'done', 'in', 'one', 'episode', '<e>'] 4.792352422537088
#
# 109 ['<s>', 'as', 'an', 'exception', 'one', 'may', 'have', 'to', 'be', 'put', 'under', 'vigilance', 'for', '24', 'hours', '<e>'] 8.675152784670844
#
# 110 ['<s>', 'do', 'not', 'consume', 'tea', 'coffee', 'carbonated', 'drinking', 'substances', 'or', 'it', 'should', 'be', 'done', 'in', 'as', 'much', 'less', 'quantity', 'as', 'possible', 'along', 'with', 'it', '<e>'] 13.64544270485742
#
# 111 ['<s>', 'if', 'these', 'increases', 'the', 'will', 'power', 'in', 'patients', 'then', 'also', 'relief', 'may', 'be', 'got', 'from', 'the', 'problems', '<e>'] 6.9519279617756045
#
# 112 ['<s>', 'if', 'a', 'tumor', 'persists', 'for', 'years', 'then', 'in', 'the', 'situation', 'of', 'the', 'growth', 'of', 'the', 'tumor', 'getting', 'tested', 'is', 'a', 'must', '<e>'] 8.25486145472024
#
# 113 ['<s>', 'the', 'patients', 'who', 'have', 'already', 'got', 'the', 'rotating', 'platform', 'high', 'flexion', 'knee', 'transplant', 'today', 'experience', 'much', 'more', 'satisfaction', 'and', 'they', 'can', 'finish', 'their', 'daily', 'activity', 'in', 'a', 'much', 'better', 'way', '<e>'] 14.128002091094267
#
# 114 ['<s>', 'since', 'naltrekson', 'is', 'intoxication', 'preventive', 'in', 'the', 'purest', 'form', 'therefore', 'till', 'the', 'time', 'it', 'is', 'there', 'in', 'the', 'body', 'no', 'type', 'of', 'excitement', 'would', 'be', 'felt', 'by', 'him', 'on', 'doing', 'any', 'type', 'of', 'intoxication', '<e>'] 10.84703784805455
#
# 115 ['<s>', 'one', 'can', 'get', 'harmed', 'by', 'the', 'consumption', 'of', 'any', 'intoxicating', 'item', 'be', 'it', 'alcohol', 'or', 'smack', 'or', 'any', 'other', 'intoxicating', 'item', 'with', 'naltrekson', 'implant', '<e>'] 9.836710972681871
#
# 116 ['<s>', 'in', 'the', 'extreme', 'case', 'of', 'bacterial', 'dysentery', 'there', 'is', 'repeated', 'tendency', 'of', 'releasing', 'fecus', 'in', 'the', 'patient', 'but', 'each', 'time', 'very', 'less', 'fecus', 'is', 'discharged', '<e>'] 29.046867379607345
#
# 117 ['<s>', 'do', 'not', 'take', 'the', 'child', 'to', 'a', 'place', 'where', 'other', 'children', 'are', 'sick', '<e>'] 5.867396364527006
#
# 118 ['<s>', 'unbalanced', 'diet', 'not', 'just', 'stops', 'the', 'continuous', 'growth', 'of', 'hair', 'but', 'it', 'also', 'makes', 'bald', 'very', 'fast', '<e>'] 29.048346668928588
#
# 119 ['<s>', 'normally', 'the', 'main', 'symptom', 'of', 'obesity', 'is', 'that', 'the', 'height', 'of', 'the', 'body', 'should', 'be', 'in', 'proportion', 'to', 'the', 'weight', 'of', 'the', 'body', '<e>'] 5.620969115808687
#
# 120 ['<s>', 'cholesterol', 'fat', 'accumulates', 'in', 'the', 'blood', 'carrying', 'vessels', 'as', 'a', 'result', 'of', 'which', 'diseases', 'like', 'high', 'blood', 'pressure', 'indigestion', 'heart', 'disease', 'and', 'diabetes', 'occur', '<e>'] 7.711864585703521
#
# 121 ['<s>', 'at', 'present', 'as', 'the', 'consciousness', 'of', 'people', 'are', 'increasing', 'towards', 'healthy', 'life', 'and', 'pure', 'and', 'plain', 'healthy', 'diet', 'and', 'exercise', 'people', 'are', 'becoming', 'aware', 'of', 'the', 'dangers', 'owing', 'to', 'increase', 'in', 'weight', 'and', 'obesity', '<e>'] 11.214352719525676
#
# 122 ['<s>', 'positive', 'results', 'of', 'reducing', 'obesity', 'come', 'forward', '<e>'] 4.641588833612778
#
# 123 ['<s>', 'dry', 'cough', 'starts', 'coming', 'and', 'there', 'is', 'difficulty', 'in', 'breathing', '<e>'] 3.5688184955264557
#
# 124 ['<s>', 'the', 'infected', 'person', 'gets', 'fever', 'of', '104', 'degree', 'fahrenheit', 'or', 'more', 'and', 'he', 'also', 'feels', 'cold', 'with', 'this', '<e>'] 20.30665883775764
#
# 125 ['<s>', 'in', 'the', 'whole', 'world', 'there', 'is', 'a', 'situation', 'of', 'illusion', 'regarding', 'the', 'patients', 'and', 'the', 'symptoms', 'of', 'sars', '<e>'] 6.449881565701826
#
# 126 ['<s>', 'the', 'nature', 'protects', 'us', 'by', 'other', 'means', 'as', 'well', '<e>'] 5.3366992312063095
#
# 127 ['<s>', 'their', 'diagnosis', 'is', 'possible', 'by', 'stool', 'examination', '<e>'] 4.641588833612778
#
# 128 ['<s>', 'the', 'water', 'in', 'rural', 'areas', 'is', 'generally', 'available', 'from', 'these', 'sources', 'only', '<e>'] 6.105402296585328
#
# 129 ['<s>', 'the', 'worm', 'generally', 'produces', 'a', 'wart', 'in', 'that', 'part', 'of', 'the', 'body', 'which', 'often', 'comes', 'in', 'contact', 'with', 'water', '<e>'] 9.478563682244145
#
# 130 ['<s>', 'by', 'affecting', 'the', 'pancreas', 'and', 'nervous', 'system', 'malaria', 'becomes', 'the', 'reason', 'of', 'loss', 'of', 'consciousness', 'and', 'at', 'times', 'death', '<e>'] 13.882730555678734
#
# 131 ['<s>', 'for', 'the', 'ascertainment', 'of', 'the', 'suitability', 'of', 'fluoride', 'rich', 'drinks', 'the', 'role', 'of', 'fluoride', 'is', 'also', 'very', 'important', '<e>'] 6.566582036004581
#
# 132 ['<s>', 'the', 'pulse', 'polio', 'program', 'will', 'continue', 'for', 'three', 'more', 'years', 'now', '<e>'] 5.146116109519194
#
# 133 ['<s>', 'this', 'is', 'the', 'reason', 'that', 'the', 'infant', 'mortality', 'rate', 'is', 'very', 'high', 'in', 'india', '<e>'] 5.2259236379917375
#
# 134 ['<s>', 'the', 'patient', 'may', 'even', 'die', 'if', 'the', 'treatment', 'is', 'not', 'done', 'immediately', 'because', 'by', 'this', 'the', 'fever', 'rises', 'up', 'to', '106', 'degree', 'fahrenheit', '<e>'] 14.112803061914569
#
# 135 ['<s>', 'there', 'is', 'no', 'permanent', 'solution', 'to', 'malaria', 'and', 'neither', 'have', 'the', 'doctors', 'of', 'the', 'world', 'discovered', 'its', 'any', 'inoculation', '<e>'] 13.743478858709238
#
# 136 ['<s>', 'patients', 'of', 'high', 'blood', 'pressure', 'should', 'consume', 'fibrous', 'eatables', 'and', 'green', 'vegetables', 'more', 'in', 'their', 'food', '<e>'] 4.959043467874181
#
# 137 ['<s>', 'in', 't', 'u', 'r', 'p', 'method', 'telescope', 'stays', 'attached', 'to', 'a', 'video', 'system', '<e>'] 6.699879435163243
#
# 138 ['<s>', 'in', 'such', 'a', 'situation', 'the', 'part', 'of', 'place', 'of', 'surgery', 'becomes', 'stiff', 'like', 'stone', '<e>'] 5.562085903769924
#
# 139 ['<s>', 'increasing', 'havoc', 'of', 'asthma', 'in', 'childhood', '<e>'] 4.216965034285822
# 140 ['<s>', 'environment', 'of', 'cities', 'is', 'more', 'polluted', '<e>'] 4.216965034285822
#
# 141 ['<s>', 'after', 'this', 'gradually', 'start', 'giving', 'fruit', 'vegetables', 'first', 'and', 'then', 'grains', '<e>'] 9.854973955313493
#
# 142 ['<s>', 'in', 'case', 'of', 'children', 'getting', 'asthma', 'the', 'disease', 'can', 'be', 'controlled', 'by', 'maintaining', 'caution', 'and', 'by', 'giving', 'appropriate', 'treatment', '<e>'] 10.353345772618345
#
# 143 ['<s>', 'on', 'getting', 'hepatitis', 'b', 'it', 'should', 'be', 'shown', 'to', 'a', 'gastroenterologist', 'immediately', '<e>'] 14.656198066618636
#
# 144 ['<s>', 'take', 'milk', 'and', 'fresh', 'curd', 'not', 'sour', 'curd', '<e>'] 9.566346639876867
#
# 145 ['<s>', 'spine', 'happens', 'to', 'be', 'the', 'base', 'of', 'the', 'whole', 'body', 'and', 'rest', 'of', 'the', 'bones', 'are', 'joined', 'to', 'each', 'other', 'like', 'the', 'ends', 'of', 'a', 'staff', '<e>'] 9.59619298072374
#
# 146 ['<s>', 'if', 'it', 'is', 'the', 'case', 'of', 'it', "'s", 'treatment', 'then', 'several', 'kinds', 'of', 'treatments', 'are', 'also', 'present', '<e>'] 6.688111922278709
#
# 147 ['<s>', 'the', 'main', 'advantage', 'of', 'vat', 'is', 'that', 'patient', 'can', 'start', 'walking', 'around', 'from', 'next', 'day', 'there', 'is', 'no', 'risk', 'of', 'bleeding', 'or', 'infection', 'and', 'patient', 'gets', 'a', 'discharge', 'from', 'the', 'hospital', 'in', '3', 'days', '<e>'] 13.700002110839216
#
# 148 ['<s>', 'drink', 'a', 'lot', 'of', 'water', 'and', 'do', 'not', 'use', 'much', 'chillies', 'and', 'spices', '<e>'] 4.766548537215017
#
# 149 ['<s>', 'during', 'sports', 'jogging', 'tennis', 'and', 'skiing', 'there', 'is', 'more', 'activity', '<e>'] 42.0523192591841
#
# 150 ['<s>', 'interstitial', 'cystitis', 'is', 'an', 'agonizing', 'disease', 'for', 'women', '<e>'] 8.150194901663843
#
# 151 ['<s>', 'treasure', 'of', 'health', '<e>'] 2.51188643150958
#
# 152 ['<s>', 'bring', 'in', 'use', 'low', 'fat', 'products', 'of', 'dairy', 'products', 'like', 'cheese', 'cottage', 'cheese', 'milk', 'and', 'cream', '<e>'] 12.524173852477155
#
# 153 ['<s>', 'exercise', 'everyday', 'for', '20', 'to', '30', 'minutes', '<e>'] 4.437117926289388
#
# 154 ['<s>', 'congenital', 'heart', 'disease', 'is', 'one', 'such', 'grotesque', 'state', 'which', 'is', 'a', 'disease', 'as', 'well', 'as', 'a', 'bane', '<e>'] 18.446162169290243
#
# 155 ['<s>', 'for', 'its', 'prevention', 'mothers', 'during', 'pregnancy', 'should', 'consider', 'it', 'beneficial', 'to', 'avoid', 'diseases', 'like', 'measles', 'and', 'strong', 'toxic', 'medicines', '<e>'] 9.779965932443732
#
# 156 ['<s>', 'through', 'surgery', 'many', 'babies', 'have', 'received', 'a', 'new', 'life', '<e>'] 5.478110574583797
#
# 157 ['<s>', 'habit', 'of', 'physical', 'exercise', 'is', 'the', 'best', 'cure', 'for', 'escape', 'from', 'heart', 'disease', '<e>'] 5.113508032055226
#
# 158 ['<s>', 'due', 'to', 's', 'u', 'i', 'fear', 'of', 'constant', 'wetness', 'and', 'the', 'stink', 'arising', 'out', 'of', 'it', 'makes', 'them', 'conscious', 'of', 'the', 'huge', 'inconvenience', '<e>'] 18.580851339086326
#
# 159 ['<s>', 'the', 'company', 'that', 'makes', 't', 'v', 't', 'determines', 'its', 'high', 'quality', '<e>'] 26.059927305192602
#
# 160 ['<s>', 'in', 'dysentery', 'the', 'apprehension', 'of', 'having', 'to', 'go', 'to', 'the', 'toilet', 'again', 'and', 'again', 'is', 'always', 'there', '<e>'] 10.215209243233351
#
# 161 ['<s>', 'in', 'youth', 'patient', 'gets', 'pimples', 'on', 'his', 'face', '<e>'] 5.011872336272723
#
# 162 ['<s>', 'small', 'but', 'very', 'useful', 'home', 'remedies', '<e>'] 4.216965034285822
#
# 163 ['<s>', 'in', 'disease', 'of', 'pyria', 'by', 'applying', 'everyday', '22', 'grams', 'of', 'lemon', 'juice', '110', 'grams', 'of', 'sesame', 'oil', 'and', 'a', 'little', 'rock', 'salt', 'mixed', 'together', 'disease', 'gets', 'destroyed', '<e>'] 8.469490108047033
#
# 164 ['<s>', 'specialists', 'also', 'treat', 'it', 'with', 'artificial', 'light', '<e>'] 4.641588833612778
#
# 165 ['<s>', 'if', 'there', 'comes', 'an', 'obstruction', 'in', 'the', 'bile', 'duct', 'that', 'makes', 'bilirubin', 'reach', 'the', 'intestine', 'from', 'the', 'liver', 'then', 'this', 'substance', 'does', 'not', 'reach', 'the', 'intestine', '<e>'] 18.165725069644658
#
# 166 ['<s>', 'consequently', 'the', 'amount', 'of', 'bilirubin', 'in', 'blood', 'increases', 'which', 'gets', 'accumulated', 'in', 'body', 'parts', 'like', 'eyes', 'skin', 'and', 'nails', 'etc', 'this', 'way', 'these', 'body', 'parts', 'start', 'looking', 'yellow', 'and', 'weakness', 'in', 'body', 'increases', '<e>'] 14.663255557409018
#
# 167 ['<s>', 'for', 'treatment', 'of', 'itching', 'it', 'is', 'necessary', 'to', 'bathe', 'in', 'a', 'proper', 'way', 'with', 'a', 'neem', 'soap', 'before', 'applying', 'medicine', '<e>'] 11.98049727712198
#
# 168 ['<s>', 'bathe', 'for', 'two', 'days', 'in', 'this', 'way', '<e>'] 4.684791216568464
#
# 169 ['<s>', 'suddenly', 'dizziness', 'coming', 'over', '<e>'] 9.47210719590089
#
# 170 ['<s>', 'knee', 'is', 'the', 'biggest', 'and', 'the', 'most', 'complex', 'joint', 'of', 'the', 'body', '<e>'] 5.193072375295623
#
# 171 ['<s>', 'if', 'there', 'is', 'wear', 'and', 'tear', 'in', 'the', 'bones', 'there', 'is', 'some', 'infection', 'or', 'there', 'is', 'a', 'tumor', 'then', 'it', 'should', 'be', 'treated', 'through', 'an', 'orthopaedic', 'surgeon', '<e>'] 12.635760061107932
#
# 172 ['<s>', 'blood', 'pressure', 'and', 'hypertension', 'are', 'reduced', 'by', 'laughter', '<e>'] 9.829253238774573
#
# 173 ['<s>', 'a', 'good', 'alternative', 'for', 'heart', 'related', 'exercise', 'is', 'laughter', '<e>'] 5.3366992312063095
#
# 174 ['<s>', 'laughter', 'reduces', 'the', 'secretion', 'of', 'the', 'hormone', 'increasing', 'tension', '<e>'] 10.237312519916946
#
# 175 ['<s>', 'decrease', 'of', 'appetite', 'peptic', 'ulcer', 'loss', 'of', 'immunity', 'capacity', 'of', 'the', 'body', 'extreme', 'pain', 'anywhere', 'continuous', 'cold', 'and', 'flu', 'also', 'are', 'the', 'common', 'problems', 'of', 'tension', '<e>'] 7.478954684894399
#
# 176 ['<s>', 'for', 'becoming', 'tension', 'free', 'discussion', 'may', 'be', 'done', 'with', 'any', 'counsellor', 'but', 'money', 'is', 'spent', 'in', 'that', '<e>'] 9.971109877326896
#
# 177 ['<s>', 'if', 'the', 'diet', 'is', 'good', 'then', 'the', 'tension', 'would', 'stay', 'less', 'but', 'if', 'there', 'is', 'even', 'slight', 'problem', 'in', 'the', 'food', 'then', 'it', 'may', 'increase', 'the', 'disease', '<e>'] 7.587509835979413
#
# 178 ['<s>', 'what', 'should', 'be', 'eaten', 'during', 'tension', '<e>'] 3.480790945322477
#
# 179 ['<s>', 'at', 'the', 'time', 'of', 'tension', 'the', 'quantity', 'of', 'vitamin', 'mineral', 'vitamin', 'b', 'complex', 'zinc', 'serenium', 'should', 'be', 'increased', '<e>'] 8.783612781727838
#
# 180 ['<s>', 'by', 'getting', 'vitamin', 'a', 'in', 'huge', 'quantity', 'blindness', 'occurring', 'due', 'to', 'lack', 'of', 'nutrition', 'can', 'be', 'prevented', '<e>'] 6.47777230129164
#
# 181 ['<s>', 'these', 'diseases', 'are', 'pneumonia', 'onset', 'of', 'dysentery', 'and', 'dry', 'eye', 'discharge', 'xerophthalmia', '<e>'] 5.498281777993325
#
# 182 ['<s>', 'xerophthalmia', 'occurs', 'due', 'to', 'the', 'error', 'in', 'transmission', 'of', 'the', 'absorbed', 'retinol', 'to', 'the', 'right', 'place', 'in', 'the', 'body', 'and', 'the', 'fast', 'depletion', 'of', 'the', 'accumulated', 'vitamin', 'in', 'the', 'body', '<e>'] 12.403330607795791
#
# 183 ['<s>', 'the', 'absorption', 'of', 'vitamin', 'a', 'in', 'the', 'children', 'victims', 'of', 'dysentery', 'respiration', 'related', 'infections', 'measles', 'diseases', 'of', 'stomach', 'and', 'intestines', 'decreases', 'and', 'its', 'need', 'to', 'the', 'body', 'increases', '<e>'] 11.184069138010697
#
# 184 ['<s>', 'now', 'by', 'giving', 'an', 'extension', 'to', 'this', 'program', 'children', 'of', '6', '11', 'months', 'are', 'also', 'being', 'included', '<e>'] 12.804784994055868
#
# 185 ['<s>', 'one', 'to', 'four', 'weeks', 'after', 'this', 'second', 'dose', 'of', '2', '00', '000', 'i', 'u', 'of', 'vitamin', 'a', 'should', 'be', 'given', '<e>'] 5.055830616490035
#
# 186 ['<s>', 'comprehensive', 'immunity', 'inoculation', 'program', 'provides', 'an', 'opportunity', 'of', 'coming', 'in', 'contact', 'with', 'the', 'newborn', 'babies', '<e>'] 7.682597193621361
# 187 ['<s>', 'the', 'amount', 'of', 'vitamin', 'a', 'and', 'carotene', 'in', 'the', 'diet', 'of', 'children', 'have', 'been', 'found', 'less', 'than', 'half', 'of', 'the', 'daily', 'proposed', 'quantity', 'of', '400', 'gram', 'retinol', 'or', '1600', 'microgram', 'of', 'beta', 'carotene', '<e>'] 24.771641958512934
#
# 188 ['<s>', 'along', 'with', 'the', 'other', 'food', 'items', 'a', 'child', 'can', 'eat', 'this', 'much', 'of', 'vegetable', 'easily', '<e>'] 6.503858760078324
#
# 189 ['<s>', 'nutrition', 'education', 'is', 'an', 'integral', 'part', 'of', 'primary', 'health', 'services', 'and', 'icds', 'program', 'and', 'under', 'this', 'emphasis', 'must', 'be', 'given', 'on', 'the', 'encouragement', 'of', 'the', 'use', 'of', 'food', 'items', 'highly', 'rich', 'in', 'vitamin', 'a', '<e>'] 11.195648802013782
#
# 190 ['<s>', 'the', 'workers', 'of', 'both', 'the', 'areas', 'will', 'be', 'benefitted', 'by', 'this', 'in', 'playing', 'their', 'responsibility', 'in', 'the', 'implementation', 'of', 'the', 'program', 'in', 'effective', 'manner', '<e>'] 11.497104028723552
#
# 191 ['<s>', 'under', 'the', 'first', 'principle', 'the', 'arrangement', 'of', 'administering', 'heavy', 'dose', 'to', 'children', 'between', 'the', 'age', 'of', '6', 'months', 'and', '5', 'years', 'has', 'been', 'done', '<e>'] 9.157783788653592
#
# 192 ['<s>', 'apart', 'from', 'this', 'the', 'organisms', 'like', 'e', 'coli', 'and', 'pseudomonas', 'have', 'also', 'been', 'found', 'because', 'of', 'whose', 'infection', 'the', 'ill', 'effect', 'on', 'the', 'body', 'is', 'maximum', '<e>'] 10.544922356850103
#
# 193 ['<s>', 'but', 'after', 'the', 'untiring', 'efforts', 'of', 'hundreds', 'of', 'researchers', 'success', 'has', 'been', 'achieved', 'in', 'the', 'preparation', 'of', 'one', 'more', 'vaccine', '<e>'] 12.248675744621591
#
# 194 ['<s>', 'though', 'this', 'medicine', 'can', 'not', 'be', 'administered', 'to', 'children', 'who', 'are', 'less', 'than', 'one', 'year', 'of', 'age', '<e>'] 8.300679879546824
#
# 195 ['<s>', 'get', 'your', 'breasts', 'checked', 'up', 'once', 'in', 'a', 'month', '<e>'] 9.90702985236761
#
# 196 ['<s>', 'the', 'children', 'should', 'be', 'given', 'such', 'snacks', 'in', 'which', 'there', 'is', 'no', 'excessive', 'sugar', 'and', 'they', 'are', 'non', 'sticky', '<e>'] 8.242988396265385
#
# 197 ['<s>', 'try', 'that', 'the', 'children', 'should', 'do', 'the', 'brushing', 'with', 'their', 'own', 'hands', '<e>'] 5.2186011598247415
#
# 198 ['<s>', 'if', 'care', 'lessens', 'has', 'not', 'been', 'shown', 'in', 'the', 'cleanliness', 'of', 'the', 'teeth', 'then', 'there', 'is', 'no', 'need', 'to', 'worry', '<e>'] 5.849461911104225
#
# 199 ['<s>', 'keep', 'the', 'bristles', 'at', 'the', 'angle', 'of', '45', 'degree', 'angle', 'on', 'the', 'teeth', '<e>'] 10.17477052213635
#
# 200 ['<s>', 'the', 'eyesight', 'becomes', 'weak', 'on', 'the', 'removal', 'of', 'the', 'upper', 'tooth', 'this', 'myth', 'is', 'totally', 'false', '<e>'] 9.385599874369712
#
# 201 ['<s>', 'there', 'is', 'plenty', 'of', 'calcium', 'in', 'dairy', 'products', 'like', 'milk', 'cheese', 'and', 'curd', 'which', 'make', 'the', 'teeth', 'strong', 'and', 'healthy', '<e>'] 18.18711432955606
#
# 202 ['<s>', 'the', 'nervous', 'system', 'weakens', 'due', 'to', 'insecticides', '<e>'] 4.641588833612778
#
# 203 ['<s>', 'the', 'right', 'quantity', 'of', 'fluoride', 'in', 'water', 'makes', 'the', 'teeth', 'and', 'bones', 'strong', '<e>'] 9.887330354898335
#
# 204 ['<s>', 'child', 'not', 'eating', 'the', 'food', 'is', 'a', 'common', 'problem', 'of', 'all', 'mothers', 'fathers', '<e>'] 8.786640475046894
#
# 205 ['<s>', 'bedwetting', 'this', 'problem', 'is', 'considered', 'to', 'be', 'normal', 'up', 'to', 'the', 'age', 'of', 'four', 'or', 'five', 'years', 'but', 'if', 'children', 'more', 'than', 'this', 'age', 'do', 'it', 'then', 'there', 'is', 'also', 'a', 'treatment', 'for', 'them', '<e>'] 8.2414806946356
#
# 206 ['<s>', 'this', 'mosquito', 'of', 'malaria', 'affects', 'the', 'red', 'blood', 'corpuscles', '<e>'] 9.812435845828475
#
# 207 ['<s>', 'the', 'vaccine', 'of', 'hepatitis', 'a', 'protects', 'the', 'child', 'from', 'jaundice', 'and', 'contagious', 'diseases', 'of', 'the', 'liver', '<e>'] 5.165138752830637
#
# 208 ['<s>', 'the', 'vaccine', 'of', 'hepatitis', 'a', 'is', 'pit', 'three', 'times', '<e>'] 14.830676386325893
#
# 209 ['<s>', 'in', 'order', 'to', 'get', 'relief', 'in', 'gas', 'give', 'fried', 'asafoetida', 'and', 'black', 'salt', 'and', 'carom', 'seed', 'with', 'luke', 'warm', 'water', '<e>'] 18.35523250760885
#
# 210 ['<s>', 'if', 'there', 'is', 'no', 'balance', 'in', 'the', 'diet', 'of', 'children', 'then', 'it', 'does', 'not', 'take', 'long', 'for', 'then', 'to', 'fall', 'ill', '<e>'] 8.778175640209383
#
# 211 ['<s>', 'and', 'also', 'maximum', 'children', 'escape', 'from', 'eating', 'food', 'or', 'they', 'like', 'such', 'food', 'in', 'which', 'there', 'is', 'less', 'nutrition', '<e>'] 16.205939372843876
#
# 212 ['<s>', 'this', 'is', 'such', 'time', 'when', 'they', 'are', 'growing', 'up', 'fast', '<e>'] 5.62341325190349
#
# 213 ['<s>', 'with', 'regular', 'check', 'up', 'one', 'can', 'know', 'of', 'the', 'growth', 'and', 'weight', 'of', 'the', 'children', '<e>'] 6.432399211627213
#
# 214 ['<s>', 'saturated', 'fat', 'and', 'unsaturated', 'fat', '<e>'] 3.72759372031494
#
# 215 ['<s>', 'from', 'birth', 'to', 'three', 'years', 'of', 'age', 'around', '1000', 'calories', '<e>'] 3.912910059959108
#
# 216 ['<s>', 'for', 'at', 'least', '6', 'months', 'the', 'mother', 'should', 'breastfeed', 'her', 'child', '<e>'] 5.878016072274913
#
# 217 ['<s>', 'however', 'from', 'the', 'third', 'or', 'fourth', 'day', 'of', 'his', 'birth', 'he', 'should', 'not', 'be', 'put', 'to', 'the', 'habit', 'of', 'being', 'fed', 'the', 'milk', 'several', 'times', 'at', 'the', 'interval', 'of', 'every', 'two', 'hours', '<e>'] 9.057425998024085
#
# 218 ['<s>', 'in', 'the', 'seventh', 'month', 'every', 'month', 'in', 'the', 'year', 'do', 'consult', 'the', 'doctor', 'so', 'that', 'in', 'the', 'upbringing', 'of', 'the', 'ones', 'child', 'there', 'is', 'no', 'lack', 'mother', '<e>'] 9.284380879956062
#
# 219 ['<s>', 'do', 'not', 'put', 'oil', 'in', 'ear', 'and', 'nose', '<e>'] 10.806660891207706
#
# 220 ['<s>', 'in', 'such', 'patients', 'tourniquet', 'test', 'is', 'positive', 'and', 'on', 'getting', 'the', 'blood', 'tested', 'the', 'platelet', 'count', 'is', 'found', 'to', 'be', 'less', 'that', 'one', 'lakh', '<e>'] 9.332006999529657
#
# 221 ['<s>', 'so', 'that', 'according', 'to', 'the', 'premenopausal', 'condition', 'and', 'fertility', 'they', 'can', 'give', 'you', 'the', 'right', 'direction', '<e>'] 12.898153967667461
#
# 222 ['<s>', 'professor', 'marion', 'joe', 'ligeto', 'of', 'the', 'columbia', 'university', 'has', 'to', 'say', 'that', '80', 'of', 'the', 'diseases', 'of', 'heart', 'is', 'related', 'to', 'gene', '<e>'] 18.051185300062198
#
# 223 ['<s>', 'the', 'gene', 'is', 'dominant', 'in', 'such', 'a', 'manner', 'that', 'despite', 'taking', 'extra', 'precaution', 'the', 'chances', 'of', 'heart', 'attack', 'keeps', 'looming', '<e>'] 25.555198877365257
#
# 224 ['<s>', 'by', 'doing', 'the', 'treatment', 'at', 'the', 'right', 'time', 'the', 'sunburns', 'also', 'get', 'healed', '<e>'] 4.793253218699569
#
# 225 ['<s>', 'like', 'bleeding', 'during', 'pregnancy', 'or', 'delivery', '<e>'] 9.794223081949491
#
# 226 ['<s>', 'do', 'you', 'know', 'in', 'which', 'items', 'these', 'iron', 'substances', 'are', 'found', 'more', '<e>'] 9.201930685207495
#
# 227 ['<s>', 'therefore', 'on', 'child', 'falling', 'sick', 'also', 'do', 'not', 'stop', 'feeding', 'food', 'to', 'him', '<e>'] 10.776587604461806
#
# 228 ['<s>', 'after', 'toilet', 'or', 'after', 'cleaning', 'the', 'child', "'", 's', 'toilet', 'certainly', 'wash', 'hands', 'with', 'soap', '<e>'] 5.908724356609487
#
# 229 ['<s>', 'when', 'they', 'want', 'children', 'how', 'many', 'children', 'whether', 'they', 'want', 'or', 'not', 'they', 'can', 'decide', 'this', 'with', 'the', 'help', 'of', 'their', 'life', 'partner', '<e>'] 8.50023993912495
#
# 230 ['<s>', 'in', 'the', 'process', 'of', 'vasectomy', 'also', 'that', 'passage', 'is', 'closed', 'without', 'incision', 'through', 'which', 'the', 'sperms', 'flow', '<e>'] 6.221152462998945
#
# 231 ['<s>', 'these', 'pills', 'on', 'going', 'to', 'the', 'body', 'of', 'the', 'female', 'stop', 'the', 'female', 'from', 'conceiving', '<e>'] 10.22976754351369
# 232 ['<s>', 'the', 'pain', 'and', 'blood', 'flow', 'occurring', 'these', 'days', 'also', 'reduces', 'by', 'which', 'the', 'complaint', 'of', 'anemia', 'does', 'not', 'occur', '<e>'] 9.439770326672742
#
# 233 ['<s>', 'there', 'is', 'no', 'alternative', 'to', 'exercise', 'in', 'reducing', 'obesity', 'but', 'if', 'you', 'feel', 'that', 'strolling', 'morning', 'evening', 'is', 'exercise', 'then', 'it', 'is', 'completely', 'wrong', '<e>'] 7.408603356531379
#
# 234 ['<s>', 'smoking', 'drinking', 'mental', 'tension', 'fuel', 'the', 'fire', 'therefore', 'escape', 'from', 'them', '<e>'] 9.987695909429965
#
# 235 ['<s>', 'consume', 'seasonal', 'fruits', 'vegetables', 'in', 'more', 'and', 'more', 'quantity', 'and', 'consume', 'fruits', 'vegetables', 'of', 'dark', 'color', 'more', 'and', 'more', 'quantity', 'and', 'certainly', 'eat', 'the', 'fruits', 'vegetables', 'of', 'dark', 'color', 'but', 'eat', 'less', 'sweet', 'fruits', '<e>'] 14.05922978943012
#
# 236 ['<s>', 'if', 'there', 'is', 'desire', 'to', 'eat', 'sweets', 'then', 'eat', 'such', 'sweets', 'in', 'which', 'there', 'has', 'been', 'no', 'use', 'ghee', 'like', 'petha', 'in', 'place', 'of', 'gulab', 'jamun', '<e>'] 23.793667329044098
#
# 237 ['<s>', 'according', 'to', 'the', 'verdict', 'of', 'dr', 'vimal', 'chhajed', 'the', 'director', 'and', 'the', 'heart', 'specialist', 'of', 'saaol', 'heart', 'center', 'of', 'delhi', 'the', 'alternative', 'of', 'natural', 'treatment', 'is', 'the', 'most', 'beneficial', 'for', 'the', 'patients', 'of', 'heart', '<e>'] 24.759157562137695
#
# 238 ['<s>', 'for', 'the', 'cleanliness', 'of', 'the', 'scalp', 'long', 'hair', 'should', 'be', 'cut', 'short', '<e>'] 18.490315940363054
#
# 239 ['<s>', 'by', 'applying', 'the', 'juice', 'of', 'the', 'leaves', 'of', 'dhatura', 'on', 'the', 'blisters', 'of', 'arunshika', 'two', 'times', 'a', 'day', 'after', 'adding', 'camphor', 'the', 'blisters', 'are', 'fast', 'destroyed', '<e>'] 7.0536891518030025
#
# 240 ['<s>', 'in', 'ayurveda', 'it', 'is', 'called', 'shaishawiya', 'pakshawadha', 'baal', 'pakshaaghaat', 'or', 'adharaang', 'waat', '<e>'] 51.486378272577134
#
# 241 ['<s>', 'the', 'attack', 'of', 'the', 'disease', 'of', 'polio', 'is', 'often', 'sudden', '<e>'] 4.9318959631203905
#
# 242 ['<s>', 'at', 'present', 'two', 'types', 'of', 'polio', 'vaccine', 'are', 'brought', 'in', 'use', 'for', 'the', 'protection', 'against', 'this', 'disease', 'salk', 'vaccine', 'and', 'sabin', 'vaccine', '<e>'] 12.323724765388953
#
# 243 ['<s>', 'there', 'is', 'the', 'provision', 'of', 'making', 'the', 'use', 'of', 'sabin', 'vaccine', 'through', 'mouth', 'at', 'the', 'interval', 'of', 'every', '1', 'month', 'continuously', 'for', 'three', 'months', 'three', 'times', 'in', 'total', '<e>'] 7.524774805597127
#
# 244 ['<s>', 'but', 'in', 'modern', 'experiments', 'one', 'such', 'element', 'has', 'come', 'to', 'be', 'known', 'which', 'is', 'considered', 'to', 'be', 'far', 'more', 'lethal', 'to', 'the', 'heart', 'than', 'the', 'cholesterol', '<e>'] 12.49681591376434
#
# 245 ['<s>', 'the', 'reasons', 'for', 'increase', 'of', 'homocystin', 'is', 'obesity', 'diabetes', 'high', 'blood', 'pressure', 'smoking', 'etc', '<e>'] 8.47070920162151
#
# 246 ['<s>', 'on', 'getting', 'heart', 'attack', 'restlessness', 'is', 'felt', 'to', 'a', 'great', 'extent', '<e>'] 3.657530467431419
#
# 247 ['<s>', 'do', 'not', 'give', 'anything', 'to', 'eat', 'or', 'drink', 'to', 'the', 'affected', 'person', '<e>'] 5.237756172848318
#
# 248 ['<s>', 'do', 'not', 'leave', 'the', 'burnt', 'area', 'uncovered', 'cover', 'it', 'with', 'sterilised', 'cloth', '<e>'] 7.415956225459837
#
# 249 ['<s>', 'along', 'with', 'the', 'fracture', 'if', 'there', 'is', 'wound', 'or', 'the', 'pulse', 'is', 'not', 'felt', 'then', 'take', 'him', 'to', 'the', 'doctor', 'immediately', '<e>'] 10.615864801870696
#
# 250 ['<s>', 'on', 'the', 'occurrence', 'of', 'any', 'domestic', 'accident', 'with', 'the', 'child', 'you', 'take', 'the', 'following', 'precautions', '<e>'] 14.717762248305908
#
# 251 ['<s>', 'scientists', 'believe', 'that', 'cancer', 'doest', 'not', 'only', 'remove', 'mild', 'diseases', 'but', 'also', 'cancer', '<e>'] 8.97069199224356
#
# 252 ['<s>', 'if', 'you', 'have', 'sugar', 'then', 'regularly', 'you', 'should', 'get', 'blood', 'pressure', 'check', 'up', 'ecg', 'and', 'also', 'urine', 'test', 'done', '<e>'] 9.58469127137216
#
# 253 ['<s>', 'the', 'lower', 'or', 'the', 'narrow', 'part', 'of', 'this', 'uterus', 'is', 'called', 'cervix', '<e>'] 15.444751651238505
#
# 254 ['<s>', 'this', 'cancer', 'though', 'occurs', 'in', 'the', 'age', 'of', 'fifty', 'six', 'but', 'now', 'this', 'disease', 'has', 'also', 'started', 'occurring', 'in', 'young', 'age', '<e>'] 11.76316831812371
#
# 255 ['<s>', 'apart', 'from', 'the', 'menstrual', 'flow', 'the', 'discharge', 'coming', 'out', 'of', 'the', 'genital', 'path', 'is', 'called', 'leukoria', 'or', 'white', 'discharge', '<e>'] 9.833121725184235
#
# 256 ['<s>', 'these', 'days', 'at', 'every', 'place', 'there', 'are', 'heaps', 'of', 'garbage', 'and', 'the', 'water', 'also', 'continues', 'to', 'get', 'accumulated', 'which', 'is', 'the', 'suitable', 'place', 'for', 'the', 'breeding', 'of', 'mosquitoes', 'flies', 'cockroaches', 'etc', '<e>'] 16.538418317511237
#
# 257 ['<s>', 'up', 'to', 'four', 'months', 'do', 'not', 'give', 'anything', 'other', 'than', 'mother', "'s", 'milk', '<e>'] 8.727252648195682
#
# 258 ['<s>', 'if', 'the', 'child', 'has', 'problem', 'in', 'drinking', 'water', 'or', 'the', 'breathing', 'is', 'fast', 'then', 'immediately', 'take', 'it', 'to', 'big', 'hospital', '<e>'] 7.525539404883695
#
# 259 ['<s>', 'every', 'vaccine', 'was', 'registered', 'in', 'the', 'mother', 'child', 'protection', 'card', 'and', 'every', 'time', 'behanji', 'reminded', 'radha', 'of', 'coming', 'the', 'next', 'time', 'for', 'the', 'vaccines', '<e>'] 16.620315770135623
#
# 260 ['<s>', 'on', 'sixth', 'month', 'the', 'weight', 'of', 'muniya', 'was', 'twice', 'from', 'that', 'at', 'birth', '<e>'] 10.036905551397266
#
# 261 ['<s>', 'change', 'in', 'the', 'nails', 'growing', 'on', 'the', 'inner', 'side', 'of', 'fingers', 'like', 'nails', 'getting', 'thick', 'or', 'colourless', 'is', 'a', 'sign', 'of', 'diabetes', 'foot', '<e>'] 7.9419575761019106
#
# 262 ['<s>', 'after', 'wiping', 'apply', 'talcum', 'powder', 'between', 'feet', 'and', 'fingers', 'so', 'that', 'there', 'remains', 'no', 'wetness', '<e>'] 11.398068590253029
#
# 263 ['<s>', 'rd_punc', 'v_vaux', 'v_vm', 'n_nn', 'cc_ccd', 'psp', 'n_nn', 'n_nn', 'rp_rpd', 'n_nn', 'cc_ccd', 'v_vm', 'n_nn', 'jj', '<e>'] 5.2491673657125775
#
# 264 ['<s>', 'the', 'interior', 'of', 'the', 'shoes', 'should', 'be', 'soft', '<e>'] 4.023238219303823
#
# ...
#
# 911 ['<s>', 'patients', 'of', 'diseases', 'like', 'aids', 'blood', 'cancer', 'rabies', 'septicemia', 'poisoning', 'in', 'blood', 'jaundice', 'viral', 'hepatitis', 'etc', 'can', 'not', 'donate', 'eyes', '<e>'] 18.436880073405938
#
# 912 ['<s>', 'till', 'eye', 'bank', 'team', 'comes', 'switch', 'off', 'fans', 'let', 'air', 'conditioner', 'or', 'coolers', 'work', 'and', 'keep', 'damp', 'cotton', 'and', 'ice', 'on', 'closed', 'eye', 'lashes', '<e>'] 21.234851089452743
#
# 913 ['<s>', 'complete', 'it', '<e>'] 1.0027972301167465
#
# 914 ['<s>', 'because', 'of', 'bipolar', 'disorder', 'some', 'people', 'get', 'addicted', 'to', 'drugs', 'and', 'alcohol', '<e>'] 15.416258454195008
#
# 915 ['<s>', 'people', 'associated', 'with', 'clinical', 'research', 'remind', 'this', 'that', 'if', 'continuous', 'therapy', 'is', 'done', 'then', 'this', 'disease', 'can', 'be', 'cured', '<e>'] 13.826284245475756
#
# 916 ['<s>', 'while', 'choosing', 'the', 'mood', 'stabilizer', 'the', 'age', 'of', 'the', 'person', 'his', 'her', 'weight', 'demographic', 'profile', 'family', 'history', 'effect', 'of', 'medicine', 'and', 'metabolic', 'endocrine', 'and', 'cardiovascular', 'profiles', 'are', 'also', 'seen', '<e>'] 25.8989038917652
#
# 917 ['<s>', 'many', 'infants', 'who', 'are', 'born', 'with', 'weak', 'immunization', 'the', 'immunity', 'of', 'children', 'increases', 'with', 'breast', 'feeding', 'and', 'many', 'children', 'who', 'are', 'regularly', 'infected', 'through', 'other', 'children', 'in', 'school', 'can', 'fall', 'sick', 'again', 'and', 'again', '<e>'] 12.374046477533163
#
# 918 ['<s>', 'for', 'remaining', 'healthy', 'good', 'nutrition', 'is', 'very', 'important', '<e>'] 4.511765588936235
#
# 919 ['<s>', 'an', 'unparalleled', 'herbomineral', 'medicine', 'septilin', 'has', 'been', 'prepared', 'in', 'consequence', 'of', 'intensive', 'research', 'and', 'testing', 'which', 'helps', 'in', 'increasing', 'the', 'immunity', 'strength', 'in', 'children', 'and', 'adults', 'making', 'the', 'security', 'system', 'of', 'the', 'body', 'itself', 'strong', '<e>'] 20.616484900553715
#
# 920 ['<s>', 'if', 'amla', 'is', 'used', 'everyday', 'then', 'it', 'cleans', 'the', 'blood', 'by', 'which', 'the', 'heart', 'remains', 'healthy', '<e>'] 6.812920690579611
#
# 921 ['<s>', 'by', 'including', 'almond', 'pista', 'peanuts', 'etc', 'in', 'regular', 'food', 'the', 'heart', 'remains', 'healthy', 'and', 'by', 'this', 'the', 'fear', 'of', 'diseases', 'happening', 'related', 'to', 'this', 'also', 'reduces', '<e>'] 12.750244558756537
#
# 922 ['<s>', 'unsaturated', 'fats', 'omega', '3', 'fatty', 'acids', 'fiber', 'etc', 'are', 'included', '<e>'] 8.754087422657422
#
# 923 ['<s>', 'by', 'watching', 'tv', 'from', 'close', 'by', 'watching', 'the', 'tv', 'for', 'long', 'water', 'starts', 'flowing', 'from', 'the', 'eyes', 'which', 'is', 'a', 'type', 'of', 'allergy', '<e>'] 9.081146932496551
#
# 924 ['<s>', 'she', 'would', 'think', 'about', 'waxing', 'for', 'getting', 'rid', 'of', 'these', 'unwanted', 'hairs', 'but', 'would', 'get', 'scared', 'about', 'the', 'pain', 'happening', 'along', 'with', 'that', '<e>'] 27.080260767927168
#
# 925 ['<s>', 'although', 'the', 'course', 'of', 'the', 'treatment', 'is', 'different', 'on', 'the', 'basis', 'of', 'the', 'growth', 'of', 'hair', 'and', 'type', 'but', 'its', 'result', 'is', 'permanent', '<e>'] 10.841113005902177
#
# 926 ['<s>', 'it', 'is', 'essential', 'for', 'the', 'care', 'of', 'food', 'and', 'exercise', 'during', 'pregnancy', '<e>'] 6.278205171016456
#
# 927 ['<s>', 'so', 'do', 'not', 'do', 'any', 'work', 'continuously', '<e>'] 4.641588833427551
#
# 928 ['<s>', 'the', 'weight', 'of', 'the', 'child', 'will', 'be', 'less', 'by', 'smoking', '<e>'] 3.9587699591068124
#
# 929 ['<s>', 'because', 'sugar', 'makes', 'our', 'immune', 'system', 'weak', '<e>'] 9.71266828677641
#
# 930 ['<s>', 'anyone', 'can', 'be', 'influenced', 'by', 'this', 'state', 'of', 'depression', '<e>'] 5.143567350587658
#
# 931 ['<s>', 'statistics', 'say', 'that', 'the', 'death', 'of', '62', 'percent', 'smoking', 'women', 'in', 'india', 'happens', 'in', '30', 'to', '49', 'years', 'of', 'age', '<e>'] 16.910346603283788
#
# 932 ['<s>', 'systolic', 'blood', 'pressure', 'must', 'be', 'between', '100', '140', 'millimetre', 'mm', 'and', 'diastolic', '70', '100', 'millimetre', '<e>'] 20.398811439980513
#
# 933 ['<s>', 'you', 'have', 'had', 'cold', 'and', 'fever', 'whose', 'reason', 'you', 'do', 'not', 'know', '<e>'] 10.074381911863414
#
# 934 ['<s>', 'first', 'time', 'donator', 'of', 'plasma', 'must', 'have', 'donated', 'blood', 'at', 'least', 'once', 'in', 'the', 'last', 'one', 'year', '<e>'] 9.437032077356239
#
# 935 ['<s>', 'in', 'comparison', 'of', 'this', 'voluntary', 'blood', 'donors', 'do', 'not', 'hide', 'their', 'diseases', '<e>'] 16.138521253350962
#
# 936 ['<s>', 'every', 'time', 'when', 'you', 'donate', 'blood', 'then', 'the', 'history', 'of', 'your', 'health', 'is', 'asked', 'and', 'a', 'limited', 'medical', 'check', 'is', 'done', '<e>'] 13.084066780915549
#
# 937 ['<s>', 'use', 'such', 'an', 'oil', 'in', 'food', 'which', 'does', 'not', 'solidify', '<e>'] 7.373613151066516
#
# 938 ['<s>', 'in', 'such', 'cases', 'the', 'danger', 'of', 'heart', 'attacks', 'increases', '20', 'percent', 'in', 'which', 'the', 'life', 'of', 'the', 'person', 'may', 'be', 'lost', '<e>'] 6.657823170871314
#
# 939 ['<s>', 'that', 'is', 'why', 'one', 'must', 'remain', 'very', 'careful', '<e>'] 8.460102701024955
#
# 940 ['<s>', 'no', 'symptom', 'of', 'enzyma', 'appears', 'in', 'the', 'patients', 'of', 'diabetes', '<e>'] 4.5692131127483036
#
# 941 ['<s>', 'stress', 'ecocardiogram', 'by', 'this', 'test', 'heart', 'wall', 'and', 'its', 'pumping', 'work', 'is', 'seen', '<e>'] 30.84223501716644
#
# 942 ['<s>', 'there', 'is', 'a', 'check', 'for', 'this', 'also', '<e>'] 4.255785657718281
#
# 943 ['<s>', 'do', 'not', 'sit', 'for', 'long', 'at', 'the', 'computer', '<e>'] 12.880665857026933
#
# 944 ['<s>', 'the', 'smoke', 'of', 'tobacco', 'harms', 'your', 'body', 'and', 'cancer', 'of', 'lungs', 'throat', 'etc', 'heart', 'disease', 'and', 'are', 'the', 'reason', 'of', 'lung', 'diseases', 'of', 'long', 'duration', 'like', 'bronchitis', 'asthma', 'etc', '<e>'] 12.787881931726341
#
# 945 ['<s>', 'as', 'beautiful', 'as', 'a', 'strawberry', 'looks', 'it', 'is', 'as', 'much', 'filled', 'with', 'benefits', '<e>'] 9.891273184121596
#
# 946 ['<s>', 'keep', 'some', 'walnuts', 'in', 'them', 'for', 'extra', 'crunch', '<e>'] 5.011872336272723
#
# 947 ['<s>', 'if', 'the', 'mother', 'father', 'both', 'are', 'fat', 'then', 'there', 'remains', '80', 'percent', 'possibility', 'of', 'the', 'child', 'being', 'fat', 'and', '40', 'percent', 'when', 'some', 'one', 'from', 'mother', 'father', 'is', 'fat', '<e>'] 9.102903074752273
# 948 ['<s>', 'along', 'with', 'the', 'compressor', 'being', 'made', 'the', 'temperature', 'of', 'the', 'engine', 'also', 'increases', '<e>'] 9.018415817755438
#
# 949 ['<s>', 'this', 'work', 'is', 'of', 'kafa', 'in', 'the', 'body', '<e>'] 3.9309120595024765
#
# 950 ['<s>', 'although', 'in', 'modern', 'medicine', 'in', 'view', 'of', 'the', 'result', 'the', 'medicine', 'is', 'given', 'but', 'that', 'medicine', 'may', 'be', 'increasing', 'the', 'pitta', 'and', 'the', 'cells', 'have', 'closed', 'because', 'of', 'the', 'increase', 'in', 'pitta', 'by', 'this', 'instead', 'of', 'benefits', 'the', 'possibility', 'of', 'harm', 'increases', '<e>'] 11.387805867842205
#
# 951 ['<s>', 'like', 'in', 'the', 'body', 'if', 'generally', 'some', 'part', 'gets', 'injured', 'then', 'the', 'cells', 'and', 'tissues', 'there', 'give', 'their', 'full', 'contribution', 'according', 'to', 'the', 'formation', 'of', 'that', 'place', '<e>'] 9.99833783400452
#
# 952 ['<s>', 'unber', 'the', 'yukti', 'vyapakshya', 'first', 'the', 'panchakarma', 'of', 'the', 'patient', 'is', 'done', '<e>'] 12.35258214651643
#
# 953 ['<s>', 'apply', 'this', 'on', 'the', 'neck', 'and', 'leave', 'for', '10', 'to', '15', 'minutes', '<e>'] 4.697672235005898
#
# 954 ['<s>', 'the', 'doctors', 'of', 'rhode', 'island', 'hospital', 'have', 'discovered', 'microscopic', 'particles', 'named', 'micro', 'vesicles', '<e>'] 40.632885748752265
#
# 955 ['<s>', 'later', 'they', 'do', 'the', 'creation', 'of', 'new', 'cells', '<e>'] 5.011872336272723
#
# 956 ['<s>', 'by', 'putting', 'a', 'cut', 'on', 'the', 'stomach', 'or', 'chest', 'the', 'aneurysm', 'part', 'of', 'the', 'aorta', 'can', 'be', 'cut', 'and', 'a', 'pipe', 'is', 'sewn', 'in', 'its', 'place', '<e>'] 8.249152544788291
#
# 957 ['<s>', 'in', 'this', 'surgical', 'repairing', 'the', 'danger', 'to', 'the', 'life', 'of', 'the', 'patient', 'is', '10', '<e>'] 9.20807879939444
#
# 958 ['<s>', 'yes', 'in', 'approximately', '20', '30', 'percent', 'people', 'by', 'the', 'deficiency', 'of', 'vitamin', 'b', '12', 'there', 'is', 'the', 'possibility', 'of', 'pain', 'in', 'the', 'waist', 'and', 'back', '<e>'] 7.634650990950378
#
# 959 ['<s>', 'complete', 'it', '<e>'] 1.0027972301167465
#
# 960 ['<s>', 'actually', 'it', 'has', 'been', 'known', 'by', 'the', 'descriptions', 'of', 'a', 'total', 'of', '18', 'studies', 'done', 'on', 'flaxseed', 'that', 'if', 'a', 'person', 'with', 'high', 'cholestrol', 'intakes', 'around', '30', 'to', '60', 'grams', 'of', 'flaxseed', 'daily', 'then', 'his', 'faulty', 'cholestrol', 'ldl', 'level', 'can', 'reduce', 'to', 'a', 'considerable', 'extent', '<e>'] 10.606016732130334
#
# 961 ['<s>', 'those', 'females', 'who', 'have', 'the', 'problem', 'of', 'leukorrhea', 'discharge', 'of', 'white', 'water', 'they', 'should', 'eat', 'ten', 'grams', 'of', 'amla', 'in', 'equal', 'amount', 'of', 'suger', 'and', 'honey', 'till', 'two', 'weeks', 'daily', 'there', 'problem', 'will', 'be', 'solved', '<e>'] 15.22367176933485
#
# 962 ['<s>', 'the', 'hemoglobin', 'level', 'improves', 'with', 'its', 'intake', '<e>'] 9.860619229083031
#
# 963 ['<s>', 'complete', 'it', '<e>'] 1.0027972301167465
#
# 964 ['<s>', 'under', 'this', 'new', 'skin', 'emerges', 'very', 'soon', 'whereas', 'before', 'this', 'when', 'the', 'ablative', 'lasers', 'were', 'used', 'then', 'it', 'took', 'time', 'for', 'the', 'fresh', 'skin', 'to', 'emerge', '<e>'] 18.85244418510803
#
# 965 ['<s>', 'fractional', 'laser', 'is', 'suitable', 'for', 'the', 'treatment', 'of', 'light', 'wrinkles', 'and', 'with', 'it', 'a', 'special', 'glow', 'comes', 'on', 'the', 'skin', '<e>'] 5.248820470505968
#
# 966 ['<s>', 'according', 'to', 'fred', 'hutchinson', 'cancer', 'research', 'centre', 'and', 'other', 'researchers', 'the', 'females', 'who', 'have', 'the', 'history', 'of', 'migraine', 'a', 'type', 'of', 'headache', 'they', 'have', '26', 'percent', 'less', 'chances', 'of', 'having', 'breast', 'cancer', '<e>'] 12.275647398013371
#
# 967 ['<s>', 'have', 'to', 'give', 'a', 'dinner', 'party', 'in', 'the', 'evening', 'or', 'participate', 'in', 'a', 'race', 'in', 'the', 'evening', '<e>'] 13.362233763552371
#
# 968 ['<s>', 'hence', 'now', 'the', 'researchers', 'are', 'being', 'pressurized', 'that', 'the', 'earlier', 'cancer', 'related', 'assumptions', 'they', 'test', 'them', 'again', 'and', 'try', 'to', 'undersatnd', 'what', 'cancer', 'actually', 'is', 'and', 'how', 'does', 'its', 'development', 'takes', 'place', '<e>'] 17.216270917228858
#
# 969 ['<s>', 'due', 'to', 'lack', 'of', 'screening', 'this', 'was', "n't", 'there', 'earlier', '<e>'] 8.168284611067866
#
# 970 ['<s>', 'astigmatismo', 'this', 'is', 'a', 'special', 'kind', 'of', 'vision', 'defect', 'in', 'which', 'the', '<e>'] 10.681766052041153
#
# 971 ['<s>', 'if', 'in', 'some', 'accident', 'the', 'female', 'hurts', 'her', 'spine', 'then', 'usually', 'she', 'has', 'backache', 'problems', '<e>'] 32.409245706181885
#
# 972 ['<s>', 'the', 'tonsil', 'stops', 'if', 'its', 'heated', 'just', 'when', 'it', 'is', 'erupting', '<e>'] 9.941079071309343
#
# 973 ['<s>', 'arnmal', 'impacted', 'cerumen', 'some', 'amount', 'of', 'dirt', 'tent', 'to', 'accumulate', 'in', 'the', 'ear', 'but', 'at', 'times', 'it', 'starts', 'to', 'get', 'more', '<e>'] 14.418692611814809
#
# 974 ['<s>', 'at', 'times', 'there', 'is', 'egzema', 'in', 'the', 'ear', 'or', 'the', 'natural', 'dirt', 'gets', 'more', 'greasy', '<e>'] 13.664060725268376
#
# 975 ['<s>', 'complete', 'it', '<e>'] 1.0027972301167465
#
# 976 ['<s>', 'in', 'equal', 'amount', 'of', 'vinegar', 'and', 'the', 'infusion', 'of', 'rose', 'add', 'half', 'of', 'it', 'in', 'whisky', 'and', 'double', 'its', 'amount', 'in', 'water', '<e>'] 7.498942093324557
#
# 977 ['<s>', 'baldness', 'becomes', 'temporary', 'after', 'fever', '<e>'] 25.942328543472772
#
# 978 ['<s>', 'argate', 'belladonna', 'hyosimes', 'antipyrine', 'tincture', 'belliriun', 'quinine', 'tincture', 'ferri', 'perchloride', 'musk', 'etc', 'are', 'useful', 'in', 'this', 'disease', '<e>'] 16.01268209125007
#
# 979 ['<s>', 'bahumutra', 'excessive', 'urination', 'diabetes', 'insipidus', 'there', 'is', 'no', 'specific', 'cause', 'of', 'this', 'disease', 'sometimes', 'it', 'happens', 'because', 'of', 'injury', 'to', 'head', '<e>'] 14.725729550809731
#
# 980 ['<s>', 'patient', 'of', 'syphilis', 'should', 'be', 'given', 'potash', 'iodide', 'in', 'whole', 'amount', '<e>'] 27.773529325349408
#
# 981 ['<s>', 'in', 'pain', 'of', 'atrophic', 'and', 'rheumatoid', 'arthritis', 'kolvikum', 'iodides', 'soda', 'salicylic', 'salicyn', 'ericherine', 'guacum', 'tincture', 'jalsimayi', 'etc', 'are', 'beneficial', '<e>'] 107.1513027479982
#
# 982 ['<s>', 'after', 'occurrence', 'of', 'tremor', 'in', 'one', 'arm', 'tremor', 'also', 'starts', 'in', 'the', 'leg', 'of', 'that', 'side', '<e>'] 15.653329325994118
#
# 983 ['<s>', 'patient', 'of', 'this', 'disease', 'recovers', 'very', 'seldom', '<e>'] 7.105103793285372
#
# 984 ['<s>', 'but', 'in', 'embolism', 'coma', 'does', 'not', 'occur', 'at', 'all', 'or', 'a', 'momentary', 'unconsciousness', 'occurs', 'but', 'half', 'paralysis', 'is', 'of', 'a', 'very', 'acute', 'kind', '<e>'] 9.81747221680237
#
# 985 ['<s>', 'nervous', 'disease', 'heart', 'disease', 'and', 'epilepsy', 'etc', 'mental', 'illnesses', 'are', 'also', 'of', 'this', 'kind', '<e>'] 30.455279883123975
#
# 986 ['<s>', 'divya', 'ashmarihar', 'kvath', 'decoction', 'it', 'is', 'made', 'from', 'diuretic', 'and', 'stone', 'penetration', 'plants', 'mentioned', 'in', 'ayurveda', '<e>'] 14.255179057035749
#
# 987 ['<s>', 'those', 'who', 'have', 'complaint', 'of', 'recurrent', 'formation', 'of', 'stones', 'after', 'eating', 'this', 'for', 'a', 'while', 'formation', 'of', 'stones', 'ends', 'forever', '<e>'] 6.878201413323828
#
# 988 ['<s>', 'this', 'kayakalp', 'oil', 'is', 'a', 'holy', 'medicine', 'worth', 'keeping', 'in', 'every', 'house', 'at', 'all', 'times', '<e>'] 5.961025023909254
#
# 989 ['<s>', 'it', 'is', 'an', 'ayurvedic', 'drink', '<e>'] 11.137684557889129
#
# 990 ['<s>', 'divya', 'dhara', 'from', '5', 'to', '10', 'drops', 'of', 'essence', 'of', 'fennel', 'etc', 'give', 'in', '15', 'minutes', 'in', 'cholera', '<e>'] 8.409638623974333
#
# 991 ['<s>', 'on', 'occurrence', 'of', 'stomach', 'ache', 'gas', 'or', 'flatulence', 'and', 'asthma', 'eat', 'adding', '3', '4', 'drops', 'to', 'raw', 'sugar', 'batasha', 'or', 'hot', 'water', '<e>'] 8.910913212740942
# 992 ['<s>', 'lungs', 'get', 'oxygen', 'in', 'more', 'amount', 'by', 'this', '<e>'] 5.011872336272723
#
# 993 ['<s>', 'by', 'consuming', 'for', 'a', 'while', 'all', 'female', 'problems', 'go', 'away', '<e>'] 9.90178557239942
#
# 994 ['<s>', 'removing', 'restlessness', 'nervousness', 'it', 'increases', 'efficiency', 'of', 'heart', '<e>'] 5.011872336272723
#
# 995 ['<s>', 'there', 'is', 'growth', 'in', 'resistance', 'power', 'in', 'body', '<e>'] 10.732973503930777
#
# 996 ['<s>', 'it', 'stops', 'inflammation', 'of', 'urinary', 'tract', 'and', 'all', 'over', 'and', 'increase', 'of', 'gall', '<e>'] 6.5281468700489365
#
# 997 ['<s>', 'there', 'is', 'danger', 'of', 'occurrence', 'of', 'ear', 'infection', 'with', 'cough', 'in', 'children', '<e>'] 4.708023308129916
#
# 998 ['<s>', 'for', 'this', 'mixing', 'water', 'in', 'khali', 'residue', 'remaining', 'after', 'extracting', 'oil', 'from', 'mustard', 'seed', 'mustard', 'leave', 'overnight', 'for', 'formation', 'of', 'daub', '<e>'] 26.64136586040238
#
# 999 ['<s>', 'your', 'hair', 'will', 'become', 'beautiful', 'black', 'dense', 'from', 'its', 'regular', 'use', '<e>'] 8.613682142778837

# %%
health_corpus_wb = []

for i in range(len(test)):
    perp = find_perp(test[i] , train_freq ,total_tokens ,'wb')
    
    print(test[i] ,perp)
    print()
    health_corpus_wb.append( [test[i] , perp])
# Out:
# ['<s>', 'drink', 'plenty', 'of', 'water', '<e>'] 1.5843146254571063
#
# ['<s>', 'if', 'fever', 'comes', 'continuously', 'you', 'must', 'get', 'it', 'checked', 'up', '<e>'] 7.20212549871248
#
# ['<s>', 'use', 'warm', 'water', 'for', 'bathing', '<e>'] 5.200361013487123
#
# ['<s>', 'brain', 'exercise', 'works', 'on', 'this', 'very', 'fundamental', '<e>'] 4.641588833612778
#
# ['<s>', 'remembering', 'in', 'chart', 'or', 'short', 'form', 'would', 'also', 'prove', 'helpful', '<e>'] 5.62341325190349
#
# ['<s>', 'brain', 'can', 'also', 'be', 'kept', 'sharpened', 'by', 'adopting', 'some', 'good', 'habits', '<e>'] 18.03271234856876
#
# ['<s>', 'h', 'i', 'v', 'stands', 'for', 'human', 'immuno', 'deficiency', 'virus', "'", '<e>'] 4.642385642517226
#
# ['<s>', 'what', 'happens', 'when', 'a', 'person', 'gets', 'infected', 'with', 'the', 'h', 'i', 'v', '<e>'] 19.131396519580363
#
# ['<s>', 'apart', 'from', 'this', 'some', 'diseases', 'of', 'the', 'internal', 'parts', 'of', 'chest', 'may', 'also', 'be', 'cured', 'by', 'this', 'method', '<e>'] 20.33262623459546
#
# ['<s>', 'because', 'of', 'only', 'four', 'holes', 'being', 'made', 'the', 'possibility', 'of', 'these', 'wounds', 'getting', 'ripened', 'or', 'infected', 'becomes', 'very', 'less', '<e>'] 11.515297894603647
#
# ['<s>', 'wounds', 'or', 'blisters', 'in', 'mouth', '<e>'] 9.898528379313406
#
# ['<s>', 'although', 'each', 'of', 'the', 'disease', 'is', 'different', 'from', 'the', 'other', 'but', 'basically', 'all', 'the', 'types', 'of', 'cancers', 'occurs', 'as', 'a', 'result', 'of', 'anomaly', 'in', 'some', 'cells', '<e>'] 12.505204651522638
#
# ['<s>', 'not', 'only', 'this', 'the', 'cost', 'of', 'early', 'identification', 'and', 'immediate', 'treatment', 'is', 'also', 'much', 'lower', 'than', 'late', 'treatment', '<e>'] 11.993941688970132
#
# ['<s>', 'testicular', 'gland', 'cancer', 'could', 'be', 'found', 'out', 'by', 'most', 'of', 'the', 'men', 'themselves', '<e>'] 11.553805364751149
#
# ['<s>', 'men', 'can', 'find', 'out', 'any', 'changes', 'in', 'the', 'testicular', 'gland', 'by', 'testing', 'themselves', 'every', 'month', '<e>'] 13.342447909766218
#
# ['<s>', 'you', 'must', 'get', 'tested', 'by', 'a', 'doctor', 'or', 'a', 'dentist', '<e>'] 10.271343608905898
#
# ['<s>', 'if', 'the', 'patient', 'takes', 'medicine', 'in', 'regular', 'cycle', 'and', 'eats', 'healthy', 'food', 'he', 'can', 'recover', 'fully', '<e>'] 9.276489073868502
#
# ['<s>', 'encouraging', 'reforms', 'in', 'rural', 'and', 'urban', 'lifestyle', 'through', 'government', 'and', 'non', 'government', 'department', 'and', 'social', 'organizations', '<e>'] 6.20945082241308
#
# ['<s>', 'it', 'can', 'also', 'spread', 'through', 'a', 'direct', 'contact', 'with', 'chicken', 'pox', 'or', 'herpes', 'because', 'there', 'is', 'contagious', 'liquid', 'in', 'raw', 'wounds', '<e>'] 8.400695721412148
#
# ['<s>', 'use', 'neem', 'oil', 'or', 'mustard', 'oil', 'over', 'body', '<e>'] 4.0348089184617555
#
# ['<s>', 'keep', 'the', 'environment', 'clean', 'at', 'home', 'and', 'nearby', '<e>'] 5.011872336272723
#
# ['<s>', 'the', 'chances', 'of', 'bringing', 'the', 'situation', 'back', 'to', 'the', 'pre', 'damage', 'stage', 'or', 'minimizing', 'it', 'increases', 'by', 'finding', 'out', 'the', 'complexities', 'early', 'through', 'regular', 'medical', 'tests', '<e>'] 11.128334503407704
#
# ['<s>', 'as', 'soon', 'as', 'the', 'above', 'mentioned', 'symptoms', 'appear', 'the', 'patient', 'should', 'immediately', 'be', 'admitted', 'for', 'treatment', 'at', 'the', 'nearby', 'primary', 'health', 'center', 'sub', 'divisional', 'government', 'hospital', 'or', 'district', 'hospital', '<e>'] 10.024428014939177
#
# ['<s>', 'the', 'family', 'welfare', 'program', 'was', 'run', 'at', 'the', 'national', 'level', 'in', 'the', 'year', 'of', '1952', '<e>'] 7.314219056583085
#
# ['<s>', 'all', 'the', 'reproduction', 'health', 'safety', 'should', 'be', 'kept', 'in', 'the', 'form', 'of', 'a', 'single', 'element', 'within', 'family', 'planning', 'services', '<e>'] 6.990332494437353
#
# ['<s>', 'this', 'program', 'has', 'been', 'running', 'in', 'uttarakhand', 'since', 'the', 'constitution', 'of', 'the', 'state', '<e>'] 20.16711745166691
#
# ['<s>', '900', 'untrained', 'midwives', 'have', 'been', 'trained', 'in', 'uttarakhand', 'in', 'the', 'year', 'of', '2001', '2002', 'and', '2002', '03', 'to', 'provide', 'services', 'of', 'safe', 'labor', 'to', 'pregnant', 'mothers', '<e>'] 5.610428709759269
#
# ['<s>', 'the', 'm', 'd', 't', 'medicine', 'cures', 'the', 'patient', 'completely', 'by', 'eradicating', 'the', 'leprosy', 'bacteria', 'and', 'prevents', 'the', 'disease', 'from', 'spreading', 'in', 'the', 'society', '<e>'] 9.81849675418864
#
# ['<s>', 'leprosy', 'often', 'starts', 'with', 'a', 'spot', 'or', 'freckle', 'on', 'the', 'body', 'that', 'is', 'numb', '<e>'] 8.795024737384944
#
# ['<s>', 'you', 'must', 'change', 'water', 'collected', 'in', 'pots', 'at', 'home', 'once', 'a', 'week', '<e>'] 8.869581793371296
#
# ['<s>', 'besides', 'this', 'mouth', 'also', 'starts', 'drying', 'up', 'due', 'to', 'mumps', '<e>'] 12.945348648280468
#
# ['<s>', 'live', 'attenuated', 'vaccines', 'of', 'measles', 'mumps', 'and', 'rubella', 'are', 'in', 'the', 'form', 'an', 'amalgamated', 'single', 'vaccine', 'which', 'is', 'called', 'mmr', '<e>'] 7.189323765757485
#
# ['<s>', 'such', 'a', 'system', 'of', 'brain', 'is', 'called', 'mental', 'disorder', '<e>'] 9.878211042362915
#
# ['<s>', 'getting', 'disturbed', 'soon', 'by', 'the', 'small', 'talk', 'of', 'children', '<e>'] 5.3366992312063095
#
# ['<s>', 'a', 'little', 'less', 'than', 'half', 'of', 'the', 'pregnant', 'women', 'are', 'able', 'to', 'get', 'pre', 'delivery', 'tests', 'done', 'in', 'uttarakhand', 'while', 'this', 'is', '65', 'percent', 'at', 'the', 'national', 'level', '<e>'] 8.997400294095481
#
# ['<s>', 'swelling', 'in', 'conjuctiva', 'of', 'the', 'eye', '<e>'] 4.1696940014353014
#
# ['<s>', 'this', 'is', 'not', 'just', 'a', 'treatment', 'method', 'but', 'a', 'life', 'style', 'according', 'to', 'the', 'internal', 'important', 'powers', 'or', 'natural', 'elements', 'present', 'in', 'the', 'human', 'body', '<e>'] 15.166599753794184
#
# ['<s>', 'there', 'can', 'also', 'be', 'complaint', 'of', 'nausea', 'along', 'with', 'pain', 'and', 'vomiting', '<e>'] 11.301954782404865
#
# ['<s>', 'there', 'should', 'be', 'less', 'amount', 'of', 'protein', 'nitrogen', 'and', 'sodium', 'in', 'diet', '<e>'] 19.605011695754886
#
# ['<s>', 'organ', 'donator', 'can', 'be', 'both', 'alive', 'or', 'dead', '<e>'] 5.011872336272723
#
# ['<s>', 'the', 'person', 'from', 'whose', 'excreta', 'the', 'cyst', 'comes', 'out', 'should', 'not', 'do', 'any', 'work', 'of', 'the', 'kitchen', 'until', 'blood', 'and', 'phlegm', 'has', 'stopped', 'coming', 'through', 'excreta', '<e>'] 13.903279081585435
#
# ['<s>', 'at', 'the', 'same', 'time', 'cent', 'percent', 'patients', 'can', 'be', 'ridden', 'from', 'the', 'disease', 'also', '<e>'] 7.411856333037042
#
# ['<s>', 'in', 'preliminary', 'stage', 'the', 'knot', 'is', 'painless', 'and', 'because', 'of', 'this', 'reason', 'we', 'commit', 'grave', 'mistake', '<e>'] 19.770103584560065
#
# ['<s>', 'if', 'pain', 'occurs', 'in', 'the', 'knot', 'of', 'skin', 'then', 'be', 'attentive', 'and', 'definitely', 'get', 'the', 'cancer', 'test', 'done', '<e>'] 18.26991872899898
#
# ['<s>', 'this', 'fact', 'has', 'only', 'come', 'forward', 'after', 'doing', 'survey', 'that', 'those', 'mothers', 'who', 'move', 'around', 'their', 'children', 'are', 'more', 'sensitive', 'towards', 'their', 'health', '<e>'] 8.40844813107144
#
# ['<s>', 'majority', 'of', 'women', 'feel', 'shy', 'hesitate', 'while', 'talking', 'to', 'their', 'doctor', 'about', 'their', 'uterus', 'and', 'reproductive', 'organs', '<e>'] 12.097156107347809
#
# ['<s>', 'three', 'year', 'old', 'rice', 'is', 'very', 'tasteful', 'and', 'that', 'which', 'produces', 'glow', '<e>'] 12.256081319274195
#
# ['<s>', 'the', 'secret', 'for', 'disease', 'free', 'healthy', 'and', 'long', 'life', 'is', 'nutritional', 'and', 'satvik', 'food', '<e>'] 6.4177427394247255
#
# ['<s>', 'the', 'meaning', 'of', 'healing', 'is', 'riddance', 'from', 'disease', 'and', 'the', 'meaning', 'of', 'healer', 'is', 'that', 'person', 'who', 'possesses', 'the', 'ability', 'to', 'cure', 'diseases', 'through', 'supernatural', 'power', '<e>'] 11.151528583040134
#
# ['<s>', 'reiki', 'is', 'a', 'heavenly', 'power', 'which', 'fills', 'the', 'hands', 'of', 'the', 'channel', 'with', 'life', '<e>'] 5.734232044934395
# ['<s>', 'reiki', 'guru', 'connects', 'the', 'student', 'with', 'the', 'universal', 'energy', 'force', 'through', 'the', 'attunement', 'and', 'his', 'life', 'gets', 'transformed', '<e>'] 7.0794578438413795
#
# ['<s>', 'some', 'people', 'take', 'energy', 'rich', 'food', 'to', 'maintain', 'health', '<e>'] 15.720471162799125
#
# ['<s>', 'if', 'gas', 'is', 'blocked', 'in', 'stomach', 'then', 'lightly', 'massage', 'the', 'stomach', 'and', 'foment', 'that', 'place', 'with', 'hot', 'water', 'bottle', 'or', 'by', 'lightly', 'warming', 'cotton', 'cloth', '<e>'] 8.672986748112882
#
# ['<s>', 'ginger', 'tea', 'gives', 'relief', 'in', 'cough', 'cold', '<e>'] 4.523869474562351
#
# ['<s>', 'the', 'wound', 'of', 'burns', 'gets', 'healed', 'by', 'raw', 'peel', 'of', 'potato', '<e>'] 11.4463410567741
#
# ['<s>', 'the', 'paste', 'of', 'hot', 'rice', 'works', 'on', 'the', 'theory', 'of', 'moist', 'heat', 'therapy', 'and', 'it', 'sucks', 'out', 'pain', 'and', 'stiffness', '<e>'] 13.175761002102071
#
# ['<s>', 'ice', 'cubes', 'reduce', 'fever', '<e>'] 3.162277660168379
#
# ['<s>', 'orifice', 'hernia', 'sac', 'and', 'the', 'substance', 'present', 'in', 'it', 'or', 'organs', '<e>'] 13.794347247887815
#
# ['<s>', 'one', 'main', 'cause', 'for', 'occurrence', 'of', 'mental', 'disorders', 'for', 'any', 'person', 'is', 'also', 'not', 'being', 'able', 'to', 'strike', 'a', 'proper', 'balance', 'with', 'his', 'surroundings', '<e>'] 24.3265979494702
#
# ['<s>', 'inguinal', 'hernia', 'this', 'is', 'a', 'swelling', 'connected', 'to', 'the', 'inguinal', 'canal', 'on', 'the', 'inner', 'walls', 'of', 'stomach', 'and', 'therefore', 'it', 'has', 'been', 'given', 'the', 'name', 'of', 'inguinal', 'hernia', '<e>'] 11.919768143304726
#
# ['<s>', 'if', 'the', 'size', 'of', 'this', 'type', 'of', 'hernia', 'is', 'small', 'that', 'is', 'less', 'than', 'half', 'inch', 'then', 'it', 'generally', 'gets', 'closed', 'on', 'its', 'own', 'by', 'the', 'time', 'the', 'child', 'reaches', 'the', 'age', 'of', 'two', 'years', '<e>'] 28.25812843602485
#
# ['<s>', 'he', 'gets', 'working', 'in', 'normal', 'way', 'after', 'just', 'two', 'three', 'days', 'of', 'surgery', 'and', 'within', '5', 'to', '7', 'days', 'he', 'gets', 'to', 'his', 'daily', 'works', '<e>'] 10.834425365289674
#
# ['<s>', 'surgeon', 'gets', 'helped', 'by', 'means', 'of', 'camera', 'in', 'seeing', 'hernia', 'and', 'the', 'adjoining', 'regions', 'on', 'the', 'video', 'screen', '<e>'] 9.971876901808155
#
# ['<s>', 'it', 'is', 'worth', 'mentioning', 'that', 'hernia', 'is', 'such', 'a', 'problem', 'which', 'does', 'not', 'get', 'cured', 'on', 'its', 'own', 'and', 'it', 'keeps', 'on', 'increasing', 'with', 'time', '<e>'] 21.534846951157952
#
# ['<s>', 'then', 'you', 'should', 'choose', 'four', 'tips', 'from', 'the', 'daily', 'food', 'column', 'and', 'the', 'alternative', 'to', 'burn', '500', 'calories', 'daily', 'from', 'the', 'exercise', '2', 'column', '<e>'] 12.250085740024772
#
# ['<s>', 'stop', 'taking', 'any', 'drink', 'which', 'increases', 'calorie', 'like', 'cola', 'alcohol', '<e>'] 5.62341325190349
#
# ['<s>', 'in', 'place', 'of', 'biryani', 'fried', 'rice', 'pulao', 'try', 'eating', 'lemon', 'rice', 'or', 'eat', 'rice', 'cooked', 'in', 'tomato', 'juice', '<e>'] 8.840932537202292
#
# ['<s>', 'walk', '30', 'minutes', 'in', 'morning', '15', 'minutes', 'after', 'lunch', 'and', '30', 'minutes', 'in', 'the', 'evening', '<e>'] 14.735720612339085
#
# ['<s>', 'this', 'is', 'that', 'condition', 'of', 'patient', 'when', 'the', 'insulin', 'is', 'secreted', 'less', 'or', 'not', 'secreted', 'at', 'all', 'because', 'the', 'immune', 'system', 'attacks', 'the', 'cells', 'of', 'pancreas', '<e>'] 10.556305057993622
#
# ['<s>', 'generally', 'school', 'going', 'girls', 'and', 'working', 'women', 'are', 'more', 'prone', 'to', 'this', '<e>'] 6.105402296585328
#
# ['<s>', 'headache', 'is', 'indeed', 'a', 'very', 'common', 'problem', '<e>'] 8.305380238677724
#
# ['<s>', 'hormonal', 'change', '<e>'] 1.7782794100389228
#
# ['<s>', 'many', 'people', 'may', 'have', 'problem', 'with', 'strong', 'sunlight', 'heat', 'or', 'cold', '<e>'] 8.548397484638551
#
# ['<s>', 'onset', 'of', 'nausea', 'and', 'vomiting', 'with', 'intense', 'headache', '<e>'] 4.1126118445987645
#
# ['<s>', 'and', 'the', 'remaining', 'half', 'is', 'in', 'tissues', 'and', 'organ', 'cells', '<e>'] 5.62341325190349
#
# ['<s>', 'unhygienic', 'life', 'style', '<e>'] 2.51188643150958
#
# ['<s>', 'gastroenteritis', 'is', 'a', 'serious', 'disease', 'for', 'those', 'who', 'can', 'not', 'digest', 'anything', '<e>'] 10.092954664714266
#
# ['<s>', 'if', 'seen', 'from', 'the', 'point', 'of', 'view', 'of', 'calorie', 'then', 'in', 'approximately', '100', 'gram', 'salad', 'leaves', 'there', 'are', '21', 'calories', '<e>'] 6.931955807838064
#
# ['<s>', 'the', 'greener', 'the', 'salad', 'leaves', 'the', 'more', 'would', 'be', 'the', 'quantity', 'of', 'vitamin', 'c', 'in', 'them', '<e>'] 21.31956273030802
#
# ['<s>', 'salad', 'leaves', 'are', 'very', 'good', 'for', 'brain', 'nervous', 'system', 'and', 'lungs', '<e>'] 13.655249216831146
#
# ['<s>', 'french', 'beans', 'is', 'also', 'very', 'beneficial', 'in', 'diseases', 'related', 'to', 'kidney', '<e>'] 14.962503000049132
#
# ['<s>', 'the', 'yellowish', 'green', 'oil', 'obtained', 'from', 'the', 'fresh', 'leaves', 'is', 'aromatic', 'and', 'bitter', 'in', 'taste', '<e>'] 8.30912281070863
#
# ['<s>', 'corn', 'keeps', 'control', 'of', 'the', 'urinary', 'system', 'keeps', 'the', 'teeth', 'strong', 'and', 'is', 'also', 'beneficial', 'in', 'heart', 'disease', 'when', 'taken', 'in', 'the', 'form', 'of', 'cornflakes', '<e>'] 8.144798927179393
#
# ['<s>', 'through', 'the', 'creative', 'capacity', 'or', 'the', 'assistance', 'of', 'the', 'brain', 'itself', 'einstein', 'c', 'v', 'raman', 'tagore', 'and', 'shakespeare', 'could', 'produce', 'their', 'extreme', 'original', 'and', 'unique', 'ideas', '<e>'] 8.544650374636088
#
# ['<s>', 'this', 'way', 'the', 'signals', 'can', 'be', 'sequenced', 'with', 'respect', 'to', 'time', '<e>'] 15.266893485091503
#
# ['<s>', 'from', 'the', 'point', 'of', 'view', 'of', 'creation', 'we', 'can', 'divide', 'the', 'brain', 'into', 'many', 'parts', '<e>'] 3.311903795298501
#
# ['<s>', 'a', 'sudden', 'jerk', 'or', 'injury', 'on', 'the', 'medulla', 'can', 'therefore', 'lead', 'to', 'death', 'in', 'a', 'moment', '<e>'] 7.4370249728321225
#
# ['<s>', 'we', 'do', 'not', 'fall', 'even', 'when', 'fleeing', 'running', 'doing', 'acrobats', 'bending', 'forward', 'backward', '<e>'] 7.147536155681587
#
# ['<s>', 'from', 'the', 'unconscious', 'state', 'we', 'have', 'come', 'to', 'the', 'conscious', 'state', '<e>'] 5.083503229637883
#
# ['<s>', 'only', 'the', 'electric', 'impulses', 'are', 'reaching', 'there', 'through', 'the', 'nerves', '<e>'] 9.77787008780974
#
# ['<s>', 'why', 'not', 'we', 'study', 'a', 'small', 'model', 'of', 'brain', 'before', 'understanding', 'an', 'incredible', 'computer', 'like', 'the', 'human', 'brain', '<e>'] 6.593511177719633
#
# ['<s>', 'both', 'the', 'hemispheres', 'of', 'cerebrum', 'continued', 'fulfilling', 'their', 'responsibility', 'by', 'controlling', 'the', 'respective', 'halves', 'of', 'the', 'body', '<e>'] 8.466183465657744
#
# ['<s>', 'whatever', 'we', 'study', 'in', 'class', 'generally', 'gets', 'accumulated', 'in', 'the', 'right', 'or', 'left', 'hemisphere', 'according', 'to', 'this', 'area', 'division', '<e>'] 10.238598661028163
#
# ['<s>', 'with', 'how', 'much', 'vigor', 'and', 'hard', 'work', 'scientists', 'are', 'engrossed', 'in', 'studying', 'our', 'brain', 'and', 'how', 'thrilling', 'are', 'their', 'experiments', '<e>'] 9.469337953180442
#
# ['<s>', 'the', 'homeopathic', 'doctor', 'minu', 'mehta', 'says', 'that', 'women', 'should', 'get', 'hyper', 'plasia', 'test', 'done', 'right', 'after', 'the', 'age', 'of', '30', 'years', '<e>'] 5.82917502800419
#
# ['<s>', 'breast', 'cancer', 'is', 'engulfing', 'indian', 'women', 'very', 'fast', '<e>'] 8.638132266889878
#
# ['<s>', 'not', 'just', 'this', 'together', 'with', 'this', 'one', 'should', 'also', 'do', 'bsf', 'or', 'breast', 'self', 'exam', '<e>'] 15.49274826949858
#
# ['<s>', 'in', 'fsh', 'test', 'one', 'can', 'be', 'saved', 'from', 'the', 'diseases', 'happening', 'at', 'the', 'time', 'of', 'or', 'after', 'menopause', '<e>'] 12.808811464016093
#
# ['<s>', 'if', 'any', 'kind', 'of', 'unusual', 'change', 'is', 'happening', 'in', 'these', 'then', 'it', 'can', 'be', 'known', 'through', 'pelvic', 'exam', 'test', '<e>'] 23.64119327949899
# ['<s>', 'if', 'you', 'are', 'less', 'than', '45', 'years', 'and', 'you', 'smoke', 'then', 'you', 'take', 'the', 'advice', 'of', 'your', 'doctor', 'regarding', 'this', 'as', 'to', 'when', 'you', 'should', 'get', 'your', 'cholesterol', 'test', 'done', '<e>'] 15.96749045788383
#
# ['<s>', 'flexible', 'sigmoendoscopy', 'must', 'be', 'done', 'once', 'every', 'five', 'years', '<e>'] 11.438497024646031
#
# ['<s>', 'a', 'glass', 'vessel', 'full', 'of', 'blood', 'in', 'which', 'oxygen', 'is', 'released', 'in', 'the', 'form', 'of', 'bubbles', '<e>'] 8.802644854620093
#
# ['<s>', 'the', 'heart', 'can', 'not', 'take', 'nutrients', 'from', 'the', 'blood', 'filled', 'in', 'its', 'chambers', '<e>'] 11.277909571645822
#
# ['<s>', 'coronary', 'arteries', 'distribute', 'oxygen', 'and', 'nutrients', 'to', 'the', 'heart', '<e>'] 4.838990630135111
#
# ['<s>', 'the', 'meaning', 'of', 'coronary', 'is', 'coronation', 'and', 'these', 'arteries', 'are', 'spread', 'like', 'a', 'crown', 'on', 'the', 'heart', '<e>'] 5.860887723736686
#
# ['<s>', 'whether', 'there', 'is', 'kidney', 'or', 'not', 'if', 'there', 'then', 'whether', 'it', 'is', 'working', 'properly', 'or', 'not', 'or', 'if', 'there', 'is', 'any', 'type', 'of', 'cyst', 'stone', 'swelling', 'pus', 'this', 'also', 'is', 'told', 'to', 'us', 'by', 'the', 'ultrasound', 'test', '<e>'] 10.037888526901375
#
# ['<s>', 'the', 'extent', 'to', 'which', 'ultrasonography', 'is', 'useful', 'in', 'the', 'test', 'of', 'foetus', 'in', 'the', 'womb', 'is', 'not', 'anywhere', '<e>'] 15.346104783867085
#
# ['<s>', 'the', 'time', 'required', 'in', 'the', 'lithoptysis', 'technique', 'depends', 'on', 'the', 'size', 'of', 'the', 'stone', 'and', 'its', 'number', '<e>'] 27.661157171823884
#
# ['<s>', 'generally', 'this', 'is', 'done', 'in', 'one', 'episode', '<e>'] 9.261729224949661
#
# ['<s>', 'as', 'an', 'exception', 'one', 'may', 'have', 'to', 'be', 'put', 'under', 'vigilance', 'for', '24', 'hours', '<e>'] 10.044757775772203
#
# ['<s>', 'do', 'not', 'consume', 'tea', 'coffee', 'carbonated', 'drinking', 'substances', 'or', 'it', 'should', 'be', 'done', 'in', 'as', 'much', 'less', 'quantity', 'as', 'possible', 'along', 'with', 'it', '<e>'] 7.373652746618115
#
# ['<s>', 'if', 'these', 'increases', 'the', 'will', 'power', 'in', 'patients', 'then', 'also', 'relief', 'may', 'be', 'got', 'from', 'the', 'problems', '<e>'] 16.997658564838645
#
# ['<s>', 'if', 'a', 'tumor', 'persists', 'for', 'years', 'then', 'in', 'the', 'situation', 'of', 'the', 'growth', 'of', 'the', 'tumor', 'getting', 'tested', 'is', 'a', 'must', '<e>'] 10.627023529985435
#
# ['<s>', 'the', 'patients', 'who', 'have', 'already', 'got', 'the', 'rotating', 'platform', 'high', 'flexion', 'knee', 'transplant', 'today', 'experience', 'much', 'more', 'satisfaction', 'and', 'they', 'can', 'finish', 'their', 'daily', 'activity', 'in', 'a', 'much', 'better', 'way', '<e>'] 8.58994414062832
#
# ['<s>', 'since', 'naltrekson', 'is', 'intoxication', 'preventive', 'in', 'the', 'purest', 'form', 'therefore', 'till', 'the', 'time', 'it', 'is', 'there', 'in', 'the', 'body', 'no', 'type', 'of', 'excitement', 'would', 'be', 'felt', 'by', 'him', 'on', 'doing', 'any', 'type', 'of', 'intoxication', '<e>'] 25.052490974175015
#
# ['<s>', 'one', 'can', 'get', 'harmed', 'by', 'the', 'consumption', 'of', 'any', 'intoxicating', 'item', 'be', 'it', 'alcohol', 'or', 'smack', 'or', 'any', 'other', 'intoxicating', 'item', 'with', 'naltrekson', 'implant', '<e>'] 12.69201558550583
#
# ['<s>', 'in', 'the', 'extreme', 'case', 'of', 'bacterial', 'dysentery', 'there', 'is', 'repeated', 'tendency', 'of', 'releasing', 'fecus', 'in', 'the', 'patient', 'but', 'each', 'time', 'very', 'less', 'fecus', 'is', 'discharged', '<e>'] 9.993157541041203
#
# ['<s>', 'do', 'not', 'take', 'the', 'child', 'to', 'a', 'place', 'where', 'other', 'children', 'are', 'sick', '<e>'] 11.469163752671308
#
# ['<s>', 'unbalanced', 'diet', 'not', 'just', 'stops', 'the', 'continuous', 'growth', 'of', 'hair', 'but', 'it', 'also', 'makes', 'bald', 'very', 'fast', '<e>'] 9.711452919413457
#
# ['<s>', 'normally', 'the', 'main', 'symptom', 'of', 'obesity', 'is', 'that', 'the', 'height', 'of', 'the', 'body', 'should', 'be', 'in', 'proportion', 'to', 'the', 'weight', 'of', 'the', 'body', '<e>'] 10.297249085203974
#
# ['<s>', 'cholesterol', 'fat', 'accumulates', 'in', 'the', 'blood', 'carrying', 'vessels', 'as', 'a', 'result', 'of', 'which', 'diseases', 'like', 'high', 'blood', 'pressure', 'indigestion', 'heart', 'disease', 'and', 'diabetes', 'occur', '<e>'] 10.39913885702393
#
# ['<s>', 'at', 'present', 'as', 'the', 'consciousness', 'of', 'people', 'are', 'increasing', 'towards', 'healthy', 'life', 'and', 'pure', 'and', 'plain', 'healthy', 'diet', 'and', 'exercise', 'people', 'are', 'becoming', 'aware', 'of', 'the', 'dangers', 'owing', 'to', 'increase', 'in', 'weight', 'and', 'obesity', '<e>'] 23.227070248858535
#
# ['<s>', 'positive', 'results', 'of', 'reducing', 'obesity', 'come', 'forward', '<e>'] 4.641588833612778
#
# ['<s>', 'dry', 'cough', 'starts', 'coming', 'and', 'there', 'is', 'difficulty', 'in', 'breathing', '<e>'] 4.758005096016654
#
# ['<s>', 'the', 'infected', 'person', 'gets', 'fever', 'of', '104', 'degree', 'fahrenheit', 'or', 'more', 'and', 'he', 'also', 'feels', 'cold', 'with', 'this', '<e>'] 11.074414347473557
#
# ['<s>', 'in', 'the', 'whole', 'world', 'there', 'is', 'a', 'situation', 'of', 'illusion', 'regarding', 'the', 'patients', 'and', 'the', 'symptoms', 'of', 'sars', '<e>'] 16.472235476257797
#
# ['<s>', 'the', 'nature', 'protects', 'us', 'by', 'other', 'means', 'as', 'well', '<e>'] 5.3366992312063095
#
# ['<s>', 'their', 'diagnosis', 'is', 'possible', 'by', 'stool', 'examination', '<e>'] 4.641588833612778
#
# ['<s>', 'the', 'water', 'in', 'rural', 'areas', 'is', 'generally', 'available', 'from', 'these', 'sources', 'only', '<e>'] 6.884017143200176
#
# ['<s>', 'the', 'worm', 'generally', 'produces', 'a', 'wart', 'in', 'that', 'part', 'of', 'the', 'body', 'which', 'often', 'comes', 'in', 'contact', 'with', 'water', '<e>'] 9.914664199280296
#
# ['<s>', 'by', 'affecting', 'the', 'pancreas', 'and', 'nervous', 'system', 'malaria', 'becomes', 'the', 'reason', 'of', 'loss', 'of', 'consciousness', 'and', 'at', 'times', 'death', '<e>'] 12.55990414967233
#
# ['<s>', 'for', 'the', 'ascertainment', 'of', 'the', 'suitability', 'of', 'fluoride', 'rich', 'drinks', 'the', 'role', 'of', 'fluoride', 'is', 'also', 'very', 'important', '<e>'] 6.131495390866748
#
# ['<s>', 'the', 'pulse', 'polio', 'program', 'will', 'continue', 'for', 'three', 'more', 'years', 'now', '<e>'] 6.69940510457629
#
# ['<s>', 'this', 'is', 'the', 'reason', 'that', 'the', 'infant', 'mortality', 'rate', 'is', 'very', 'high', 'in', 'india', '<e>'] 11.829343333634972
#
# ['<s>', 'the', 'patient', 'may', 'even', 'die', 'if', 'the', 'treatment', 'is', 'not', 'done', 'immediately', 'because', 'by', 'this', 'the', 'fever', 'rises', 'up', 'to', '106', 'degree', 'fahrenheit', '<e>'] 11.272151220703904
#
# ['<s>', 'there', 'is', 'no', 'permanent', 'solution', 'to', 'malaria', 'and', 'neither', 'have', 'the', 'doctors', 'of', 'the', 'world', 'discovered', 'its', 'any', 'inoculation', '<e>'] 7.728067806443591
#
# ['<s>', 'patients', 'of', 'high', 'blood', 'pressure', 'should', 'consume', 'fibrous', 'eatables', 'and', 'green', 'vegetables', 'more', 'in', 'their', 'food', '<e>'] 6.395909601592506
#
# ['<s>', 'in', 't', 'u', 'r', 'p', 'method', 'telescope', 'stays', 'attached', 'to', 'a', 'video', 'system', '<e>'] 4.974577557209428
#
# ['<s>', 'in', 'such', 'a', 'situation', 'the', 'part', 'of', 'place', 'of', 'surgery', 'becomes', 'stiff', 'like', 'stone', '<e>'] 10.23537402844315
#
# ['<s>', 'increasing', 'havoc', 'of', 'asthma', 'in', 'childhood', '<e>'] 8.64547090776486
#
# ['<s>', 'environment', 'of', 'cities', 'is', 'more', 'polluted', '<e>'] 4.216965034285822
#
# ['<s>', 'after', 'this', 'gradually', 'start', 'giving', 'fruit', 'vegetables', 'first', 'and', 'then', 'grains', '<e>'] 5.878016072274913
#
# ['<s>', 'in', 'case', 'of', 'children', 'getting', 'asthma', 'the', 'disease', 'can', 'be', 'controlled', 'by', 'maintaining', 'caution', 'and', 'by', 'giving', 'appropriate', 'treatment', '<e>'] 13.494219129141925
#
# ['<s>', 'on', 'getting', 'hepatitis', 'b', 'it', 'should', 'be', 'shown', 'to', 'a', 'gastroenterologist', 'immediately', '<e>'] 10.019195069074803
# ['<s>', 'take', 'milk', 'and', 'fresh', 'curd', 'not', 'sour', 'curd', '<e>'] 5.011872336272723
#
# ['<s>', 'spine', 'happens', 'to', 'be', 'the', 'base', 'of', 'the', 'whole', 'body', 'and', 'rest', 'of', 'the', 'bones', 'are', 'joined', 'to', 'each', 'other', 'like', 'the', 'ends', 'of', 'a', 'staff', '<e>'] 24.75587537703017
#
# ['<s>', 'if', 'it', 'is', 'the', 'case', 'of', 'it', "'s", 'treatment', 'then', 'several', 'kinds', 'of', 'treatments', 'are', 'also', 'present', '<e>'] 23.711544901616406
#
# ['<s>', 'the', 'main', 'advantage', 'of', 'vat', 'is', 'that', 'patient', 'can', 'start', 'walking', 'around', 'from', 'next', 'day', 'there', 'is', 'no', 'risk', 'of', 'bleeding', 'or', 'infection', 'and', 'patient', 'gets', 'a', 'discharge', 'from', 'the', 'hospital', 'in', '3', 'days', '<e>'] 20.485495743833752
#
# ['<s>', 'drink', 'a', 'lot', 'of', 'water', 'and', 'do', 'not', 'use', 'much', 'chillies', 'and', 'spices', '<e>'] 15.478786680743232
#
# ['<s>', 'during', 'sports', 'jogging', 'tennis', 'and', 'skiing', 'there', 'is', 'more', 'activity', '<e>'] 5.62341325190349
#
# ['<s>', 'interstitial', 'cystitis', 'is', 'an', 'agonizing', 'disease', 'for', 'women', '<e>'] 5.655069876389966
#
# ['<s>', 'treasure', 'of', 'health', '<e>'] 2.51188643150958
#
# ['<s>', 'bring', 'in', 'use', 'low', 'fat', 'products', 'of', 'dairy', 'products', 'like', 'cheese', 'cottage', 'cheese', 'milk', 'and', 'cream', '<e>'] 8.000205577708941
#
# ['<s>', 'exercise', 'everyday', 'for', '20', 'to', '30', 'minutes', '<e>'] 7.284867962058955
#
# ['<s>', 'congenital', 'heart', 'disease', 'is', 'one', 'such', 'grotesque', 'state', 'which', 'is', 'a', 'disease', 'as', 'well', 'as', 'a', 'bane', '<e>'] 15.52379301002387
#
# ['<s>', 'for', 'its', 'prevention', 'mothers', 'during', 'pregnancy', 'should', 'consider', 'it', 'beneficial', 'to', 'avoid', 'diseases', 'like', 'measles', 'and', 'strong', 'toxic', 'medicines', '<e>'] 10.993525804724133
#
# ['<s>', 'through', 'surgery', 'many', 'babies', 'have', 'received', 'a', 'new', 'life', '<e>'] 4.974830278315674
#
# ['<s>', 'habit', 'of', 'physical', 'exercise', 'is', 'the', 'best', 'cure', 'for', 'escape', 'from', 'heart', 'disease', '<e>'] 17.195822780061473
#
# ['<s>', 'due', 'to', 's', 'u', 'i', 'fear', 'of', 'constant', 'wetness', 'and', 'the', 'stink', 'arising', 'out', 'of', 'it', 'makes', 'them', 'conscious', 'of', 'the', 'huge', 'inconvenience', '<e>'] 13.32184501804056
#
# ['<s>', 'the', 'company', 'that', 'makes', 't', 'v', 't', 'determines', 'its', 'high', 'quality', '<e>'] 5.878016072274913
#
# ['<s>', 'in', 'dysentery', 'the', 'apprehension', 'of', 'having', 'to', 'go', 'to', 'the', 'toilet', 'again', 'and', 'again', 'is', 'always', 'there', '<e>'] 7.84098089256678
#
# ['<s>', 'in', 'youth', 'patient', 'gets', 'pimples', 'on', 'his', 'face', '<e>'] 5.74187059966276
#
# ['<s>', 'small', 'but', 'very', 'useful', 'home', 'remedies', '<e>'] 4.216965034285822
#
# ['<s>', 'in', 'disease', 'of', 'pyria', 'by', 'applying', 'everyday', '22', 'grams', 'of', 'lemon', 'juice', '110', 'grams', 'of', 'sesame', 'oil', 'and', 'a', 'little', 'rock', 'salt', 'mixed', 'together', 'disease', 'gets', 'destroyed', '<e>'] 19.102196938933567
#
# ['<s>', 'specialists', 'also', 'treat', 'it', 'with', 'artificial', 'light', '<e>'] 4.641588833612778
#
# ['<s>', 'if', 'there', 'comes', 'an', 'obstruction', 'in', 'the', 'bile', 'duct', 'that', 'makes', 'bilirubin', 'reach', 'the', 'intestine', 'from', 'the', 'liver', 'then', 'this', 'substance', 'does', 'not', 'reach', 'the', 'intestine', '<e>'] 13.514684264561437
#
# ['<s>', 'consequently', 'the', 'amount', 'of', 'bilirubin', 'in', 'blood', 'increases', 'which', 'gets', 'accumulated', 'in', 'body', 'parts', 'like', 'eyes', 'skin', 'and', 'nails', 'etc', 'this', 'way', 'these', 'body', 'parts', 'start', 'looking', 'yellow', 'and', 'weakness', 'in', 'body', 'increases', '<e>'] 21.06291159989631
#
# ['<s>', 'for', 'treatment', 'of', 'itching', 'it', 'is', 'necessary', 'to', 'bathe', 'in', 'a', 'proper', 'way', 'with', 'a', 'neem', 'soap', 'before', 'applying', 'medicine', '<e>'] 10.62846710649517
#
# ['<s>', 'bathe', 'for', 'two', 'days', 'in', 'this', 'way', '<e>'] 7.062651916702338
#
# ['<s>', 'suddenly', 'dizziness', 'coming', 'over', '<e>'] 3.162277660168379
#
# ['<s>', 'knee', 'is', 'the', 'biggest', 'and', 'the', 'most', 'complex', 'joint', 'of', 'the', 'body', '<e>'] 8.315409959690106
#
# ['<s>', 'if', 'there', 'is', 'wear', 'and', 'tear', 'in', 'the', 'bones', 'there', 'is', 'some', 'infection', 'or', 'there', 'is', 'a', 'tumor', 'then', 'it', 'should', 'be', 'treated', 'through', 'an', 'orthopaedic', 'surgeon', '<e>'] 13.536823875510612
#
# ['<s>', 'blood', 'pressure', 'and', 'hypertension', 'are', 'reduced', 'by', 'laughter', '<e>'] 5.544219546009097
#
# ['<s>', 'a', 'good', 'alternative', 'for', 'heart', 'related', 'exercise', 'is', 'laughter', '<e>'] 10.818607209334358
#
# ['<s>', 'laughter', 'reduces', 'the', 'secretion', 'of', 'the', 'hormone', 'increasing', 'tension', '<e>'] 5.485572756797091
#
# ['<s>', 'decrease', 'of', 'appetite', 'peptic', 'ulcer', 'loss', 'of', 'immunity', 'capacity', 'of', 'the', 'body', 'extreme', 'pain', 'anywhere', 'continuous', 'cold', 'and', 'flu', 'also', 'are', 'the', 'common', 'problems', 'of', 'tension', '<e>'] 8.587462023109115
#
# ['<s>', 'for', 'becoming', 'tension', 'free', 'discussion', 'may', 'be', 'done', 'with', 'any', 'counsellor', 'but', 'money', 'is', 'spent', 'in', 'that', '<e>'] 18.781614109139227
#
# ['<s>', 'if', 'the', 'diet', 'is', 'good', 'then', 'the', 'tension', 'would', 'stay', 'less', 'but', 'if', 'there', 'is', 'even', 'slight', 'problem', 'in', 'the', 'food', 'then', 'it', 'may', 'increase', 'the', 'disease', '<e>'] 24.47912963697567
#
# ['<s>', 'what', 'should', 'be', 'eaten', 'during', 'tension', '<e>'] 3.4241825060595983
#
# ['<s>', 'at', 'the', 'time', 'of', 'tension', 'the', 'quantity', 'of', 'vitamin', 'mineral', 'vitamin', 'b', 'complex', 'zinc', 'serenium', 'should', 'be', 'increased', '<e>'] 10.217434418785812
#
# ['<s>', 'by', 'getting', 'vitamin', 'a', 'in', 'huge', 'quantity', 'blindness', 'occurring', 'due', 'to', 'lack', 'of', 'nutrition', 'can', 'be', 'prevented', '<e>'] 8.981267981144645
#
# ['<s>', 'these', 'diseases', 'are', 'pneumonia', 'onset', 'of', 'dysentery', 'and', 'dry', 'eye', 'discharge', 'xerophthalmia', '<e>'] 12.927403334660486
#
# ['<s>', 'xerophthalmia', 'occurs', 'due', 'to', 'the', 'error', 'in', 'transmission', 'of', 'the', 'absorbed', 'retinol', 'to', 'the', 'right', 'place', 'in', 'the', 'body', 'and', 'the', 'fast', 'depletion', 'of', 'the', 'accumulated', 'vitamin', 'in', 'the', 'body', '<e>'] 12.159862049241752
#
# ['<s>', 'the', 'absorption', 'of', 'vitamin', 'a', 'in', 'the', 'children', 'victims', 'of', 'dysentery', 'respiration', 'related', 'infections', 'measles', 'diseases', 'of', 'stomach', 'and', 'intestines', 'decreases', 'and', 'its', 'need', 'to', 'the', 'body', 'increases', '<e>'] 7.447954268550139
#
# ['<s>', 'now', 'by', 'giving', 'an', 'extension', 'to', 'this', 'program', 'children', 'of', '6', '11', 'months', 'are', 'also', 'being', 'included', '<e>'] 9.117720634530675
#
# ['<s>', 'one', 'to', 'four', 'weeks', 'after', 'this', 'second', 'dose', 'of', '2', '00', '000', 'i', 'u', 'of', 'vitamin', 'a', 'should', 'be', 'given', '<e>'] 10.331302584968155
#
# ['<s>', 'comprehensive', 'immunity', 'inoculation', 'program', 'provides', 'an', 'opportunity', 'of', 'coming', 'in', 'contact', 'with', 'the', 'newborn', 'babies', '<e>'] 6.944521059800954
#
# ['<s>', 'the', 'amount', 'of', 'vitamin', 'a', 'and', 'carotene', 'in', 'the', 'diet', 'of', 'children', 'have', 'been', 'found', 'less', 'than', 'half', 'of', 'the', 'daily', 'proposed', 'quantity', 'of', '400', 'gram', 'retinol', 'or', '1600', 'microgram', 'of', 'beta', 'carotene', '<e>'] 10.657429706738185
#
# ['<s>', 'along', 'with', 'the', 'other', 'food', 'items', 'a', 'child', 'can', 'eat', 'this', 'much', 'of', 'vegetable', 'easily', '<e>'] 12.717605070066616
#
# ['<s>', 'nutrition', 'education', 'is', 'an', 'integral', 'part', 'of', 'primary', 'health', 'services', 'and', 'icds', 'program', 'and', 'under', 'this', 'emphasis', 'must', 'be', 'given', 'on', 'the', 'encouragement', 'of', 'the', 'use', 'of', 'food', 'items', 'highly', 'rich', 'in', 'vitamin', 'a', '<e>'] 17.361628886430378
# ['<s>', 'the', 'workers', 'of', 'both', 'the', 'areas', 'will', 'be', 'benefitted', 'by', 'this', 'in', 'playing', 'their', 'responsibility', 'in', 'the', 'implementation', 'of', 'the', 'program', 'in', 'effective', 'manner', '<e>'] 14.706551338754771
#
# ['<s>', 'under', 'the', 'first', 'principle', 'the', 'arrangement', 'of', 'administering', 'heavy', 'dose', 'to', 'children', 'between', 'the', 'age', 'of', '6', 'months', 'and', '5', 'years', 'has', 'been', 'done', '<e>'] 15.886363956460599
#
# ['<s>', 'apart', 'from', 'this', 'the', 'organisms', 'like', 'e', 'coli', 'and', 'pseudomonas', 'have', 'also', 'been', 'found', 'because', 'of', 'whose', 'infection', 'the', 'ill', 'effect', 'on', 'the', 'body', 'is', 'maximum', '<e>'] 8.128338296771533
#
# ['<s>', 'but', 'after', 'the', 'untiring', 'efforts', 'of', 'hundreds', 'of', 'researchers', 'success', 'has', 'been', 'achieved', 'in', 'the', 'preparation', 'of', 'one', 'more', 'vaccine', '<e>'] 6.431819398058965
#
# ['<s>', 'though', 'this', 'medicine', 'can', 'not', 'be', 'administered', 'to', 'children', 'who', 'are', 'less', 'than', 'one', 'year', 'of', 'age', '<e>'] 7.782878669403489
#
# ['<s>', 'get', 'your', 'breasts', 'checked', 'up', 'once', 'in', 'a', 'month', '<e>'] 9.181236825843225
#
# ['<s>', 'the', 'children', 'should', 'be', 'given', 'such', 'snacks', 'in', 'which', 'there', 'is', 'no', 'excessive', 'sugar', 'and', 'they', 'are', 'non', 'sticky', '<e>'] 8.60083528190295
#
# ['<s>', 'try', 'that', 'the', 'children', 'should', 'do', 'the', 'brushing', 'with', 'their', 'own', 'hands', '<e>'] 12.87430018157199
#
# ['<s>', 'if', 'care', 'lessens', 'has', 'not', 'been', 'shown', 'in', 'the', 'cleanliness', 'of', 'the', 'teeth', 'then', 'there', 'is', 'no', 'need', 'to', 'worry', '<e>'] 9.324644047220653
#
# ['<s>', 'keep', 'the', 'bristles', 'at', 'the', 'angle', 'of', '45', 'degree', 'angle', 'on', 'the', 'teeth', '<e>'] 9.626434914788401
#
# ['<s>', 'the', 'eyesight', 'becomes', 'weak', 'on', 'the', 'removal', 'of', 'the', 'upper', 'tooth', 'this', 'myth', 'is', 'totally', 'false', '<e>'] 10.891243842050013
#
# ['<s>', 'there', 'is', 'plenty', 'of', 'calcium', 'in', 'dairy', 'products', 'like', 'milk', 'cheese', 'and', 'curd', 'which', 'make', 'the', 'teeth', 'strong', 'and', 'healthy', '<e>'] 11.71016711356884
#
# ['<s>', 'the', 'nervous', 'system', 'weakens', 'due', 'to', 'insecticides', '<e>'] 9.823068779975884
#
# ['<s>', 'the', 'right', 'quantity', 'of', 'fluoride', 'in', 'water', 'makes', 'the', 'teeth', 'and', 'bones', 'strong', '<e>'] 18.07204623602346
#
# ['<s>', 'child', 'not', 'eating', 'the', 'food', 'is', 'a', 'common', 'problem', 'of', 'all', 'mothers', 'fathers', '<e>'] 9.84546782898336
#
# ['<s>', 'bedwetting', 'this', 'problem', 'is', 'considered', 'to', 'be', 'normal', 'up', 'to', 'the', 'age', 'of', 'four', 'or', 'five', 'years', 'but', 'if', 'children', 'more', 'than', 'this', 'age', 'do', 'it', 'then', 'there', 'is', 'also', 'a', 'treatment', 'for', 'them', '<e>'] 17.435199278052362
#
# ['<s>', 'this', 'mosquito', 'of', 'malaria', 'affects', 'the', 'red', 'blood', 'corpuscles', '<e>'] 5.709798104245377
#
# ['<s>', 'the', 'vaccine', 'of', 'hepatitis', 'a', 'protects', 'the', 'child', 'from', 'jaundice', 'and', 'contagious', 'diseases', 'of', 'the', 'liver', '<e>'] 5.181732215228143
#
# ['<s>', 'the', 'vaccine', 'of', 'hepatitis', 'a', 'is', 'pit', 'three', 'times', '<e>'] 4.900348305132474
#
# ['<s>', 'in', 'order', 'to', 'get', 'relief', 'in', 'gas', 'give', 'fried', 'asafoetida', 'and', 'black', 'salt', 'and', 'carom', 'seed', 'with', 'luke', 'warm', 'water', '<e>'] 8.287777618091628
#
# ['<s>', 'if', 'there', 'is', 'no', 'balance', 'in', 'the', 'diet', 'of', 'children', 'then', 'it', 'does', 'not', 'take', 'long', 'for', 'then', 'to', 'fall', 'ill', '<e>'] 9.32104777415716
#
# ['<s>', 'and', 'also', 'maximum', 'children', 'escape', 'from', 'eating', 'food', 'or', 'they', 'like', 'such', 'food', 'in', 'which', 'there', 'is', 'less', 'nutrition', '<e>'] 9.547479317621283
#
# ['<s>', 'this', 'is', 'such', 'time', 'when', 'they', 'are', 'growing', 'up', 'fast', '<e>'] 41.27266641819207
#
# ['<s>', 'with', 'regular', 'check', 'up', 'one', 'can', 'know', 'of', 'the', 'growth', 'and', 'weight', 'of', 'the', 'children', '<e>'] 9.656392883774846
#
# ['<s>', 'saturated', 'fat', 'and', 'unsaturated', 'fat', '<e>'] 4.949829014481331
#
# ['<s>', 'from', 'birth', 'to', 'three', 'years', 'of', 'age', 'around', '1000', 'calories', '<e>'] 3.604552287848655
#
# ['<s>', 'for', 'at', 'least', '6', 'months', 'the', 'mother', 'should', 'breastfeed', 'her', 'child', '<e>'] 9.860534088006569
#
# ['<s>', 'however', 'from', 'the', 'third', 'or', 'fourth', 'day', 'of', 'his', 'birth', 'he', 'should', 'not', 'be', 'put', 'to', 'the', 'habit', 'of', 'being', 'fed', 'the', 'milk', 'several', 'times', 'at', 'the', 'interval', 'of', 'every', 'two', 'hours', '<e>'] 12.062893907553212
#
# ['<s>', 'in', 'the', 'seventh', 'month', 'every', 'month', 'in', 'the', 'year', 'do', 'consult', 'the', 'doctor', 'so', 'that', 'in', 'the', 'upbringing', 'of', 'the', 'ones', 'child', 'there', 'is', 'no', 'lack', 'mother', '<e>'] 12.483174719164357
#
# ['<s>', 'do', 'not', 'put', 'oil', 'in', 'ear', 'and', 'nose', '<e>'] 7.2472078294876345
#
# ['<s>', 'in', 'such', 'patients', 'tourniquet', 'test', 'is', 'positive', 'and', 'on', 'getting', 'the', 'blood', 'tested', 'the', 'platelet', 'count', 'is', 'found', 'to', 'be', 'less', 'that', 'one', 'lakh', '<e>'] 13.78275592193368
#
# ['<s>', 'so', 'that', 'according', 'to', 'the', 'premenopausal', 'condition', 'and', 'fertility', 'they', 'can', 'give', 'you', 'the', 'right', 'direction', '<e>'] 11.222452605640385
#
# ['<s>', 'professor', 'marion', 'joe', 'ligeto', 'of', 'the', 'columbia', 'university', 'has', 'to', 'say', 'that', '80', 'of', 'the', 'diseases', 'of', 'heart', 'is', 'related', 'to', 'gene', '<e>'] 21.4313440873871
#
# ['<s>', 'the', 'gene', 'is', 'dominant', 'in', 'such', 'a', 'manner', 'that', 'despite', 'taking', 'extra', 'precaution', 'the', 'chances', 'of', 'heart', 'attack', 'keeps', 'looming', '<e>'] 13.636220641576585
#
# ['<s>', 'by', 'doing', 'the', 'treatment', 'at', 'the', 'right', 'time', 'the', 'sunburns', 'also', 'get', 'healed', '<e>'] 15.254841441312573
#
# ['<s>', 'like', 'bleeding', 'during', 'pregnancy', 'or', 'delivery', '<e>'] 4.216965034285822
#
# ['<s>', 'do', 'you', 'know', 'in', 'which', 'items', 'these', 'iron', 'substances', 'are', 'found', 'more', '<e>'] 5.261100147489514
#
# ['<s>', 'therefore', 'on', 'child', 'falling', 'sick', 'also', 'do', 'not', 'stop', 'feeding', 'food', 'to', 'him', '<e>'] 30.121571474187892
#
# ['<s>', 'after', 'toilet', 'or', 'after', 'cleaning', 'the', 'child', "'", 's', 'toilet', 'certainly', 'wash', 'hands', 'with', 'soap', '<e>'] 8.244211785591457
#
# ['<s>', 'when', 'they', 'want', 'children', 'how', 'many', 'children', 'whether', 'they', 'want', 'or', 'not', 'they', 'can', 'decide', 'this', 'with', 'the', 'help', 'of', 'their', 'life', 'partner', '<e>'] 13.025208668652954
#
# ['<s>', 'in', 'the', 'process', 'of', 'vasectomy', 'also', 'that', 'passage', 'is', 'closed', 'without', 'incision', 'through', 'which', 'the', 'sperms', 'flow', '<e>'] 8.243118368668382
#
# ['<s>', 'these', 'pills', 'on', 'going', 'to', 'the', 'body', 'of', 'the', 'female', 'stop', 'the', 'female', 'from', 'conceiving', '<e>'] 7.09873308716756
#
# ['<s>', 'the', 'pain', 'and', 'blood', 'flow', 'occurring', 'these', 'days', 'also', 'reduces', 'by', 'which', 'the', 'complaint', 'of', 'anemia', 'does', 'not', 'occur', '<e>'] 19.924726290242024
#
# ['<s>', 'there', 'is', 'no', 'alternative', 'to', 'exercise', 'in', 'reducing', 'obesity', 'but', 'if', 'you', 'feel', 'that', 'strolling', 'morning', 'evening', 'is', 'exercise', 'then', 'it', 'is', 'completely', 'wrong', '<e>'] 10.785463115062688
#
# ['<s>', 'smoking', 'drinking', 'mental', 'tension', 'fuel', 'the', 'fire', 'therefore', 'escape', 'from', 'them', '<e>'] 5.878016072274913
#
# ['<s>', 'consume', 'seasonal', 'fruits', 'vegetables', 'in', 'more', 'and', 'more', 'quantity', 'and', 'consume', 'fruits', 'vegetables', 'of', 'dark', 'color', 'more', 'and', 'more', 'quantity', 'and', 'certainly', 'eat', 'the', 'fruits', 'vegetables', 'of', 'dark', 'color', 'but', 'eat', 'less', 'sweet', 'fruits', '<e>'] 12.052992461794728
# ['<s>', 'if', 'there', 'is', 'desire', 'to', 'eat', 'sweets', 'then', 'eat', 'such', 'sweets', 'in', 'which', 'there', 'has', 'been', 'no', 'use', 'ghee', 'like', 'petha', 'in', 'place', 'of', 'gulab', 'jamun', '<e>'] 8.758854387623993
#
# ['<s>', 'according', 'to', 'the', 'verdict', 'of', 'dr', 'vimal', 'chhajed', 'the', 'director', 'and', 'the', 'heart', 'specialist', 'of', 'saaol', 'heart', 'center', 'of', 'delhi', 'the', 'alternative', 'of', 'natural', 'treatment', 'is', 'the', 'most', 'beneficial', 'for', 'the', 'patients', 'of', 'heart', '<e>'] 8.931645279382604
#
# ['<s>', 'for', 'the', 'cleanliness', 'of', 'the', 'scalp', 'long', 'hair', 'should', 'be', 'cut', 'short', '<e>'] 8.1043279279839
#
# ['<s>', 'by', 'applying', 'the', 'juice', 'of', 'the', 'leaves', 'of', 'dhatura', 'on', 'the', 'blisters', 'of', 'arunshika', 'two', 'times', 'a', 'day', 'after', 'adding', 'camphor', 'the', 'blisters', 'are', 'fast', 'destroyed', '<e>'] 18.730048881357526
#
# ['<s>', 'in', 'ayurveda', 'it', 'is', 'called', 'shaishawiya', 'pakshawadha', 'baal', 'pakshaaghaat', 'or', 'adharaang', 'waat', '<e>'] 14.083521162011237
#
# ['<s>', 'the', 'attack', 'of', 'the', 'disease', 'of', 'polio', 'is', 'often', 'sudden', '<e>'] 9.847467356977738
#
# ['<s>', 'at', 'present', 'two', 'types', 'of', 'polio', 'vaccine', 'are', 'brought', 'in', 'use', 'for', 'the', 'protection', 'against', 'this', 'disease', 'salk', 'vaccine', 'and', 'sabin', 'vaccine', '<e>'] 12.971771262209659
#
# ['<s>', 'there', 'is', 'the', 'provision', 'of', 'making', 'the', 'use', 'of', 'sabin', 'vaccine', 'through', 'mouth', 'at', 'the', 'interval', 'of', 'every', '1', 'month', 'continuously', 'for', 'three', 'months', 'three', 'times', 'in', 'total', '<e>'] 17.743335453151875
#
# ['<s>', 'but', 'in', 'modern', 'experiments', 'one', 'such', 'element', 'has', 'come', 'to', 'be', 'known', 'which', 'is', 'considered', 'to', 'be', 'far', 'more', 'lethal', 'to', 'the', 'heart', 'than', 'the', 'cholesterol', '<e>'] 7.10848573628218
#
# ['<s>', 'the', 'reasons', 'for', 'increase', 'of', 'homocystin', 'is', 'obesity', 'diabetes', 'high', 'blood', 'pressure', 'smoking', 'etc', '<e>'] 12.947973401284719
#
# ['<s>', 'on', 'getting', 'heart', 'attack', 'restlessness', 'is', 'felt', 'to', 'a', 'great', 'extent', '<e>'] 3.642967372593667
#
# ['<s>', 'do', 'not', 'give', 'anything', 'to', 'eat', 'or', 'drink', 'to', 'the', 'affected', 'person', '<e>'] 6.918499392740559
#
# ['<s>', 'do', 'not', 'leave', 'the', 'burnt', 'area', 'uncovered', 'cover', 'it', 'with', 'sterilised', 'cloth', '<e>'] 11.063816155986649
#
# ['<s>', 'along', 'with', 'the', 'fracture', 'if', 'there', 'is', 'wound', 'or', 'the', 'pulse', 'is', 'not', 'felt', 'then', 'take', 'him', 'to', 'the', 'doctor', 'immediately', '<e>'] 7.997961443299185
#
# ['<s>', 'on', 'the', 'occurrence', 'of', 'any', 'domestic', 'accident', 'with', 'the', 'child', 'you', 'take', 'the', 'following', 'precautions', '<e>'] 13.294614793144351
#
# ['<s>', 'scientists', 'believe', 'that', 'cancer', 'doest', 'not', 'only', 'remove', 'mild', 'diseases', 'but', 'also', 'cancer', '<e>'] 8.015017313846975
#
# ['<s>', 'if', 'you', 'have', 'sugar', 'then', 'regularly', 'you', 'should', 'get', 'blood', 'pressure', 'check', 'up', 'ecg', 'and', 'also', 'urine', 'test', 'done', '<e>'] 17.575642503250993
#
# ['<s>', 'the', 'lower', 'or', 'the', 'narrow', 'part', 'of', 'this', 'uterus', 'is', 'called', 'cervix', '<e>'] 6.105402296585328
#
# ['<s>', 'this', 'cancer', 'though', 'occurs', 'in', 'the', 'age', 'of', 'fifty', 'six', 'but', 'now', 'this', 'disease', 'has', 'also', 'started', 'occurring', 'in', 'young', 'age', '<e>'] 13.015034908377677
#
# ['<s>', 'apart', 'from', 'the', 'menstrual', 'flow', 'the', 'discharge', 'coming', 'out', 'of', 'the', 'genital', 'path', 'is', 'called', 'leukoria', 'or', 'white', 'discharge', '<e>'] 9.554169254482428
#
# ['<s>', 'these', 'days', 'at', 'every', 'place', 'there', 'are', 'heaps', 'of', 'garbage', 'and', 'the', 'water', 'also', 'continues', 'to', 'get', 'accumulated', 'which', 'is', 'the', 'suitable', 'place', 'for', 'the', 'breeding', 'of', 'mosquitoes', 'flies', 'cockroaches', 'etc', '<e>'] 25.234566515810656
#
# ['<s>', 'up', 'to', 'four', 'months', 'do', 'not', 'give', 'anything', 'other', 'than', 'mother', "'s", 'milk', '<e>'] 6.526945174546081
#
# ['<s>', 'if', 'the', 'child', 'has', 'problem', 'in', 'drinking', 'water', 'or', 'the', 'breathing', 'is', 'fast', 'then', 'immediately', 'take', 'it', 'to', 'big', 'hospital', '<e>'] 13.609384755013837
#
# ['<s>', 'every', 'vaccine', 'was', 'registered', 'in', 'the', 'mother', 'child', 'protection', 'card', 'and', 'every', 'time', 'behanji', 'reminded', 'radha', 'of', 'coming', 'the', 'next', 'time', 'for', 'the', 'vaccines', '<e>'] 16.855510937348875
#
# ['<s>', 'on', 'sixth', 'month', 'the', 'weight', 'of', 'muniya', 'was', 'twice', 'from', 'that', 'at', 'birth', '<e>'] 5.998572589355608
#
# ['<s>', 'change', 'in', 'the', 'nails', 'growing', 'on', 'the', 'inner', 'side', 'of', 'fingers', 'like', 'nails', 'getting', 'thick', 'or', 'colourless', 'is', 'a', 'sign', 'of', 'diabetes', 'foot', '<e>'] 7.040956991241236
#
# ['<s>', 'after', 'wiping', 'apply', 'talcum', 'powder', 'between', 'feet', 'and', 'fingers', 'so', 'that', 'there', 'remains', 'no', 'wetness', '<e>'] 6.6608462908091575
#
# ['<s>', 'rd_punc', 'v_vaux', 'v_vm', 'n_nn', 'cc_ccd', 'psp', 'n_nn', 'n_nn', 'rp_rpd', 'n_nn', 'cc_ccd', 'v_vm', 'n_nn', 'jj', '<e>'] 7.671023581964704
#
# ['<s>', 'the', 'interior', 'of', 'the', 'shoes', 'should', 'be', 'soft', '<e>'] 8.430846990228652
#
# ['<s>', 'in', 'the', 'condition', 'before', 'occurrence', 'of', 'diabetes', 'pre', 'diabetic', 'on', 'examining', 'blood', 'on', 'an', 'empty', 'stomach', 'level', 'of', 'glucose', 'increases', 'and', "'", 'glucose', 'tolerance', "'", 'becomes', 'abnormal', '<e>'] 12.816086684740645
#
# ['<s>', 'these', 'complications', 'can', 'be', 'stopped', 'in', 'a', 'significant', 'manner', 'by', 'keeping', 'a', 'strict', 'control', 'on', 'all', 'these', 'abnormal', 'processes', 'and', 'expense', 'that', 'is', 'incurred', 'on', 'the', 'patient', 'is', 'also', 'less', '<e>'] 15.775948002752939
#
# ['<s>', 'for', 'this', 'we', 'will', 'have', 'to', 'bring', 'changes', 'in', 'lifestyle', 'of', 'common', 'man', '<e>'] 7.326653510661938
#
# ['<s>', 'if', 'an', 'elderly', 'woman', 'is', 'afflicted', 'with', 'category', 'i', 'diabetes', 'then', 'danger', 'of', 'bone', 'breaking', 'increases', 'by', 'it', '<e>'] 10.069494727801905
#
# ...
#
# ['<s>', 'after', 'death', 'can', 'body', 'parts', 'be', 'taken', 'out', 'in', 'home', '<e>'] 4.811951768460936
#
# ['<s>', 'cornea', 'is', 'the', 'clear', 'window', 'in', 'front', 'of', 'the', 'eye', 'which', 'covers', 'them', '<e>'] 11.582138333972848
#
# ['<s>', 'patients', 'of', 'diseases', 'like', 'aids', 'blood', 'cancer', 'rabies', 'septicemia', 'poisoning', 'in', 'blood', 'jaundice', 'viral', 'hepatitis', 'etc', 'can', 'not', 'donate', 'eyes', '<e>'] 10.44360614104461
#
# ['<s>', 'till', 'eye', 'bank', 'team', 'comes', 'switch', 'off', 'fans', 'let', 'air', 'conditioner', 'or', 'coolers', 'work', 'and', 'keep', 'damp', 'cotton', 'and', 'ice', 'on', 'closed', 'eye', 'lashes', '<e>'] 7.666822074546215
#
# ['<s>', 'complete', 'it', '<e>'] 1.0000552046289062
#
# ['<s>', 'because', 'of', 'bipolar', 'disorder', 'some', 'people', 'get', 'addicted', 'to', 'drugs', 'and', 'alcohol', '<e>'] 8.420492339004428
#
# ['<s>', 'people', 'associated', 'with', 'clinical', 'research', 'remind', 'this', 'that', 'if', 'continuous', 'therapy', 'is', 'done', 'then', 'this', 'disease', 'can', 'be', 'cured', '<e>'] 7.932065359238713
#
# ['<s>', 'while', 'choosing', 'the', 'mood', 'stabilizer', 'the', 'age', 'of', 'the', 'person', 'his', 'her', 'weight', 'demographic', 'profile', 'family', 'history', 'effect', 'of', 'medicine', 'and', 'metabolic', 'endocrine', 'and', 'cardiovascular', 'profiles', 'are', 'also', 'seen', '<e>'] 15.140074097122643
#
# ['<s>', 'many', 'infants', 'who', 'are', 'born', 'with', 'weak', 'immunization', 'the', 'immunity', 'of', 'children', 'increases', 'with', 'breast', 'feeding', 'and', 'many', 'children', 'who', 'are', 'regularly', 'infected', 'through', 'other', 'children', 'in', 'school', 'can', 'fall', 'sick', 'again', 'and', 'again', '<e>'] 9.718806786810285
#
# ['<s>', 'for', 'remaining', 'healthy', 'good', 'nutrition', 'is', 'very', 'important', '<e>'] 4.643186473894229
# ['<s>', 'an', 'unparalleled', 'herbomineral', 'medicine', 'septilin', 'has', 'been', 'prepared', 'in', 'consequence', 'of', 'intensive', 'research', 'and', 'testing', 'which', 'helps', 'in', 'increasing', 'the', 'immunity', 'strength', 'in', 'children', 'and', 'adults', 'making', 'the', 'security', 'system', 'of', 'the', 'body', 'itself', 'strong', '<e>'] 13.632410222821056
#
# ['<s>', 'if', 'amla', 'is', 'used', 'everyday', 'then', 'it', 'cleans', 'the', 'blood', 'by', 'which', 'the', 'heart', 'remains', 'healthy', '<e>'] 23.162705978632545
#
# ['<s>', 'by', 'including', 'almond', 'pista', 'peanuts', 'etc', 'in', 'regular', 'food', 'the', 'heart', 'remains', 'healthy', 'and', 'by', 'this', 'the', 'fear', 'of', 'diseases', 'happening', 'related', 'to', 'this', 'also', 'reduces', '<e>'] 22.636470980163775
#
# ['<s>', 'unsaturated', 'fats', 'omega', '3', 'fatty', 'acids', 'fiber', 'etc', 'are', 'included', '<e>'] 4.557986357516786
#
# ['<s>', 'by', 'watching', 'tv', 'from', 'close', 'by', 'watching', 'the', 'tv', 'for', 'long', 'water', 'starts', 'flowing', 'from', 'the', 'eyes', 'which', 'is', 'a', 'type', 'of', 'allergy', '<e>'] 12.52256855928109
#
# ['<s>', 'she', 'would', 'think', 'about', 'waxing', 'for', 'getting', 'rid', 'of', 'these', 'unwanted', 'hairs', 'but', 'would', 'get', 'scared', 'about', 'the', 'pain', 'happening', 'along', 'with', 'that', '<e>'] 9.783549502814491
#
# ['<s>', 'although', 'the', 'course', 'of', 'the', 'treatment', 'is', 'different', 'on', 'the', 'basis', 'of', 'the', 'growth', 'of', 'hair', 'and', 'type', 'but', 'its', 'result', 'is', 'permanent', '<e>'] 12.99073541388856
#
# ['<s>', 'it', 'is', 'essential', 'for', 'the', 'care', 'of', 'food', 'and', 'exercise', 'during', 'pregnancy', '<e>'] 21.689129532616267
#
# ['<s>', 'so', 'do', 'not', 'do', 'any', 'work', 'continuously', '<e>'] 6.838295702195499
#
# ['<s>', 'the', 'weight', 'of', 'the', 'child', 'will', 'be', 'less', 'by', 'smoking', '<e>'] 8.363192447423284
#
# ['<s>', 'because', 'sugar', 'makes', 'our', 'immune', 'system', 'weak', '<e>'] 6.326545264428661
#
# ['<s>', 'anyone', 'can', 'be', 'influenced', 'by', 'this', 'state', 'of', 'depression', '<e>'] 7.288753354459176
#
# ['<s>', 'statistics', 'say', 'that', 'the', 'death', 'of', '62', 'percent', 'smoking', 'women', 'in', 'india', 'happens', 'in', '30', 'to', '49', 'years', 'of', 'age', '<e>'] 11.578690081616555
#
# ['<s>', 'systolic', 'blood', 'pressure', 'must', 'be', 'between', '100', '140', 'millimetre', 'mm', 'and', 'diastolic', '70', '100', 'millimetre', '<e>'] 12.319108665068097
#
# ['<s>', 'you', 'have', 'had', 'cold', 'and', 'fever', 'whose', 'reason', 'you', 'do', 'not', 'know', '<e>'] 7.718249784144566
#
# ['<s>', 'first', 'time', 'donator', 'of', 'plasma', 'must', 'have', 'donated', 'blood', 'at', 'least', 'once', 'in', 'the', 'last', 'one', 'year', '<e>'] 12.217188197312995
#
# ['<s>', 'in', 'comparison', 'of', 'this', 'voluntary', 'blood', 'donors', 'do', 'not', 'hide', 'their', 'diseases', '<e>'] 10.152291223661598
#
# ['<s>', 'every', 'time', 'when', 'you', 'donate', 'blood', 'then', 'the', 'history', 'of', 'your', 'health', 'is', 'asked', 'and', 'a', 'limited', 'medical', 'check', 'is', 'done', '<e>'] 14.661053284149022
#
# ['<s>', 'use', 'such', 'an', 'oil', 'in', 'food', 'which', 'does', 'not', 'solidify', '<e>'] 15.513835833477929
#
# ['<s>', 'in', 'such', 'cases', 'the', 'danger', 'of', 'heart', 'attacks', 'increases', '20', 'percent', 'in', 'which', 'the', 'life', 'of', 'the', 'person', 'may', 'be', 'lost', '<e>'] 16.809329456481994
#
# ['<s>', 'that', 'is', 'why', 'one', 'must', 'remain', 'very', 'careful', '<e>'] 19.18496561383872
#
# ['<s>', 'no', 'symptom', 'of', 'enzyma', 'appears', 'in', 'the', 'patients', 'of', 'diabetes', '<e>'] 11.512145328469066
#
# ['<s>', 'stress', 'ecocardiogram', 'by', 'this', 'test', 'heart', 'wall', 'and', 'its', 'pumping', 'work', 'is', 'seen', '<e>'] 9.93368398362239
#
# ['<s>', 'there', 'is', 'a', 'check', 'for', 'this', 'also', '<e>'] 8.052437923521378
#
# ['<s>', 'do', 'not', 'sit', 'for', 'long', 'at', 'the', 'computer', '<e>'] 8.281656715562903
#
# ['<s>', 'the', 'smoke', 'of', 'tobacco', 'harms', 'your', 'body', 'and', 'cancer', 'of', 'lungs', 'throat', 'etc', 'heart', 'disease', 'and', 'are', 'the', 'reason', 'of', 'lung', 'diseases', 'of', 'long', 'duration', 'like', 'bronchitis', 'asthma', 'etc', '<e>'] 14.682430322749527
#
# ['<s>', 'as', 'beautiful', 'as', 'a', 'strawberry', 'looks', 'it', 'is', 'as', 'much', 'filled', 'with', 'benefits', '<e>'] 6.9280942102174015
#
# ['<s>', 'keep', 'some', 'walnuts', 'in', 'them', 'for', 'extra', 'crunch', '<e>'] 16.001412356300985
#
# ['<s>', 'if', 'the', 'mother', 'father', 'both', 'are', 'fat', 'then', 'there', 'remains', '80', 'percent', 'possibility', 'of', 'the', 'child', 'being', 'fat', 'and', '40', 'percent', 'when', 'some', 'one', 'from', 'mother', 'father', 'is', 'fat', '<e>'] 15.33205118324735
#
# ['<s>', 'along', 'with', 'the', 'compressor', 'being', 'made', 'the', 'temperature', 'of', 'the', 'engine', 'also', 'increases', '<e>'] 5.573992241649627
#
# ['<s>', 'this', 'work', 'is', 'of', 'kafa', 'in', 'the', 'body', '<e>'] 5.643785013522833
#
# ['<s>', 'although', 'in', 'modern', 'medicine', 'in', 'view', 'of', 'the', 'result', 'the', 'medicine', 'is', 'given', 'but', 'that', 'medicine', 'may', 'be', 'increasing', 'the', 'pitta', 'and', 'the', 'cells', 'have', 'closed', 'because', 'of', 'the', 'increase', 'in', 'pitta', 'by', 'this', 'instead', 'of', 'benefits', 'the', 'possibility', 'of', 'harm', 'increases', '<e>'] 15.855197463790647
#
# ['<s>', 'like', 'in', 'the', 'body', 'if', 'generally', 'some', 'part', 'gets', 'injured', 'then', 'the', 'cells', 'and', 'tissues', 'there', 'give', 'their', 'full', 'contribution', 'according', 'to', 'the', 'formation', 'of', 'that', 'place', '<e>'] 10.869472169529875
#
# ['<s>', 'unber', 'the', 'yukti', 'vyapakshya', 'first', 'the', 'panchakarma', 'of', 'the', 'patient', 'is', 'done', '<e>'] 7.173925536593902
#
# ['<s>', 'apply', 'this', 'on', 'the', 'neck', 'and', 'leave', 'for', '10', 'to', '15', 'minutes', '<e>'] 7.88565847148863
#
# ['<s>', 'the', 'doctors', 'of', 'rhode', 'island', 'hospital', 'have', 'discovered', 'microscopic', 'particles', 'named', 'micro', 'vesicles', '<e>'] 6.397077853671306
#
# ['<s>', 'later', 'they', 'do', 'the', 'creation', 'of', 'new', 'cells', '<e>'] 9.167272772831133
#
# ['<s>', 'by', 'putting', 'a', 'cut', 'on', 'the', 'stomach', 'or', 'chest', 'the', 'aneurysm', 'part', 'of', 'the', 'aorta', 'can', 'be', 'cut', 'and', 'a', 'pipe', 'is', 'sewn', 'in', 'its', 'place', '<e>'] 17.519329844261772
#
# ['<s>', 'in', 'this', 'surgical', 'repairing', 'the', 'danger', 'to', 'the', 'life', 'of', 'the', 'patient', 'is', '10', '<e>'] 5.356635078488887
#
# ['<s>', 'yes', 'in', 'approximately', '20', '30', 'percent', 'people', 'by', 'the', 'deficiency', 'of', 'vitamin', 'b', '12', 'there', 'is', 'the', 'possibility', 'of', 'pain', 'in', 'the', 'waist', 'and', 'back', '<e>'] 15.599701790349712
#
# ['<s>', 'complete', 'it', '<e>'] 1.0000552046289062
#
# ['<s>', 'actually', 'it', 'has', 'been', 'known', 'by', 'the', 'descriptions', 'of', 'a', 'total', 'of', '18', 'studies', 'done', 'on', 'flaxseed', 'that', 'if', 'a', 'person', 'with', 'high', 'cholestrol', 'intakes', 'around', '30', 'to', '60', 'grams', 'of', 'flaxseed', 'daily', 'then', 'his', 'faulty', 'cholestrol', 'ldl', 'level', 'can', 'reduce', 'to', 'a', 'considerable', 'extent', '<e>'] 9.886472173304888
#
# ['<s>', 'those', 'females', 'who', 'have', 'the', 'problem', 'of', 'leukorrhea', 'discharge', 'of', 'white', 'water', 'they', 'should', 'eat', 'ten', 'grams', 'of', 'amla', 'in', 'equal', 'amount', 'of', 'suger', 'and', 'honey', 'till', 'two', 'weeks', 'daily', 'there', 'problem', 'will', 'be', 'solved', '<e>'] 10.018972802785123
#
# ['<s>', 'the', 'hemoglobin', 'level', 'improves', 'with', 'its', 'intake', '<e>'] 4.641588833612778
#
# ['<s>', 'complete', 'it', '<e>'] 1.0000552046289062
#
# ['<s>', 'under', 'this', 'new', 'skin', 'emerges', 'very', 'soon', 'whereas', 'before', 'this', 'when', 'the', 'ablative', 'lasers', 'were', 'used', 'then', 'it', 'took', 'time', 'for', 'the', 'fresh', 'skin', 'to', 'emerge', '<e>'] 11.842800311849953
#
# ['<s>', 'fractional', 'laser', 'is', 'suitable', 'for', 'the', 'treatment', 'of', 'light', 'wrinkles', 'and', 'with', 'it', 'a', 'special', 'glow', 'comes', 'on', 'the', 'skin', '<e>'] 8.096388819793704
# ['<s>', 'according', 'to', 'fred', 'hutchinson', 'cancer', 'research', 'centre', 'and', 'other', 'researchers', 'the', 'females', 'who', 'have', 'the', 'history', 'of', 'migraine', 'a', 'type', 'of', 'headache', 'they', 'have', '26', 'percent', 'less', 'chances', 'of', 'having', 'breast', 'cancer', '<e>'] 13.209405006984534
#
# ['<s>', 'have', 'to', 'give', 'a', 'dinner', 'party', 'in', 'the', 'evening', 'or', 'participate', 'in', 'a', 'race', 'in', 'the', 'evening', '<e>'] 7.214667535907177
#
# ['<s>', 'hence', 'now', 'the', 'researchers', 'are', 'being', 'pressurized', 'that', 'the', 'earlier', 'cancer', 'related', 'assumptions', 'they', 'test', 'them', 'again', 'and', 'try', 'to', 'undersatnd', 'what', 'cancer', 'actually', 'is', 'and', 'how', 'does', 'its', 'development', 'takes', 'place', '<e>'] 10.745852356440569
#
# ['<s>', 'due', 'to', 'lack', 'of', 'screening', 'this', 'was', "n't", 'there', 'earlier', '<e>'] 6.393667468341493
#
# ['<s>', 'astigmatismo', 'this', 'is', 'a', 'special', 'kind', 'of', 'vision', 'defect', 'in', 'which', 'the', '<e>'] 5.6388743324261394
#
# ['<s>', 'if', 'in', 'some', 'accident', 'the', 'female', 'hurts', 'her', 'spine', 'then', 'usually', 'she', 'has', 'backache', 'problems', '<e>'] 13.010109148907858
#
# ['<s>', 'the', 'tonsil', 'stops', 'if', 'its', 'heated', 'just', 'when', 'it', 'is', 'erupting', '<e>'] 9.89634764107922
#
# ['<s>', 'arnmal', 'impacted', 'cerumen', 'some', 'amount', 'of', 'dirt', 'tent', 'to', 'accumulate', 'in', 'the', 'ear', 'but', 'at', 'times', 'it', 'starts', 'to', 'get', 'more', '<e>'] 12.244130784732128
#
# ['<s>', 'at', 'times', 'there', 'is', 'egzema', 'in', 'the', 'ear', 'or', 'the', 'natural', 'dirt', 'gets', 'more', 'greasy', '<e>'] 8.08417482183081
#
# ['<s>', 'complete', 'it', '<e>'] 1.0000552046289062
#
# ['<s>', 'in', 'equal', 'amount', 'of', 'vinegar', 'and', 'the', 'infusion', 'of', 'rose', 'add', 'half', 'of', 'it', 'in', 'whisky', 'and', 'double', 'its', 'amount', 'in', 'water', '<e>'] 9.544046418060939
#
# ['<s>', 'baldness', 'becomes', 'temporary', 'after', 'fever', '<e>'] 3.72759372031494
#
# ['<s>', 'argate', 'belladonna', 'hyosimes', 'antipyrine', 'tincture', 'belliriun', 'quinine', 'tincture', 'ferri', 'perchloride', 'musk', 'etc', 'are', 'useful', 'in', 'this', 'disease', '<e>'] 5.190973553656606
#
# ['<s>', 'bahumutra', 'excessive', 'urination', 'diabetes', 'insipidus', 'there', 'is', 'no', 'specific', 'cause', 'of', 'this', 'disease', 'sometimes', 'it', 'happens', 'because', 'of', 'injury', 'to', 'head', '<e>'] 11.753870388911732
#
# ['<s>', 'patient', 'of', 'syphilis', 'should', 'be', 'given', 'potash', 'iodide', 'in', 'whole', 'amount', '<e>'] 5.878016072274913
#
# ['<s>', 'in', 'pain', 'of', 'atrophic', 'and', 'rheumatoid', 'arthritis', 'kolvikum', 'iodides', 'soda', 'salicylic', 'salicyn', 'ericherine', 'guacum', 'tincture', 'jalsimayi', 'etc', 'are', 'beneficial', '<e>'] 6.087699745221323
#
# ['<s>', 'after', 'occurrence', 'of', 'tremor', 'in', 'one', 'arm', 'tremor', 'also', 'starts', 'in', 'the', 'leg', 'of', 'that', 'side', '<e>'] 19.018851855391546
#
# ['<s>', 'patient', 'of', 'this', 'disease', 'recovers', 'very', 'seldom', '<e>'] 3.420634883766885
#
# ['<s>', 'but', 'in', 'embolism', 'coma', 'does', 'not', 'occur', 'at', 'all', 'or', 'a', 'momentary', 'unconsciousness', 'occurs', 'but', 'half', 'paralysis', 'is', 'of', 'a', 'very', 'acute', 'kind', '<e>'] 12.748158409199274
#
# ['<s>', 'nervous', 'disease', 'heart', 'disease', 'and', 'epilepsy', 'etc', 'mental', 'illnesses', 'are', 'also', 'of', 'this', 'kind', '<e>'] 6.72465016946084
#
# ['<s>', 'divya', 'ashmarihar', 'kvath', 'decoction', 'it', 'is', 'made', 'from', 'diuretic', 'and', 'stone', 'penetration', 'plants', 'mentioned', 'in', 'ayurveda', '<e>'] 10.016047056828429
#
# ['<s>', 'those', 'who', 'have', 'complaint', 'of', 'recurrent', 'formation', 'of', 'stones', 'after', 'eating', 'this', 'for', 'a', 'while', 'formation', 'of', 'stones', 'ends', 'forever', '<e>'] 7.50937425978183
#
# ['<s>', 'this', 'kayakalp', 'oil', 'is', 'a', 'holy', 'medicine', 'worth', 'keeping', 'in', 'every', 'house', 'at', 'all', 'times', '<e>'] 21.13594042374263
#
# ['<s>', 'it', 'is', 'an', 'ayurvedic', 'drink', '<e>'] 4.298693378261098
#
# ['<s>', 'divya', 'dhara', 'from', '5', 'to', '10', 'drops', 'of', 'essence', 'of', 'fennel', 'etc', 'give', 'in', '15', 'minutes', 'in', 'cholera', '<e>'] 6.511870318353271
#
# ['<s>', 'on', 'occurrence', 'of', 'stomach', 'ache', 'gas', 'or', 'flatulence', 'and', 'asthma', 'eat', 'adding', '3', '4', 'drops', 'to', 'raw', 'sugar', 'batasha', 'or', 'hot', 'water', '<e>'] 10.24118877843078
#
# ['<s>', 'lungs', 'get', 'oxygen', 'in', 'more', 'amount', 'by', 'this', '<e>'] 7.79573736102389
#
# ['<s>', 'by', 'consuming', 'for', 'a', 'while', 'all', 'female', 'problems', 'go', 'away', '<e>'] 8.024878554003037
#
# ['<s>', 'removing', 'restlessness', 'nervousness', 'it', 'increases', 'efficiency', 'of', 'heart', '<e>'] 5.253055608807535
#
# ['<s>', 'there', 'is', 'growth', 'in', 'resistance', 'power', 'in', 'body', '<e>'] 4.224063152014316
#
# ['<s>', 'it', 'stops', 'inflammation', 'of', 'urinary', 'tract', 'and', 'all', 'over', 'and', 'increase', 'of', 'gall', '<e>'] 11.504769623030644
#
# ['<s>', 'there', 'is', 'danger', 'of', 'occurrence', 'of', 'ear', 'infection', 'with', 'cough', 'in', 'children', '<e>'] 6.19574718093246
#
# ['<s>', 'for', 'this', 'mixing', 'water', 'in', 'khali', 'residue', 'remaining', 'after', 'extracting', 'oil', 'from', 'mustard', 'seed', 'mustard', 'leave', 'overnight', 'for', 'formation', 'of', 'daub', '<e>'] 9.477722148120629
#
# ['<s>', 'your', 'hair', 'will', 'become', 'beautiful', 'black', 'dense', 'from', 'its', 'regular', 'use', '<e>'] 7.609933573018582

# %%
with open('health_corpus_kn.pkl', 'wb') as f:
    pickle.dump(health_corpus_kney, f)

# %%
with open('health_corpus_wb.pkl', 'wb') as f:
    pickle.dump(health_corpus_wb, f)
