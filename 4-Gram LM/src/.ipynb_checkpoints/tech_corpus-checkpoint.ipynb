# %%
import re
import random
import numpy as np 
import pickle

# %% [markdown]
# ### Tokenization

# %%
def remove_space_from_quatation(string):
    temp = string.split()
    
    final_str = ''
    
    for i in temp:
        
        if i=='’':
            t = final_str[:len(final_str)-1] + "'"
            final_str = t
        else:
            final_str += i
            final_str += ' '
            
    return final_str
            
def get_tokens(statement):
    fs = remove_space_from_quatation(statement)
    count = 0
    ans = re.findall(r'[\'\w]+', fs)
    
    final_tokens = []
    
    for i in ans:
        final_tokens.append( i.lower())
        count += 1
        
    return final_tokens ,count 


def tokenize(file):
    count = 0
    f = open(file)
    lines = f.readlines()
    
    tokens = []
    
    for i in lines:
        temp ,c = get_tokens(i)
        
        count += c
        tokens.append(temp)
        
    return tokens ,count

# %% [markdown]
# ### Adding starting and ending tokens in each statements

# %%
def add_padding(tokens):
    start_token = '<s>'
    end_token = '<e>'

    final_tokens = []

    for i in tokens:
        temp = [start_token] + i + [end_token]
        final_tokens.append(temp)

    return final_tokens

# %% [markdown]
# ### Preprocessing

# %%
def preproceesing( filename ):
    tokens , total_tokens = tokenize(filename)
    
    padded_tokens = add_padding(tokens)
    
    return padded_tokens ,total_tokens

# %%
tokens, total_tokens = preproceesing('../text_data/technical_domain_corpus.txt')

# %% [markdown]
# ### Calculating grams

# %%
def unigram(tokens):
    grams = []
    
    for stmt in tokens:
        for i in stmt:
            temp = tuple([i])
            grams.append(temp)
    
    return grams

def bigram(tokens):
    
    gram = []
    
    for line in tokens:
        for i in range( len(line) - 1):
            temp = tuple( [line[i] ,line[i+1]])
            gram.append( temp)
            
    return gram 


def trigram(tokens):
    
    gram = []
    
    for line in tokens:
        for i in range( len(line) - 2):
            temp = tuple( [line[i] ,line[i+1],line[i+2]])
            gram.append(temp)
            
    return gram


def fourgram(tokens):
    gram = []
    
    for line in tokens:
        for i in range( len(line) - 3):
            temp = tuple( [line[i] ,line[i+1] , line[i+2] ,line[i+3] ])
            gram.append(temp)
    
    return gram


n_grams = [ None ,unigram(tokens) , bigram(tokens) , trigram(tokens) , fourgram(tokens) ]

# %%
def calc_freq( n_grams ):
    freq = [ None , {} ,{} ,{} ,{} ]
    
    for n in range(1,5):
        gram = n_grams[n]
        
        for i in gram:
            if i not in freq[n]:
                freq[n][i] = 1
            else:
                freq[n][i] += 1
                
    return freq

freq = calc_freq(n_grams)

# %% [markdown]
# ### Kneser-Ney Smoothing

# %%
def kn_recur( word , prev_words , top_order , freq , total_tokens):
    
    ## Base Condition
    if len(prev_words) == 0:
        if top_order == True:
            count = 0
            
            if word in freq[1]:
                count = freq[1][word]
        
            return ( count / total_tokens )
        else:
            num = 0

            for i in freq[2]:
                if i[1] == word:
                    num+=1

            return num / len( freq[2] )

    d = 0.7
    words = prev_words + [word]
    
    ## Compute NUmerator
    look_all = len(words)
    look_prev = len(prev_words)
    key = tuple(words)
    num1 = 0
    
    if top_order == True:
        ## Count For highest Order
        if key in freq[look_all]:
            num1 = max( freq[look_all][key] - d , 0 )
    
    else:
        temp = words[1:]
        
        for i in freq[look_all]:
            t1 = list(i)
            t2 = t1[ 1:len(t1)]
            t3 = tuple(t2)
            
            if t3 == temp:
                num1 += 1
    
    
    ## Computing Denominator
    key = tuple(prev_words)
    deno = 0
    
    if top_order == True:
        if key in freq[look_prev]:
            deno = freq[look_prev][key]
        else:
            deno = 1
    else:
        deno = len(freq[look_all])
    
    
    num2 = 0
    for i in freq[look_all]:
        t1 = list(i)
        t2 = t1[0:len(t1)-1]
        t3 =  tuple(t2)
        
        if t3 == tuple(prev_words):
            num2 += 1
    
    if num1==0 and num2==0:
        #ans = random.uniform(0.1, 0.01) +  random.uniform(0,1) * kn_recur(word ,prev_words[1:] ,False ,freq ,total_tokens)
        ans = random.uniform(0.1, 0.2) + kn_recur(word ,prev_words[1:] ,False ,freq ,total_tokens)

        return ans
    
    if num2 == 0:
        return ( num1 / deno )
    
    return (num1/deno) + d*(num2/deno)*kn_recur(word , prev_words[1:] ,False ,freq ,total_tokens)

# %% [markdown]
# ### Witten Bell smoothing

# %%
def val( gram ,freq):
    ans = 0
    if len(gram) == 0 :
        for i in freq[1].values():
            ans += i
    elif gram in freq[ len(gram)].keys():
        ans = freq[len(gram)][gram]
    else:
        ans = 0
    
    return ans 

def lambdas( gram ,freq):
    
    count = 0
    
    for i in freq[ len(gram)+1 ].keys():
        if i[:-1] == gram:
            count += 1
            
    deno = val(gram ,freq)
        
    deno = deno + count
    
    if deno != 0:
        lam = count/float(deno)
        return lam
    
    return random.uniform(0.1,0.2)


def wb( words , freq):
    
    if len(words) == 1 :
        gram = tuple([words])
        num = val(gram ,freq)
        
        deno = 0
        for i in freq[1].values():
            deno += i
        
        return num/float(deno)
    
    gram = tuple(words)
    
    num = val( gram ,freq)
    deno = val( gram[:-1] ,freq)
    
    if deno != 0 :
        
        ans1 = ( 1-lambdas(gram[:-1] , freq) )
        ans2 =  lambdas(gram[:-1] ,freq ) * wb(gram[1:] ,freq)
        
        ans = ans1*(num/deno) + ans2
        
        return ans 
    
    else:
        ans = random.uniform(0.1, 0.2) +  +(lambdas(gram[:-1] ,freq) * wb(gram[1:] ,freq))
        return ans

# %% [markdown]
# ### Perplexity

# %%
def find_perp( stmt ,freq ,total_tokens ,smoothing):
    
    gram4 = fourgram([stmt])

    probability = 1
    prev_prob = 1
    
    for i in gram4:
        
        cur_word = i[3]
        prev_words = list(i[0:3])
        
        if smoothing == 'kn':
            temp = kn_recur(cur_word, prev_words ,True ,freq ,total_tokens)
        else:
            temp = wb(i ,freq)
        
        if temp == 0 :
            continue
        
        prev_prob = probability
        probability *= temp
        
        if probability == 0 :
            probability = prev_prob
            break
    
    deno = 1/probability
    perplexity = np.power( deno ,1/len(stmt))
    
    return perplexity

# %% [markdown]
# ### Testing

# %%
f = open('../text_data/technical_domain_corpus.txt')
lines = f.readlines()

# %%
idx = random.sample(range(0, len(tokens)), 1000)

test = []
train = [] 
stmts = []

total_tokens = 0
for i in range(0, len(tokens)):
    
    if i in idx:
        test.append( tokens[i] )
        stmts.append( lines[i] )
    else:
        train.append(tokens[i] )
        total_tokens += len(tokens[i])

# %%
n_grams = [ None ,unigram(train) , bigram(train) , trigram(train) , fourgram(train) ]

train_freq = calc_freq(n_grams)

# %%
tech_corpus_kney = [] 

for i in range(len(test)):
    perp = find_perp(test[i] , train_freq ,total_tokens ,'kn' )
    
    print(i,stmts[i] ,perp)
    print()
    
    tech_corpus_kney.append([stmts[i],perp])
# Out:
# 0 Now , why do we started our discussion on chain polymerization ?
#  140.42836798135795
#
# 1 Now , this anionic species or cationic species , they are not present alone in the medium , they are always associated with or accompanied by a counter ion .
#  901.57714519276
#
# 2 This ketone loop complex form complex with this ionic species and then once they form complex , the reactivity of this ionic species are lost .
#  803.9925361910372
#
# 3 So , as the reactivity of the ionic centre , obviously , the free is the ionic center it gets , it becomes more reactive .
#  412.01221367703585
#
# 4 And if you compare with radical chain polymerization , solvent polarity actually has no such role to play in case of radical chain polymerization .
#  56.7730826903011
#
# 5 Because they have seen this propagation species are similarly charged , they cannot react with each other and terminate the chains .
#  1683.8421692625623
#
# 6 As a result , there is a huge increase in the concentration of these active centers in the medium and as a result , the reaction is very fast .
#  842.2816596756054
#
# 7 So , I should write cationic chain polymerization .
#  538.4668624502291
#
# 8 So , if you consider this case the reaction happens like this .
#  114.79898019631936
#
# 9 This is I and which then react with a monomer forming the chain initiating spices .
#  205.8488959762563
#
# 10 So , it follows this trend and for the carbon cationic generator like RCl , like AlCl 3 plus , this reaction .
#  28.494808203628427
#
# 11 So , we talked about the initiator reaction with by this reaction of the monomers with the electrophile .
#  239.41867897509522
#
# 12 But as I mentioned in earlier , these are the generic examples , which we get in this page .
#  11063.169367429033
#
# 13 When you increase the polarity by adding ethylene dichloride , dichloethane , EU , say in 40 - 60 mixture , your dielectric constant goes up , your reaction goes up .
#  54.530869545652536
#
# 14 You do film diffusion klam can be computed .
#  389.40914402265764
#
# 15 A JD factor has been defined in the case of heterogeneous catalysis in general and which applies very well to even enzyme catalyzed reaction .
#  549.0615884128513
#
# 16 Based on the operational data that means the concentration of substrate in the feed and the product stream as well as the parameters of the reactor operation and the particle size , one can determine the length of the reactor required and if this length of the reactor required is relative to the length of the reactor required for biochemical reaction , if you compare this height required , let us say this is Z1 to that of the height required Z2 based on biochemical reaction if you calculate idealized reactor performance equation and calculate the height of the reactor required and compare the two values that gives you an identification whether film diffusion is controlling or not .
#  inf
#
# 17 All the enzymes are present on the surface and in the thin film there is no reaction taking place .
#  516.1185348571311
#
# 18 which is called as effectiveness factor .
#  51.91504892231312
#
# 19 This effectiveness factor is the ratio of the rate of actual reaction in the matrix divided by the maximum reaction rate obtainable if there was no pore diffusional resistance .
#  7057.986349943555
#
# 20 Ultimately when you will measure the enzyme activity you will see that the enzyme activity is low because per unit enzyme loading the activity which will be expressed by the immobilized enzyme particle will be lower .
#  4024.487709687695
#
# 21 At the moment we are talking only of mass transfer and biochemical reaction .
#  71.71113452498332
#
# 22 In today ’ s lecture we planned to cover interfacial polymerization , and we also will be talking about different synthesis of different step polymers in very brief briefly .
#  5432.106425835842
#
# 23 And when a reaction has progressed some for some duration and then duration there is a chance that monomers might form dimer or small molecular weight , oligomers .
#  216.67286085288038
#
# 24 So , that will again reduce the molecular weight build up .
#  30.359803900897724
#
# 25 And sometimes the catalyst , which you are using in the reaction that might be one source , which might be catalyzing the side reactions as well .
#  1030.2710808499753
#
# 26 And I will come to the example of interfacial and polymerization .
#  312.70052303410824
#
# 27 So , what is done to tackle this problem a tri a amine is added in the organic medium , say triethylamine or trimethylamine and when this reacts with this species it is form a salt now this is water soluble .
#  830.3982061333406
#
# 28 So , what are the requirements for a successful inter polymerization interfacial polymerization you need to have a inorganic base , which you require to neutralize the produce HCl otherwise HCl with go back and hydrolyze the salt .
#  430.7778711528679
#
# 29 So , you know increasingly people are trying to avoid this root simply to avoid this use of large amount of organic solvent , which are not environmentally friendly .
#  1015.7760708407359
#
# 30 We will move to the next class of polymers step polymers polyamides and we have this is linear poly polymerization reactions this is aliphatic diamine with aliphatic diacid you can directly under go reaction to form linear polyamide .
#  241.54700106006237
#
# 31 So , you can first stage you do a step polymerize to syntheses this and then you can take this and do a second step of chain polymerization either by oxidizing this or no using the other methods .
#  483.4835677164726
#
# 32 There are also amorphous T g is very high and their continuous use temperature is 300 to 350 degree centigrade temperature .
#  394.2390809902444
#
# 33 This is another example another set of polymers is polyamide imides you take this aromatic diamines with one side poly anhydride and the carbo oxalic acid silica acids to form this amide polyamide imides .
#  104.44707532541118
#
# 34 And butylene glycol group butylene glycol group always next to each other will we expect that or will you expect that there be will random copolymers .
#  93.60627508692802
#
# 35 Then you will always land up in a completely random copolymer , you understand why , because this reaction when they are happening there is slow reaction .
#  250.98434385186908
#
# 36 Because , they very fast reaction once the product is formed the byproduct HCl is getting neutralized with sodium hydroxide , which means there is one reaction is formed .
#  446.01416266615996
#
# 37 If there are significant differences in the reactivity of the two diols then there will be a blocky nature in the copolymers .
#  223.16306106210473
#
# 38 At the end of the immobilization enzyme preparation retention of catalytic activity is a major requirement .
#  49.05620448940242
#
# 39 So when we say retention of catalytic activity you are implying that a major fraction of the activity must be retained .
#  410.17215252848
#
# 40 One limitation will be that the product has to be a low molecular product .
#  2350.0102219301325
#
# 41 In living cell also the enzyme is entrapped through a semi permeable membrane which does not allow the enzyme molecules to pass through and some of the product molecules from the cell also are usually ripped off .
#  985.2877567248687
#
# 42 One is that the scientist wanted to apply some of the enzymes for industrial processing and obviously for industrial processing you need certain operational advantages The major disadvantages in the case of the enzymes is the restriction in the best mode of processing , the stability , some of the physico chemical properties in respect of pH optimum , temperature optimum , substrate specificity and they could all be taken care for industrial processing .
#  162.23344074564093
#
# 43 When I say physico - chemical properties the most important properties probably for which enzymes are considered as poor candidates are their stability .
#  94.00115125891293
#
# 44 In fact any immobilized enzyme system has three major constituents , three major players The first player is the soluble enzyme .
#  330.0861168510262
#
# 45 What are the properties we look at when we choose a soluble enzyme ?
#  52.652261569820844
#
# 46 If your environmental pH is alkaline , seven plus , the isomerisation can take place naturally and the isomerisation product will not be only fructose but it will be plus few other hexoses which will be produced and the whole advantage of using an enzymatic process is lost .
#  144.70848829656813
# 47 Bulk of the immobilization enzyme product will be in the form of carrier .
#  511.35398956458477
#
# 48 This will require many of the functional groups to be present on the carrier .
#  41761.23599191509
#
# 49 Large varieties of carriers have been used and are available for use fortunately and these carriers have been classified by various people in different modes , in different forms .
#  491.69278365395724
#
# 50 The non - porous carriers will have a low specific surface area because the porous matrix will provide lot of internal surface in a matrix .
#  140.01740146235653
#
# 51 Then in the case of proteins almost like what we talked about gel structure , collagen and gelatin are typical examples and there is a whole range of synthetic polymers which have been reported and used for immobilizing enzymes which are usually polystyrene based , vinyl polymers , polyacrylamide and so on.You can classify and a large variety of carriers are available for use for immobilizing enzymes and the choice will depend upon various properties that we have listed .
#  4194.438745423637
#
# 52 And if time permits we will continue and discuss the method of dilute solution viscometry by which we can determine viscosity average molecular weight .
#  2688.9181401559154
#
# 53 And eta s p you know if you recollect ; eta s p is eta r minus 1 , eta by eta 0 minus 1 .
#  1146.7990552286094
#
# 54 So , hydrodynamic volume will be lower in this case .
#  179.0458686013422
#
# 55 Now this r we said it is proportional to the radius of gyration .
#  221.05605109321183
#
# 56 So , we can write that intrinsic viscosity is proportional to ; the proportionality sign is also missing here is V h which is proportional to this term divide by M .
#  535.270649842362
#
# 57 So if you change any of these three polymer solvent and temperature , then k and a value will be changed .
#  904.8028711428274
#
# 58 Now k increases with the value of a for flexibility ; typically you have seen it has been seen that k also increases with the increase in the value of a and it is typically around this range .
#  7111.780914011633
#
# 59 So , the expansion factor will be ; if you compare the expansion factor of unperturbed linear polymer chain it may go down below that below one .
#  3272.585838083798
#
# 60 You know this assumption is reasonably okay to do is one ; the eta specific viscosity is given by the summation of the specific viscosity of the individual chains .
#  1301.4082936508698
#
# 61 So now , we can find out the expression for the intrinsic viscosity for the polymer sample which is the mixture of all the polymer chain which is given by limit c tends to 0 eta specific by c ; eta specific is given by summation of i c .
#  617.1719737375892
#
# 62 We can continue to write this is as summation of eta i c i by c .
#  148.57374883320378
#
# 63 So , in the expression of this m V we just found out that it is having the expression of this .
#  10479.098960721862
#
# 64 Now actually this is supposed to M v , the expression gives you k is eta is k M v to the power a .
#  367.8559071556088
#
# 65 Now this k the slope depends on the molecular rate of polymer ; it is not equal for all the lengths of polymer .
#  4671.326893694941
#
# 66 You change any of this change .
#  3587.9938076931926
#
# 67 So , now you can use this for the mixture of the polymer or interpolymer distribution so that it can be useful , because it is independent of molecular weight .
#  1547.4775673268525
#
# 68 So , I can plot either eta reduced which is nothing but eta s p by c or we can plot eta inherent which is ln into r by c and we will get .
#  1776.0509843932484
#
# 69 A particular class of inhibitor gives you a typical effect on the value of Km or Vm .
#  863.7027850081245
#
# 70 That means the binding site on the enzyme molecule for the substrate is different from the binding site for the inhibitor molecule .
#  38383.25823612755
#
# 71 But only thing is that this ESI complex once formed is catalytically inactive and does not lead to product formation .
#  1018.151638490498
#
# 72 It is only ES complex which will lead to product formation .
#  2640.3224864558238
#
# 73 It does not influence the K2 value , the turn over number , because as we know Vm = K2.E ’ 0 Here E0 , in the presence of non - competitive inhibitor , corresponds to that fraction of total enzyme which is in the form of ES .
#  148.8633898099599
#
# 74 One is the binding process which is not influenced which is elaborated by our dissociation constant .
#  430.7785259679259
#
# 75 It is a dead end complex and then the binding site on the enzyme which is bound by the substrate is not able to give the product .
#  10761.35923892667
#
# 76 Therefore one can determine the value of Ki as we saw in the case of competitive inhibitor by a secondary plot .
#  40.19143498497209
#
# 77 Most of these cases are usually related to bisubstrate reactions particularly because you notice here that the inhibitor binds after the substrate is bound .
#  2212.7446145235012
#
# 78 One of the most commonly observed mixed type of inhibition is what we call as linear mixed type inhibition .
#  267.41015212315546
#
# 79 Such cases are very commonly found and in most of the practical cases they are not usually ideal type of inhibition patterns .
#  1405.8941288910148
#
# 80 ( 1 + I / Ki ) The degree of inhibition will rise from S = 0 when there is no reaction to a limiting value of 1 + I / Ki at very high value of substrate concentration .
#  874.7868163454558
#
# 81 The inhibition patterns obtained for bisubstrate reactions gives you lot of information about the binding pattern of different substrate or the sequence of binding of the different substrate in the case of a multisubstrate reaction .
#  245.06361372225894
#
# 82 In the case of a non - competitive inhibitor KESI will be equal to KEI .
#  58.340098520009555
#
# 83 That means binding to free inhibitor is not feasible .
#  49.69213004239273
#
# 84 Let us just recap couple of minutes on the topics we covered in last lecture .
#  563.9690845780726
#
# 85 If you do a higher reaction at higher temperature then equilibrium concentration comes goes up that means your polymerization reaction stop at a higher free monomer concentration .
#  1114.8803780733626
#
# 86 And if you keep on increasing the temperature , one temperature will come where that equilibrium concentration is equals to the free monomer concentration your know pure pure monomer concentration .
#  134.47969807753034
#
# 87 This is minus 100 , minus 104 , 121 .
#  62.65651934062587
#
# 88 Now , let us compare between first styrene and alpha methyl styrene .
#  20.2994233723091
#
# 89 So , anything you do to stabilize the double bond it will lower the magnitude of the del H p .
#  1057.28498164017
#
# 90 Now , what is the reason that this monomers are difficult to polymerize ?
#  1793.4331988437443
#
# 91 Now , that so we talked about the T c and the values of del H and del S .
#  1098.7145798236766
#
# 92 We , the effect of pressure is not that significant for addition polymerization .
#  792.0250918005657
#
# 93 Now , if for for a polymer getting for polymers getting terminated by combination that means one polymer is getting formed from two kinetic chain .
#  298.1023944405488
#
# 94 Whereas , P is given the probability of the propagation radical will continue to propagate and build polymer which is R p divided R p plus R t and are transfer , where if the polymer is terminated by combination reaction than this gives by this .
#  658.5542238829363
#
# 95 Starting from low molecular weight at the beginning to high molecular weights at the at the end thE distribution goes up .
#  1449.9267008830845
#
# 96 So , you take the monomer you dissolve the initiator and heat the monomer to start the or to initiate the reaction .
#  2945.173182154833
#
# 97 But monomer actually , if you increase the monomer both the reaction rate and the molecular weight goes up and this is the maximum concentration you can do .
#  2445.6910634297706
#
# 98 So , it is sometimes very difficult to take out all the solvents from the polymer quantitively .
#  323.18060046825514
#
# 99 So , what you do initially , you initiate is dissolved in the monomer and then preheated dispersing minimum added .
#  370.3717281370653
#
# 100 Now , you have the monomer droplets along with the initiator molecules has a small droplets which are dispersed in the aqueous solution .
#  5587.250374656816
# 101 One category contains the factor which becomes fixed once an immobilized enzyme is prepared .
#  182.56199697253194
#
# 102 Similarly the catalytic surface to volume ratio is also fixed once an immobilized enzyme preparation is available .
#  1538.1806029267918
#
# 103 You can write down the expression ln S0 / S 1 k ’ 2E0t + = S0 - S Km K ’ m ( S0 - S ) From the equation two if you just simplify you get a straight line equation which can give the values of Km and vm .
#  372.07281078924706
#
# 104 Here I must again put a caution .
#  713.321083105547
#
# 105 When we used the Michaelis Menten equation you will recall that we had made certain assumptions and the assumptions were that we are talking of the initial reaction rate .
#  167.90634452538578
#
# 106 Even while looking at the kinetics of the soluble enzyme we always look at the situations when it comes to extreme substrate conditions .
#  111.35671295413309
#
# 107 Km / S0 will be large and under that condition you must assume a first order kinetics and if the value of Km / S0 decreases the error will continue to increase .
#  1238.339954728466
#
# 108 In the continuous stirred tank reactor one is a continuous flow reactor .
#  33943.82196150915
#
# 109 Similarly here also if you make assumptions of zero order or first order situation when K ’ m is much , much smaller than S0 , that is a zero order system ?
#  670.6595158747828
#
# 110 / S0 which is equal to zero to X dX / - v .
#  22.80316018864654
#
# 111 That means the fluid dynamics in the reactor whether it is a back mix system or its a plug flow system does not influence the reactor performance as long as the reaction is in the zero order regime or the concentration of the substrate is much , much higher than the Km value and you must appreciate that if it is in our limits we will always like to use a very high substrate concentration .
#  1880.6796984602715
#
# 112 That means most of the substrates which is being fed gets converted into product .
#  2091.6506065282124
#
# 113 You take a simple value of 0.5 and if you make calculation for X = 0.90 , the Erel required will be equal to 4.5 .
#  4076.4200738765676
#
# 114 The inference I want to arrive at is that higher the fractional conversion required for a particular reaction under first order regime , the relative quantity of the enzyme required in the CSTR will drastically increase .
#  668.9605007651775
#
# 115 Here instead of Km / S0 I plotted S0 / Km .
#  171.24563248237556
#
# 116 If suppose your substrate is colloidal , we will prefer to use CSTR rather than the PFR ; it will choke .
#  3381.5355790304347
#
# 117 The system is mass transfer limited .
#  35.05011340423561
#
# 118 I think we will stop here and continue to discuss the behavior of enzyme reactors .
#  6349.452776526235
#
# 119 That means the polymer chains are entangled to each other and as they are entangled they cannot be moved independently with each other for example , real life example if I have a bowl of noodles and I ask you to take a spoon , no , one spoon of noodles , you cannot independently take out as a noodles to the spoon because they are entangled .
#  386.4665966545394
#
# 120 So , chains come together so when you take out a noodles you get a junk of polymer or no no pieces of noodles which you take out .
#  609.1115088222155
#
# 121 They must have at least or functionality of two to that means they can be , no , reacted at least from two sides for example , we talked about styrene molecules or ethylene molecules which means they can be extended from two sides .
#  992.4521797152486
#
# 122 If you have a molecules which have only one functionality for example , instead of ethylene glycol you have a phenol molecules , then once this weights of phenol is reacted you , the chain does not goes , you you cannot make a polymers .
#  1051.8732398059842
#
# 123 This is styrene and when it polymerized its gives you polystyrene .
#  9563.61998896229
#
# 124 Now , before going forward let us clarify one thing in a more often or not you know in commonly polymers are referred as plastics .
#  576.1872982532071
#
# 125 Now , there is certain difference between the term plastics and polymer .
#  64.2869878390453
#
# 126 Polymers are most cases thermal insulator which makes it or enables polymers to use in electronic industry and unlike the conventional materials like wood , metal they are optically clear which enables application of polymers in media , and optical devices and one more important that there are so many polymers available in market that you can choose a definite polymer for your particular applications .
#  210.09879205151915
#
# 127 Now , where how do you get these polymers ?
#  2405.158677363007
#
# 128 How this , how the polymer industry works ?
#  411.551835171577
#
# 129 They also do this step , this step compounding step them self .
#  93.16051823213122
#
# 130 There are some smaller industries which make custom polymer products .
#  22.932762809460467
#
# 131 There is a focus also make this polymerization process green and environmental friendly where you avoid use of this toxic chemicals and gases like solvents and other things .
#  31.13275531315833
#
# 132 Polymers are large molecules , which is made from repetition of structural units .
#  7804.974898590859
#
# 133 That is you have to have one of the substrate in a very large excess concentration .
#  463.01315066215386
#
# 134 In a living cell the concentration of the two substrates that are to interact with the enzyme may be almost in an equal or near by concentration levels .
#  307.1339741005062
#
# 135 But in general the action of enzymes on a reaction involving two substrates A and B giving rise to products X and Y is expressed here .
#  5234.530380831176
#
# 136 That means both the substrates are in large quantity and they are able to saturate the enzyme which in concentration terms is much , much smaller than the A or B .
#  1001.2531953686997
#
# 137 There might be some confusion about KA and K ’ A .
#  181.2210697594331
#
# 138 Although they are related it also involves the concentration term of the other substrate which is B and a similar relationship like this when you consider constant concentration of A and the apparent Km for B .
#  5490.336329452012
#
# 139 It is with respect to first substrate binding .
#  145.5793059790293
#
# 140 If you consider the single substrate reaction the dissociation constant of substrate with the enzyme is analogous to Km value , whereas in the case of bi - substrate reaction that situation is not true .
#  3624.3034755540475
#
# 141 At any other V value of B the rate profile will be a hyperbolic profile analogous to that of Michaelis Menten constant .
#  274.81785897441466
#
# 142 If B increases you will get a slope of KA + K ’ A.KB / B Vm The intercept on this factor will be 1 + KB / B Vm So you will notice that both slope as well as intercept of the profiles will decrease as you increase the value of B and ultimately when this B become saturating it will be a typical K value for the substrate A .
#  373.4155102945374
#
# 143 Experimentally the magnitude of KA , KB , K ’ A and Vm can be determined by double reciprocal plot analysis .
#  492.0921311239735
#
# 144 In specific cases they may be equal also .
#  54.476915474232875
#
# 145 The process in this direction is not feasible .
#  1699.6162753908277
#
# 146 We can only react with enzyme only when A has bound to it to form and one of the products is released and the modified enzyme substrate complex is generated .
#  3995.4618184183596
#
# 147 The second substrate has to interact with the binary complex before the first product can arrive at but the stable intermediates are only EA and EY .
#  989.4791523640248
#
# 148 The kind of system we will take for simplicity will be a two enzyme substrate complex formation ES going to ET going to E plus P .
#  831.9080925482244
#
# 149 To illustrate the procedure followed I chose this reaction mechanism .
#  134.87044497232608
#
# 150 They are only the steps which are involved in formation of E .
#  60694.79274367617
#
# 151 Now , we had discussed this , these molecules and their reactivity , now as we are discussing that if the more stable radical will have a tendency to react or undergo transfer reaction compared to the less stable one .
#  1556.5247893469934
#
# 152 So , this stability would be similar to stability of this radical .
#  93.09763849037623
# 153 If for example , if the monomer is electron donor it will have more tendency to react with a solvent which is electron acceptor , whereas if the monomer is a electron acceptor it will have a tendency to react with electron donating solvent , for let us compare between two monomer and two solvent and see whether , we can justify or we can have this verified from the experimental data .
#  7673.298058025894
#
# 154 So , you can justify the values for methyl methacrylate , which is again a electron accepting monomer .
#  1811.4653123566306
#
# 155 That means , this solvents are very poor solvents if you want to build higher molecular weight in the radical polymerization .
#  202.1167467930991
#
# 156 Now , this is a typical example how this common monomers are shift or store , because most monomers when there are shift from between different countries are locally there are stabilized with small amount of this inviters .
#  46.68658272084923
#
# 157 So , it is a example of a retardation there would be four possible , which is a combination of inhibition and retardation something like this a starts at a sometimes as well as the reaction is slower , this happens if we add 0.2 percent nitro benzene .
#  728.2750100779903
#
# 158 Now , we get it once s more time this the expression for k p is just for your reminder that this is this .
#  1084.346335710059
#
# 159 So , we know this now from the experiment and we can find out the concentration of aim as well , so this k p and M dot are the two unknown quantities .
#  2767.594515457808
#
# 160 Now , we know R I is minus d I by d t .
#  1722.874639087105
#
# 161 So , basically there is auto acceleration the rates zooms the rate of polymerization becomes to much accelerated as a results you get a gel at the end .
#  125.83994721908775
#
# 162 So , the kinetic chains have mobility .
#  31.81053193326282
#
# 163 So , you if you draw T g with mole fraction you are going to get like this , so this your glassy part .
#  719.9529922131588
#
# 164 Substrate binding sites are one of them .
#  51391.36240415878
#
# 165 If one of the amino acids is transferred or removed the whole folding will change and primarily involved means those which are physically present on the active site .
#  90.71837945734408
#
# 166 In the case of A and B acting in the absence of any catalyst , in our case we are considering enzyme as catalyst , when the transition state compound is formed there is a loss of entropy .
#  504.0789222524567
#
# 167 This A and B both have to colloid and make an unstable compound .
#  15.970747973507354
#
# 168 Whereas from the enzyme substrate complex to transition state is a totally different phenomenon and the energy required to go from an enzyme substrate complex to transition state is the amount of activation energy required for the reaction .
#  3618.7570374356383
#
# 169 This effect of entropic contribution to the energy of activation is called approximation effect or propinquity effect .
#  380.5565609338379
#
# 170 Not all the collisions result into product .
#  79.06650391185542
#
# 171 When you consider the strain or the distortion of the substrate molecule before it can go into the active site for binding purposes , if the desired bond which has to be broken during the reaction is partially strained or distorted then part of the job is already done .
#  955.9098951110498
#
# 172 That means that this bond is already now partially broken and if this molecule then goes to transition state the energy of activation required will be much less .
#  2753.451194830789
#
# 173 Enthalpic contribution might reduce energy by 2 kcals .
#  37.54197269935604
#
# 174 Lysozyme is an enzyme which breaks down bacterial polysaccharide by virtue of acid base catalysis predominantly .
#  606.9318724342037
#
# 175 They have a covalent bond .
#  563.439198203494
#
# 176 The resulting highly reacting enzyme substrate complex is then attacked by water in the normal cases if it is a hydrolytic reaction .
#  123.76325002642999
#
# 177 In some of the examples in this table you will notice that on the first column you have side chain serine , cysteine , histidine , lysine , aspartic acid and glutamic acid .
#  610.071368329198
#
# 178 A not very frequently encountered effect for reducing the energy of activation is attributed to environmental effects .
#  695.6361160861579
#
# 179 Now , the nature of the additives we must use or we use , must be depended on several parameter ; for example , composition on the polymer .
#  101.11548528493037
#
# 180 And , generally , this small organic additives , they worked by sacrifices , sacrificial mechanism ; by meaning , by terms sacrificial mechanism meaning , that they do destroy themselves and protect the polymer , the main polymer which you want to maintain or retain .
#  548.2683556692259
#
# 181 So , that , they , we can classify the polymers in several ways .
#  716.3006541097159
#
# 182 And , these sides serve as chlorine radical source , which basically initiate the degradation .
#  70.52553456423354
#
# 183 One example , there are many , many additives can be used ; one additives , one type of additives are shown here .
#  15180.054945256927
#
# 184 They convert these unstable arylic , allyl chlorides to non allic , non allyl sites ; and example dibutyl tin disulfides , and their chemical reaction with the allylic double bond is shown here .
#  14.980973852968923
#
# 185 The other additives used for PVC stabilizations , like soaps of cadmium , zinc , barium salts ; and , they act as acid scavengers .
#  2280.107093717875
#
# 186 So , you have a initiator forming a initiator radical which might abstract hydrogen from polymer backbone , forming a radical in the backbone .
#  32.92552185947674
#
# 187 So , we can add the additives which can trap this radical R dot or proxy radicals , which is done by adding primary anti oxidant ; we can increase the rate of termination reaction , which is done by adding hinder diamine .
#  9666.25294250117
#
# 188 There are many many phenolic anti oxidants available in the market .
#  276.03485973407095
#
# 189 Secondary anti oxidants , they are hydro peroxide decomposers ; react with hydro peroxides and produce non radical products .
#  152.9587145895594
#
# 190 They are proven to hydrolyze .
#  44.662446522791896
#
# 191 And , these are the one example of the hydrolysis happening during the processing condition at higher temperature , at higher shear rate .
#  1015.6041985254961
#
# 192 This 2 path is shown here .
#  57.227617708345655
#
# 193 Titanium oxides , it is another UV absorber , which absorbs highly below 370 nano meter .
#  12.67184958076541
#
# 194 I will , in the next lecture , which we will be going to be the last lecture of this course .
#  1324.7263357186705
#
# 195 You have a whole range of small applications in different sectors probably the most prominent among the miscellaneous groups I will like to place is biological …… treatment .
#  220.979914545783
#
# 196 Finally regenerability of the carrier is a factor you will notice in one of the examples which I have given today that although the carrier is very expensive the cost factor here as we have mentioned may be high but if it is regenerable the cost can be taken care and does not contribute very significantly to the overall cost of the process .
#  667.9122400604818
#
# 197 If you notice here some of the experimental conditions , amino acylase was immobilized by ionic binding to DEAE sephadex “0.2M ” concentration of substrate was used containing 5x 10 - 4 M cobalt salt which acts as stabilizing agents , stabilizer for enzymes and reaction temperature was 50 deg C .
#  71.28081398204333
#
# 198 This is the comparison and this is the fraction of the relative cost .
#  5634.570893832742
#
# 199 The cost of production per unit quantity of the product comes down by over sixty nine point of total cost .
#  40.18632170418086
#
# 200 The recovery has improved so per unit cost as a result of raw material consumption has decreased .
#  12.161168665418723
#
# 201 So the labor and the enzyme cost are the major factors .
#  3923.337824514576
#
# 202 I think you may like to go through and I suggest some of the references ; you just go through them ; you will find the experimental details as to how they arrived at the final decisions .
#  286.25683500057016
#
# 203 Here we have 29 % but still 29 % is the highest and probably one has to accept it .
#  1381.1367068100742
# 204 When you take lower substrate concentration , 0.2M the activity loss is much , much higher and over the same period of time instead of 50 % it reaches to about 25 % and this is the case where if you recall we discussed the substrate dependent enzyme decay .
#  774.5208514622101
#
# 205 We discussed two cases of enzyme deactivations during continuous operation of the reactor one was substrate independent where in the earlier case of aminoacylase substrate concentration plays no role and the deactivation constant is predominant but in the case of the aspartase , it is substrate dependent deactivation and higher the concentration of the substrate the operational life is comparatively better .
#  298.07199843618724
#
# 206 In fact most of the products for example the beverages particularly Pepsi and Coke they are based on glucose fructose syrup ; they don ’ t use sucrose as a sweetener because of the use of glucose and fructose syrup in their parent countries their processes need glucose and fructose syrup .
#  1218.829904290856
#
# 207 And , in this lecture , this tenth lecture , I will try to complete the discussion on the different type of radical initiator , which we began in the last lecture , and briefly talk about the initiator efficiency .
#  8589.841130162538
#
# 208 For example , I have molecule like this , or you can have benzyl ketals , benzyl ketals where you have structure of that like this .
#  200.04229937241297
#
# 209 These are the main type of photo initiator or photo chemical initiator used in commercial applications .
#  1341.4494829683597
#
# 210 So , it is , it is very , very useful to application , like film , where you can cover a part of the film , and you can keep part of the film uncovered ; where if you sign light , that part will get polymerized , leaving the part where , which is covered as unpolymerized medium .
#  1448.8348441363657
#
# 211 So , if this photo polymerization method or the radical polymerization by photo initiators sometimes can be used , has a advantage ; this can be used or it is used to apply or used to make polymers in a local or in a , whatever targeted part .
#  3224.338449465641
#
# 212 The other type of possible initiation is the thermally induced self initiation ; that means , the monomer itself , on thermal or on heating can gives rise to , or they can generate radical , but this not a very common way of generating radical ; this is , has been proved only for , in the case of styrene .
#  415.7537596606883
#
# 213 For example , if you take AIBN , you have seen that AIBN on dissociating to this , this species ; now , they can again recombine by reacting with themselves and form these molecule .
#  573.8447849759419
#
# 214 In this case , part of the radicals which were generated by homiletic cleavage of AIBN , they are getting destroyed ; in the sense , they are becoming inefficient , inefficient or dead , non radical species by reacting with themselves .
#  3202.5884459026297
#
# 215 And , we will talk about induced decomposition of initiator ; or , if I have a propagating radical ; now , if give example of benzyl peroxide , it can , the propagating radical can react with initiator molecules and form a another radical .
#  415.44000125537724
#
# 216 So , M is also taken out .
#  32.379383227695584
#
# 217 So , M dot is ; this is the summation of the concentration of all the radicals present ; all the propagating radicals present in the reaction medium .
#  586.274146150343
#
# 218 So , these ; so , R p now given up , given by k p rate constant for all those individual steps , monomer concentration , and this is the summation of the concentration of all the propagating radicals of the , all the chain radicals ; this is the sum of all those things .
#  1268.9934354171353
#
# 219 Disproportionation , 2 of these .
#  34.14078763087031
#
# 220 So , here also we write 2 .
#  651.109448289737
#
# 221 What is , it would look like , for a redox initiator ?
#  19969.31522524562
#
# 222 Now , that indicates that , now that indicates that ; see if we , if the rate of polymerization dependent not directly , not to the power 1 , but more than 1 select 3 by 1.5 ; which means , that this monomer also taking part in generating radicals .
#  1475.3967747070105
#
# 223 So , and which will depend upon the temperature .
#  236.04453757531434
#
# 224 If it is gets terminated by the disproportionation reactions , we seen earlier ; then average degrees of polymerization is nu , because the number of monomers , average numbers of monomers per radical is the size of this chain .
#  526.6584840580556
#
# 225 The most absolute specificity in terms of an enzyme , with which some of you may be familiar , is oxidation of ﬂ - D - glucose to glucono lactone by glucose oxidase a fungal enzyme which is produced by Aspergillus niger .
#  1124.4317179450095
#
# 226 Then we have a number of enzymes which show stereo chemical specificity .
#  335.6728687173241
#
# 227 The specificity can have a very large variety and one must also appreciate that the specificity of these enzymes in terms of their catalytic action is attributed to the active sites .
#  16452.64776175497
#
# 228 But as far as the binding is concerned , it has to be specific in terms of bringing the functional group on which the reaction has to take place .
#  5109.586597077048
#
# 229 The one which binds methyl group will be hydrophobic in nature and this will be bound predominantly by electrostatic interactions .
#  404.23492216793056
#
# 230 Here you have the active site , the sites on which the binding groups available on the substrate binds and this portion shows the substrate which is analogous to the key .
#  9714.465607345082
#
# 231 Your hand is analogues to substrate .
#  1218.0469526760885
#
# 232 But in case where two substrates are involved as in the case of hexose phosphorylation , the role of hexose and ATP both participating at the binding site for the reaction to occur could be explained using induced fit mechanism .
#  510.2277010027454
#
# 233 None of them is able to provide a suitable explanation for the catalytic function .
#  1446.8874603387064
#
# 234 This binding process brings in the specificity and the nature of the binding site or the active site on the enzyme molecule is slightly complementary or of the similar type but not exactly complementary and the complementarity comes only after binding has taken place which results in the distortion of the reacting group and then the complementary comes in .
#  2669.4030936041136
#
# 235 The strain effects have been discussed when we were talking about the ways in which the enzyme reduces energy of activation .
#  57.51323206527418
#
# 236 Because the active site is not exactly complementary , after the substrate approaches the binding sites it forces the reacting group to develop a strain so as to bring in complementary to the catalytic sites .
#  2890.1605276635732
#
# 237 Just coming in proximity could provide you an effect what we discussed like high substrate concentration in the proximity of the active site but does not explain you how the energy of activation is induced .
#  95.71327716832339
#
# 238 There are many other unfavorable interactions available at the active site and these interactions tend to distort the substrate in such a way so that it favors the formation of a complex which is analogues to structure in transition state .
#  435.49307969609373
#
# 239 What is the order of specificity , to what extent it would be specific , what are the impurities which can interfere in the specificity they are all related to the results of reaction that is the rate of formation of product .
#  2784.3129531034115
#
# 240 So obviously you have to produce them on a very small scale and producing on small scale will lead to high cost of production .
#  5523.867162992116
#
# 241 The specificity must be looked in from both the angle and in many cases today people are applying the development of molecular biology particularly in sense of protein engineering to modify the substrate specificity both when we want the absence of side products to make it more specific as well as when we want broad specificity so that the same enzyme can be applied to a large variety of substrates .
#  2775.4825563542427
#
# 242 Now , before we start getting the expression for enthalpy of mixing , just one point just to highlight that this is the expression we received or deduced for entropy of mixing for a polymer solvent .
#  254.18402547965513
# 243 This is what it does .
#  5.948100153898909
#
# 244 If you go back here , each polymer segment , if all of these are , say for argument , all these neighboring cells has solvent molecules , and then it will have z contacts .
#  497.62182324498076
#
# 245 So , that is , what is the chance that each segment would be giving up a polymer solvent contact .
#  166.25296769078864
#
# 246 So , we can write del h m is chi n 1 phi 2 into k T .
#  253.38370760829258
#
# 247 Parameter is basically gives you the difference when a solvent molecule is taken out from a solvent environment and put in a polymer environment .
#  10010.874573161302
#
# 248 One will be transport of the substrate from the bulk to the surface ; from surface the substrate has to transport to the site of the enzymatic reaction which means the enzyme molecules that are located throughout the immobilized enzyme particle and then the reverse process that means the product produced as a result of biochemical reaction has to transport back from the carrier interior to the surface .
#  1732.2762950561046
#
# 249 An important feature of the performance of immobilized enzyme reactor is that one needs to identify the limiting rate , the step which has a limiting rate the lowest reaction rate .
#  12398.58487368266
#
# 250 That means the kind of reactants we have used in immobilization , the kind of matrix we have used in immobilization and whatever the interaction between the matrix and the enzyme under the conditions of immobilization , whatever conformational changes have taken place , whatever kinetic parameters have been modified as a result of this interaction are considered in the inherent parameters and we define them as ví = kí2E0S / Kím + S The parameters are just given prime and the inherent parameters have no role to play or not much can be done during the reactor design or reactor operation .
#  921.4497906682113
#
# 251 l . When you say F is equal to one , there is no effect on the kinetic parameter Km or there is no diffusional limitation in other words .
#  1585.1006444531404
#
# 252 l . Under what conditions ?
#  5603.704417824187
#
# 253 When ? l magnitude is greater than two you can safely take that the reaction is diffusional limited and Kappm equal to Kappm = Kím .
#  539.1827956108388
#
# 254 That means at high substrate concentration when you are talking of ?
#  738.9747437659805
#
# 255 F is one .
#  85.12937699682588
#
# 256 Another way is to look at the Lineweaver - Burk plot .
#  15.869165739845986
#
# 257 1081 , 1974 .
#  1.4276006564774926
#
# 258 Consider another situation in which at the low substrate concentration when ?
#  15.87084485233332
#
# 259 So a change in the activation energy over a range of temperature also indicates the diffusional limitation behavior .
#  1256.4400651320516
#
# 260 Therefore we have three distinct approaches to monitor by experimental methods the effect of diffusional limitation in the case of immobilized enzyme particles .
#  386.4182044121628
#
# 261 kl is the mass transfer coefficient cm / sec .
#  29.479215321523434
#
# 262 The slope of this straight line will be , at low substrate concentration , 1 / klam + Kím / kí2E0 .
#  53091.887601300296
#
# 263 On the other hand the slope here will be Kím / kí2E0 .
#  662.8030056729459
#
# 264 By knowing the two slopes one can calculate klam .
#  3.37080276521511
#
# 265 The difference between the two slopes is the 1 / klam .
#  17.13163464212544
#
# 266 And we just started giving examples , which chain transfer with monomeric species and what we will do .
#  58.7112686556927
#
# 267 But for the examples , monomers like styrene , it will be only one double bond possible because in case of styrene you have only one possibilities of beta transfer .
#  281.4567303032206
#
# 268 Similarly , in this case , this can again reinitiate a cationic polymerization .
#  3987.1727973153543
#
# 269 Now , there could be some agents , reagents present , like in case of radical chain polymerizations where this reagent actually can slow down the cationic chain polymerization considerably .
#  138.45921877751184
#
# 270 We are not considering for this kinetic expression , the other time transfer reaction , so we can write k t IZ .
#  2230.609954263834
#
# 271 It , the activation general propagation will of course , depends on the initiator or coinitiator and the solvent .
#  95.06250663847753
#
# 272 Now , typically E transfer is higher than E p , so which means , that with T , with increase in , decrease in temperature C also goes down , which means , X n goes up .
#  12193.520209619139
#
# 273 If it is negative , then with decreasing temperature you get increase in polymerization rate , but if it positive , then with decrease in temperature you get reduction in the polymerization rate .
#  379.1708785981379
#
# 274 And as we know , that the reactivities of the free counterions or the solvent separated counterions are much different than tight iron - pairs .
#  129.64851738127518
#
# 275 Now , you have to maintain moisture free environment and if you , and if you are actually using H 2 as a cocatalyst , then we should add H 2 O in the symmetric amount with respect to the catalyst because moisture or H 2 is present in excess than what you desired as a cocatalyst .
#  368.15430748009106
#
# 276 And generally , E R , the activation of is positive , small positive .
#  28.775580451952216
#
# 277 Most important is using alkyl lithium .
#  33.963235715163144
#
# 278 Other initiations possible by electron transfer , electron transfer , for example , reaction between sodium and naphthalene .
#  290.4355748295871
#
# 279 This is the example of how initiation is done with electron transfer .
#  379.29301005504493
#
# 280 So that means it is active .
#  36.83192040219011
#
# 281 Similarly in case of enzyme loading we talk of international units per gram of carrier or if you take into account the bulk density of the carrier you can also say international units per ml of carrier bed that means you pack the carrier into a bed , packed bed , and then consider the volume .
#  1616.1712086282505
#
# 282 Very often even after the immobilized enzyme preparation has been exhausted during use the carrier can be recovered and reused .
#  2341.5984213170386
#
# 283 Weak binding in the sense while during use , the enzyme can also dissolve slowly over a long period of time and if the carrier characteristics are sturdy they can be regenerated and reused .
#  832.0355112738597
#
# 284 If the enzyme is stable at 70ºC , 70ºC is acceptable and can be considered as mild .
#  48.66057226416596
#
# 285 Again when I say the term high it refers in the comparative form and the comparison here is with covalent binding .
#  22.82991268734014
#
# ...
#  191.9688363656046
#
# 918 Hence K s c would be given by e to the power del S 0 p p by R .
#  1006.4966887283322
#
# 919 So , we can simply write from these two , V is V 0 plus V i e to the power minus A s L dash by 2 .
#  111.31919299341676
#
# 920 So , the output signal in this detector is proportional to the concentration and if we assume that detector response is proportional to the concentration in the range we are working , and also this response does not depend on molecular weight .
#  1229.6520938927715
#
# 921 So , this is the weight fraction between the polymer which eluted and they can be written like this where a is the area under this curve ; and if we do interrogation and followed by normalization we can get this weight fraction molecular weight distribution in the form .
#  12692.284290059442
#
# 922 So , the polymer which are same type used and calibration .
#  92.37102967879737
#
# 923 So , preferably we use longer column ; typically in normal sense , we actually use few column in series and some cases to make the process faster ; we mix bed type columns are used where you have the columns are made with different pore size and you can use two such or three such mix bed columns in series or a single different pore size columns also in series .
#  194.4490236570002
#
# 924 So , it is preferable that the column is kept in a constant temperature ; obviously , the sample loading is small from a very dilute solution ; specially , when you are using detectors like light scattering and viscosity there we are assumption the solution is very dilute .
#  516.9082175436589
#
# 925 So , that we can consider the specific viscosity divide by c as an intrinsic viscosity and the molecular obtained by light scattering ; there will be less error .
#  3925.3767857386943
#
# 926 So , what is the modification done to get the mass spectroscopy polymers ; one soft ionization mechanism is used where will come in a minute using matrix assisted laser desorption ionization or MALDI by which the polymers are vaporized with the help of a matrix without degradation and we also use the second technique called time of flight mass spectroscopy ; and in combination of these two techniques we get MALDI TOF MS matrix assisted laser desorption ionization , time of flight mass spectroscopy which is nowadays very important or very common for polymer samples .
#  617.0522114296207
#
# 927 So , this name MALDI comes from there .
#  30.883344780633134
#
# 928 So , in MALDI , choosing of matrix is very critical and it needs to optimize for every polymer samples .
#  136.0336583514475
#
# 929 For oliphinic polymers like polyethylene , polypropylene , it is very difficult to find a cation which might complex with these oliphinic polymers ; it is very difficult to cationize and then analyze this polymers by MALDI ; and water soluble polymers already which does not soluble in a solvent is also very difficult .
#  309.0057388696499
#
# 930 So , this keeps the entire distribution ; this is the normalized intensity and if you look at the gaps between the molecular ions you can see the gaps is 100 Dalton which is exactly the mass for a MMA repeating unit .
#  111.16205571903674
#
# 931 And from this distribution the different molecular weight like number average molecular weight , weight average molecular weight and other molecules can be directly obtained .
#  1740.10568930184
#
# 932 So , just all this benefits , but the only disadvantage is that the price of MALDI TOF is very high .
#  309.85813532359094
#
# 933 The two factors on which the classification of enzyme reactors can be based are on the mode of charging and discharging of substrate and product stream and also physical configuration .
#  1147.7423460877417
#
# 934 There are options where even soluble enzymes can be used in a continuous reactor but for practically most applications the use of soluble enzyme is usually with the batch reactors .
#  123.25290196843366
#
# 935 In the example I cited a little ago on the hydrolysis of penicillin to 6 - APA because of simultaneous acid production you need to control the pH otherwise the enzyme gets inactivated and a very precise control of pH is needed and therefore addition of the alkali simultaneously is a must and which can be carried out very easily in a stirred batch reactor and with a control system you can control the pH .
#  3870.2153589431864
#
# 936 For a perfect total recycled reactor to be considered as a batch reactor operation the requirement should be that the total recycled time must be very small or negligible compared to the total batch cycle ; that is the recycling has to be very fast .
#  1163.4624414827388
#
# 937 The concentration profile of the feed at any given cross section of the reactor is flat .
#  6440.924568104699
#
# 938 This will be a function of the particle shape and size .
#  488.527842908015
#
# 939 That is the reactor output instead of going directly to the product stream passes through ultra filtration unit in which the product stream is filtered out and can be taken out of the product stream while the retentate which contains mainly the enzyme is recycled back into the reactor .
#  2165.608502887006
#
# 940 That means the substrate can go into the vicinity of the enzyme and product can go out and ultimately the product stream can be taken out but the enzyme cannot go out of the ultra filtration tubes and such a reaction system has an advantage that you can use such a system as a continuous plug flow reactors even using the soluble enzymes .
#  inf
#
# 941 When you say when you are immobilizing on the walls of the tube then they don ’ t operate really on the hollow fiber reactor .
#  346.97112227890955
#
# 942 It is retained in the semi permeable hollow fiber tubes so that it is not able to go out almost similar to microencapsulation where the enzyme is contained in the forms of tubes .
#  1665.5628260975075
#
# 943 So the combined CSTR coupled with the ultra filtration reactor can be easily used .
#  502.0818792334927
#
# 944 during continuous use .
#  144.13149670147112
#
# 945 Before we go into the reactor performance of different types of reactor for the immobilized enzyme systems , we cannot normally consider all the parameters like non - ideal fluid dynamics , the mass transfer constraints and along with the biochemical reaction we cannot really combine at one stage .
#  359.74868364951436
#
# 946 The first one is “tau ” which is the reactor space time in terms of V / Q .
#  3036.2490768015464
#
# 947 When I say E0 , I think it will be desirable to also have the magnitude of kd , the deactivation constant .
#  571.2962309064657
#
# 948 Then pH ; pH here is not only monitoring but more important is the control of pH .
#  448.57270251558697
#
# 949 That means the concentration difference ; substrate concentration between the inlet and the outlet stream , the ratio of the two .
#  457.6834470154183
#
# 950 So , I can write q for m 1 q for m 2 for 1 , 1 , 1 e m 2 , you can get the expression from k 1 1 for k 1 1 k 2 and so the ratio you get these two , this because is the same radical 1 and 1 .
#  9271.366412604388
#
# 951 So , if I can write , similarly for r 2 Q now because Q is always talking about related to monomer .
#  15.916776750872328
#
# 952 So , r 1 , r 2 will be given by if we can multiply these two given by exponential minus e 1 minus e 2 square .
#  2159.466566469823
#
# 953 Now , obvious this is Q is measure of reactivity as we have seen and e is measure of electrostatic charge .
#  84.15000124496098
#
# 954 So , brittle that if this copolymer does not have a significant improvement over , over the polystyrene molecule homo polymer in terms of brittleness .
#  142.01865640265035
# 955 The other examples , but I am not spending much time on discussing those applications here .
#  1574.942330015844
#
# 956 Now , the feasibility of this polymerization from a ring to linear product linear monomer to polycyclic monomer to a linear product , like all other reactions depends both on thermodynamic and thermo dynamic and last kinetic factor .
#  213.1459598479574
#
# 957 Basically this is saturated ring and there is no place where u can carry out a electrophilic or neutrophillic character by external and open the ring , and then carry out the polymerization .
#  89.51940306146012
#
# 958 So , basically all have a hetero atom in the ring , whether it is a or ester or amides whatever is the case .
#  671.2424836440657
#
# 959 Now , poly ester poly amides are typically synthesized we have discussed earlier they are synthesized by stiff polymerization , but in this case we are making the same types of polymers , which we knew till now that they are typically synthesized by step growth polymerization .
#  3785.516943112445
#
# 960 So , the chain keep on propagating there is no reaction between two monomers or there is no reaction between two high molecular polymer chain as well .
#  1226.6011653462604
#
# 961 So , you can make block of polymers of functional polymers at the end of the reaction , and in this case unlike a linear polymerization of the vinyl molecules , polymerization de polymerization equilibrium is very important .
#  305.593850501323
#
# 962 If you want to terminate the reaction you can exchange these with a say adding some water or alcohol , and then you can exchange like other we discussed earlier .
#  713.5574364262003
#
# 963 Similarly , if we have little bit of moisture present in the medium or if you have water molecules , then this will easily compete with your monomer with oxinium ion and then terminate the or disrupt the reaction immediately .
#  224.61772811895415
#
# 964 Ultimately it can reach the same kind of saturation behavior but the initial profile will be different in the case of a sigmoidal profile .
#  419.8516043653934
#
# 965 Similarly in the case of hydrolysis of sucrose by invertase also by one of the possible mechanistic models when one substrate molecule binds , the enzyme substrate complex leads to a product formation .
#  2346.947948635282
#
# 966 Notice the two terms which I have highlighted here .
#  215.0474934551182
#
# 967 Identical means the catalytic sites have identical free energy change of binding .
#  554.8826036272899
#
# 968 They don ’ t influence the binding to other site .
#  3.7097100679947133
#
# 969 The only difference is here the definition of Vm must be taken as 2K2 .E0 or in another words if it is a multimeric protein or enzyme where n binding sites are there , it can become n.K2.E0 Otherwise the treatment can be identical as in the case of a hyperbolic profile .
#  1240.4491234089821
#
# 970 The first binding site is free for all the substrate molecule and once this is bound if it makes a change on the confirmation of the other binding sites such that the affinity of the substrate to the binding site gets altered , if you want a positive favorable effect , the affinity must increase or the Km value must decrease , dissociation constant must decrease .
#  461.526880668374
#
# 971 All of you know probably with your background in the biochemical metabolism that with each metabolic path way you have certain regulatory enzymes which behave in allosteric manner .
#  496.1362745295976
#
# 972 For the two enzymes to act , in the early phases when substrate concentration increases from zero to three arbitrary units whatever are the units , in the case of sigmoidal kinetics the reaction velocity is only 0.1 in some arbitrary units .
#  5463.150191643144
#
# 973 In the case of living cells the intercellular concentration of substrate does not change over a very large range .
#  1826.556098260255
#
# 974 This is something like an extension to that and which means that when the substrate molecule binds on one of the binding sites of the enzyme it immediately triggers off a conformational change whereby the affinity for the next binding site becomes much higher and they expressed it with an interaction factor .
#  1757.516311672872
#
# 975 The conformational change leads to the dissociation constant or Michaelis Menten constant for the second binding site and then second binding site also gets bound .
#  2686.8105189440203
#
# 976 This K ’ is different than the Michaelis Menten constant .
#  19.594976691419063
#
# 977 Or S0.5 substrate concentration for 50 % maximum reaction velocity is nvK ’ .
#  188.04403984230072
#
# 978 Now , how to get more information with we can deduce from this .
#  526.5626218918245
#
# 979 So , this curve now is for theta is equals to 0 and this is for c equals to 0 .
#  33.721377982242004
#
# 980 Why we extrapolate ?
#  2.171117060134879
#
# 981 So , this is known as zimm plot ; this is very unique way of plotting this three dimension 3 d data into two dimensional using the help of a arbitrarily chosen constant and we can get this information from this zimm plot .
#  562.2812331472414
#
# 982 One is the solvent and the solute solution all the polymer solution should be absolutely dust free ; otherwise , the dust particles will scatter light that will interfere and give error in the your final result .
#  493.4372471941847
#
# 983 Now , it is the lambda we are using , because what happened if the size of the scatterer or the polymer molecule or the other scatterer is very high and the respective interference between the scattered light from different part of the solute becomes so much that even at a little higher theta , this becomes 0 ; the value of P theta becomes 0 .
#  2897.967075052332
#
# 984 So , it is very difficult to get accurate measurements of i theta for those cases .
#  43.93237470308631
#
# 985 So , here we detect the scattering from very small volume at very small time intervals ; this is what we do ; delta T which varies from microseconds to milliseconds and then correlate the scattering intensity fluctuations with time .
#  47.30965857114445
#
# 986 Today we will be discussing some of the characteristic features of enzymes particularly as proteins and their chemical nature .
#  349.31390563203513
#
# 987 One could determine by any method that is known to us and I will talk about it a little later .
#  1726.802236418676
#
# 988 The other way could be and which is probably more important for assay of an enzyme is its catalytic function .
#  919.0704179359723
#
# 989 One of the limitations is that this is not a SI unit which is an internationally accepted system of units .
#  367.4036796271939
#
# 990 The most simple system probably you are familiar is by ultra violent absorption .
#  468.24309739761753
#
# 991 Another method is biuret method which is based on the reduction with alkaline Copper sulphate solution which contains sodium potassium tartrate and the cupric ions form a co - ordination complex with the amino groups or the - NH group present in the peptide bond .
#  129.14013390912845
#
# 992 At a low pH the molecule will act like a cation and as we increase the pH it will be negatively charged and it will behave like anion and some where in between there will be a zero net charge that means it will have both positive and negative charge of equal magnitude , what we call as zwitterion in the case of amino acids .
#  443.50134155083435
#
# 993 The molecule is very compact .
#  668.0100917859286
#
# 994 Most important non covalent interaction which involves in the conformation of the protein molecule is hydrogen bonds , very large number of hydrogen bonds .
#  289.7948675319391
#
# 995 That means when you consider the wet side , on the surface there will be most of the charged groups and most of the non polar side chains will be located inside the three dimensional molecules .
#  1397.3607993094492
#
# 996 It doesn ’ t mean that on the surface there are no hydro phobic patches .
#  1130.2727387499021
#
# 997 Then this chain can fold itself locally in the shape of either an alpha helix or a pleated sheet so as to give a secondary structure .
#  7450.8897968026795
#
# 998 This alpha helix and other type of conformation which many proteins will have will be again as the result of hydrogen bonding will be in the form of beta pleated sheet .
#  527.7835987118043
# 999 The disruption of the non covalent interaction is good enough to lead to denaturation .
#  76.30637000052297

# %%
tech_corpus_wb = []

for i in range(len(test)):
    perp = find_perp(test[i] , train_freq ,total_tokens ,'wb')
    
    print(stmts[i] ,perp)
    print()
    tech_corpus_wb.append( [stmts[i] , perp])
# Out:
# Now , why do we started our discussion on chain polymerization ?
#  4.133339291740594
#
# Now , this anionic species or cationic species , they are not present alone in the medium , they are always associated with or accompanied by a counter ion .
#  11.351944386557843
#
# This ketone loop complex form complex with this ionic species and then once they form complex , the reactivity of this ionic species are lost .
#  11.378820658431678
#
# So , as the reactivity of the ionic centre , obviously , the free is the ionic center it gets , it becomes more reactive .
#  9.67806224148965
#
# And if you compare with radical chain polymerization , solvent polarity actually has no such role to play in case of radical chain polymerization .
#  5.546744640012036
#
# Because they have seen this propagation species are similarly charged , they cannot react with each other and terminate the chains .
#  10.314919392706834
#
# As a result , there is a huge increase in the concentration of these active centers in the medium and as a result , the reaction is very fast .
#  16.764739540683866
#
# So , I should write cationic chain polymerization .
#  5.700327928338126
#
# So , if you consider this case the reaction happens like this .
#  9.185980027660612
#
# This is I and which then react with a monomer forming the chain initiating spices .
#  10.25438638992621
#
# So , it follows this trend and for the carbon cationic generator like RCl , like AlCl 3 plus , this reaction .
#  11.37941755006036
#
# So , we talked about the initiator reaction with by this reaction of the monomers with the electrophile .
#  9.09548687019222
#
# But as I mentioned in earlier , these are the generic examples , which we get in this page .
#  19.307548354578664
#
# When you increase the polarity by adding ethylene dichloride , dichloethane , EU , say in 40 - 60 mixture , your dielectric constant goes up , your reaction goes up .
#  4.476003227432967
#
# You do film diffusion klam can be computed .
#  2.4279098816572184
#
# A JD factor has been defined in the case of heterogeneous catalysis in general and which applies very well to even enzyme catalyzed reaction .
#  12.426087488922425
#
# Based on the operational data that means the concentration of substrate in the feed and the product stream as well as the parameters of the reactor operation and the particle size , one can determine the length of the reactor required and if this length of the reactor required is relative to the length of the reactor required for biochemical reaction , if you compare this height required , let us say this is Z1 to that of the height required Z2 based on biochemical reaction if you calculate idealized reactor performance equation and calculate the height of the reactor required and compare the two values that gives you an identification whether film diffusion is controlling or not .
#  14.118599982993167
#
# All the enzymes are present on the surface and in the thin film there is no reaction taking place .
#  9.447557484243628
#
# which is called as effectiveness factor .
#  6.877762969375675
#
# This effectiveness factor is the ratio of the rate of actual reaction in the matrix divided by the maximum reaction rate obtainable if there was no pore diffusional resistance .
#  12.987419932103617
#
# Ultimately when you will measure the enzyme activity you will see that the enzyme activity is low because per unit enzyme loading the activity which will be expressed by the immobilized enzyme particle will be lower .
#  13.573026429613131
#
# At the moment we are talking only of mass transfer and biochemical reaction .
#  6.097445295967901
#
# In today ’ s lecture we planned to cover interfacial polymerization , and we also will be talking about different synthesis of different step polymers in very brief briefly .
#  12.953168105665286
#
# And when a reaction has progressed some for some duration and then duration there is a chance that monomers might form dimer or small molecular weight , oligomers .
#  6.51067031155537
#
# So , that will again reduce the molecular weight build up .
#  7.8039833406593955
#
# And sometimes the catalyst , which you are using in the reaction that might be one source , which might be catalyzing the side reactions as well .
#  10.235484813185002
#
# And I will come to the example of interfacial and polymerization .
#  11.37605671035321
#
# So , what is done to tackle this problem a tri a amine is added in the organic medium , say triethylamine or trimethylamine and when this reacts with this species it is form a salt now this is water soluble .
#  12.279751311060162
#
# So , what are the requirements for a successful inter polymerization interfacial polymerization you need to have a inorganic base , which you require to neutralize the produce HCl otherwise HCl with go back and hydrolyze the salt .
#  11.940211764657459
#
# So , you know increasingly people are trying to avoid this root simply to avoid this use of large amount of organic solvent , which are not environmentally friendly .
#  5.682273176865518
#
# We will move to the next class of polymers step polymers polyamides and we have this is linear poly polymerization reactions this is aliphatic diamine with aliphatic diacid you can directly under go reaction to form linear polyamide .
#  9.95664398808765
#
# So , you can first stage you do a step polymerize to syntheses this and then you can take this and do a second step of chain polymerization either by oxidizing this or no using the other methods .
#  8.560717540487964
#
# There are also amorphous T g is very high and their continuous use temperature is 300 to 350 degree centigrade temperature .
#  8.740838243403594
#
# This is another example another set of polymers is polyamide imides you take this aromatic diamines with one side poly anhydride and the carbo oxalic acid silica acids to form this amide polyamide imides .
#  6.789048964497807
#
# And butylene glycol group butylene glycol group always next to each other will we expect that or will you expect that there be will random copolymers .
#  10.252028293123272
#
# Then you will always land up in a completely random copolymer , you understand why , because this reaction when they are happening there is slow reaction .
#  14.152582807506093
#
# Because , they very fast reaction once the product is formed the byproduct HCl is getting neutralized with sodium hydroxide , which means there is one reaction is formed .
#  12.95239952386193
#
# If there are significant differences in the reactivity of the two diols then there will be a blocky nature in the copolymers .
#  9.11734179577976
#
# At the end of the immobilization enzyme preparation retention of catalytic activity is a major requirement .
#  3.89748242543451
#
# So when we say retention of catalytic activity you are implying that a major fraction of the activity must be retained .
#  6.198340388886941
#
# One limitation will be that the product has to be a low molecular product .
#  8.675327909073378
#
# In living cell also the enzyme is entrapped through a semi permeable membrane which does not allow the enzyme molecules to pass through and some of the product molecules from the cell also are usually ripped off .
#  10.711280536911488
#
# One is that the scientist wanted to apply some of the enzymes for industrial processing and obviously for industrial processing you need certain operational advantages The major disadvantages in the case of the enzymes is the restriction in the best mode of processing , the stability , some of the physico chemical properties in respect of pH optimum , temperature optimum , substrate specificity and they could all be taken care for industrial processing .
#  12.122802280690856
#
# When I say physico - chemical properties the most important properties probably for which enzymes are considered as poor candidates are their stability .
#  5.166969994085995
#
# In fact any immobilized enzyme system has three major constituents , three major players The first player is the soluble enzyme .
#  5.571318029140447
#
# What are the properties we look at when we choose a soluble enzyme ?
#  5.656886133614425
#
# If your environmental pH is alkaline , seven plus , the isomerisation can take place naturally and the isomerisation product will not be only fructose but it will be plus few other hexoses which will be produced and the whole advantage of using an enzymatic process is lost .
#  6.856743335686389
# Bulk of the immobilization enzyme product will be in the form of carrier .
#  15.00535159559924
#
# This will require many of the functional groups to be present on the carrier .
#  12.165453223114552
#
# Large varieties of carriers have been used and are available for use fortunately and these carriers have been classified by various people in different modes , in different forms .
#  10.685439630017818
#
# The non - porous carriers will have a low specific surface area because the porous matrix will provide lot of internal surface in a matrix .
#  5.110066956515605
#
# Then in the case of proteins almost like what we talked about gel structure , collagen and gelatin are typical examples and there is a whole range of synthetic polymers which have been reported and used for immobilizing enzymes which are usually polystyrene based , vinyl polymers , polyacrylamide and so on.You can classify and a large variety of carriers are available for use for immobilizing enzymes and the choice will depend upon various properties that we have listed .
#  14.34573554894534
#
# And if time permits we will continue and discuss the method of dilute solution viscometry by which we can determine viscosity average molecular weight .
#  10.854135361483252
#
# And eta s p you know if you recollect ; eta s p is eta r minus 1 , eta by eta 0 minus 1 .
#  11.75895678067732
#
# So , hydrodynamic volume will be lower in this case .
#  6.050481085316134
#
# Now this r we said it is proportional to the radius of gyration .
#  6.956430024413146
#
# So , we can write that intrinsic viscosity is proportional to ; the proportionality sign is also missing here is V h which is proportional to this term divide by M .
#  10.937222732139832
#
# So if you change any of these three polymer solvent and temperature , then k and a value will be changed .
#  7.314714096272253
#
# Now k increases with the value of a for flexibility ; typically you have seen it has been seen that k also increases with the increase in the value of a and it is typically around this range .
#  18.134221930519633
#
# So , the expansion factor will be ; if you compare the expansion factor of unperturbed linear polymer chain it may go down below that below one .
#  14.529488902459079
#
# You know this assumption is reasonably okay to do is one ; the eta specific viscosity is given by the summation of the specific viscosity of the individual chains .
#  19.105219093845385
#
# So now , we can find out the expression for the intrinsic viscosity for the polymer sample which is the mixture of all the polymer chain which is given by limit c tends to 0 eta specific by c ; eta specific is given by summation of i c .
#  12.345011664350892
#
# We can continue to write this is as summation of eta i c i by c .
#  7.715860395582611
#
# So , in the expression of this m V we just found out that it is having the expression of this .
#  18.896134799060174
#
# Now actually this is supposed to M v , the expression gives you k is eta is k M v to the power a .
#  10.142343983869925
#
# Now this k the slope depends on the molecular rate of polymer ; it is not equal for all the lengths of polymer .
#  10.577623662889742
#
# You change any of this change .
#  5.4911991599543395
#
# So , now you can use this for the mixture of the polymer or interpolymer distribution so that it can be useful , because it is independent of molecular weight .
#  13.441272022579913
#
# So , I can plot either eta reduced which is nothing but eta s p by c or we can plot eta inherent which is ln into r by c and we will get .
#  8.19579451538606
#
# A particular class of inhibitor gives you a typical effect on the value of Km or Vm .
#  8.346037131746947
#
# That means the binding site on the enzyme molecule for the substrate is different from the binding site for the inhibitor molecule .
#  16.726998332085326
#
# But only thing is that this ESI complex once formed is catalytically inactive and does not lead to product formation .
#  8.072208483380573
#
# It is only ES complex which will lead to product formation .
#  5.489349358052524
#
# It does not influence the K2 value , the turn over number , because as we know Vm = K2.E ’ 0 Here E0 , in the presence of non - competitive inhibitor , corresponds to that fraction of total enzyme which is in the form of ES .
#  6.028080537832057
#
# One is the binding process which is not influenced which is elaborated by our dissociation constant .
#  5.818657082756466
#
# It is a dead end complex and then the binding site on the enzyme which is bound by the substrate is not able to give the product .
#  17.447295554424223
#
# Therefore one can determine the value of Ki as we saw in the case of competitive inhibitor by a secondary plot .
#  3.9632456192195815
#
# Most of these cases are usually related to bisubstrate reactions particularly because you notice here that the inhibitor binds after the substrate is bound .
#  11.059913248595992
#
# One of the most commonly observed mixed type of inhibition is what we call as linear mixed type inhibition .
#  6.363099323945895
#
# Such cases are very commonly found and in most of the practical cases they are not usually ideal type of inhibition patterns .
#  6.728800659627235
#
# ( 1 + I / Ki ) The degree of inhibition will rise from S = 0 when there is no reaction to a limiting value of 1 + I / Ki at very high value of substrate concentration .
#  6.994979744857579
#
# The inhibition patterns obtained for bisubstrate reactions gives you lot of information about the binding pattern of different substrate or the sequence of binding of the different substrate in the case of a multisubstrate reaction .
#  7.871894056200756
#
# In the case of a non - competitive inhibitor KESI will be equal to KEI .
#  2.6102922823768293
#
# That means binding to free inhibitor is not feasible .
#  6.844764218518452
#
# Let us just recap couple of minutes on the topics we covered in last lecture .
#  5.398714232901678
#
# If you do a higher reaction at higher temperature then equilibrium concentration comes goes up that means your polymerization reaction stop at a higher free monomer concentration .
#  11.351517113430084
#
# And if you keep on increasing the temperature , one temperature will come where that equilibrium concentration is equals to the free monomer concentration your know pure pure monomer concentration .
#  6.306141833615471
#
# This is minus 100 , minus 104 , 121 .
#  4.382692773465124
#
# Now , let us compare between first styrene and alpha methyl styrene .
#  2.8417926472132584
#
# So , anything you do to stabilize the double bond it will lower the magnitude of the del H p .
#  9.687778591548476
#
# Now , what is the reason that this monomers are difficult to polymerize ?
#  11.904003647508954
#
# Now , that so we talked about the T c and the values of del H and del S .
#  8.975468050359185
#
# We , the effect of pressure is not that significant for addition polymerization .
#  14.837179120882531
#
# Now , if for for a polymer getting for polymers getting terminated by combination that means one polymer is getting formed from two kinetic chain .
#  14.962733065739961
#
# Whereas , P is given the probability of the propagation radical will continue to propagate and build polymer which is R p divided R p plus R t and are transfer , where if the polymer is terminated by combination reaction than this gives by this .
#  14.467305828872096
#
# Starting from low molecular weight at the beginning to high molecular weights at the at the end thE distribution goes up .
#  6.049497433250277
#
# So , you take the monomer you dissolve the initiator and heat the monomer to start the or to initiate the reaction .
#  25.082958688710434
#
# But monomer actually , if you increase the monomer both the reaction rate and the molecular weight goes up and this is the maximum concentration you can do .
#  10.689822679992037
#
# So , it is sometimes very difficult to take out all the solvents from the polymer quantitively .
#  4.514060109926545
#
# So , what you do initially , you initiate is dissolved in the monomer and then preheated dispersing minimum added .
#  6.006397720311793
#
# Now , you have the monomer droplets along with the initiator molecules has a small droplets which are dispersed in the aqueous solution .
#  12.564578369339756
#
# One category contains the factor which becomes fixed once an immobilized enzyme is prepared .
#  13.777113751769493
#
# Similarly the catalytic surface to volume ratio is also fixed once an immobilized enzyme preparation is available .
#  8.724126729889601
# You can write down the expression ln S0 / S 1 k ’ 2E0t + = S0 - S Km K ’ m ( S0 - S ) From the equation two if you just simplify you get a straight line equation which can give the values of Km and vm .
#  10.114656862687113
#
# Here I must again put a caution .
#  11.605102592686553
#
# When we used the Michaelis Menten equation you will recall that we had made certain assumptions and the assumptions were that we are talking of the initial reaction rate .
#  6.642329488584853
#
# Even while looking at the kinetics of the soluble enzyme we always look at the situations when it comes to extreme substrate conditions .
#  10.233911783532607
#
# Km / S0 will be large and under that condition you must assume a first order kinetics and if the value of Km / S0 decreases the error will continue to increase .
#  9.570380549167165
#
# In the continuous stirred tank reactor one is a continuous flow reactor .
#  14.34587008315085
#
# Similarly here also if you make assumptions of zero order or first order situation when K ’ m is much , much smaller than S0 , that is a zero order system ?
#  7.057169857096608
#
# / S0 which is equal to zero to X dX / - v .
#  3.1045142976924174
#
# That means the fluid dynamics in the reactor whether it is a back mix system or its a plug flow system does not influence the reactor performance as long as the reaction is in the zero order regime or the concentration of the substrate is much , much higher than the Km value and you must appreciate that if it is in our limits we will always like to use a very high substrate concentration .
#  13.408514625199548
#
# That means most of the substrates which is being fed gets converted into product .
#  5.562640122131074
#
# You take a simple value of 0.5 and if you make calculation for X = 0.90 , the Erel required will be equal to 4.5 .
#  9.553456443316795
#
# The inference I want to arrive at is that higher the fractional conversion required for a particular reaction under first order regime , the relative quantity of the enzyme required in the CSTR will drastically increase .
#  13.68711518223447
#
# Here instead of Km / S0 I plotted S0 / Km .
#  9.335799615447012
#
# If suppose your substrate is colloidal , we will prefer to use CSTR rather than the PFR ; it will choke .
#  6.90888535861711
#
# The system is mass transfer limited .
#  2.7540856069333235
#
# I think we will stop here and continue to discuss the behavior of enzyme reactors .
#  18.864908862149722
#
# That means the polymer chains are entangled to each other and as they are entangled they cannot be moved independently with each other for example , real life example if I have a bowl of noodles and I ask you to take a spoon , no , one spoon of noodles , you cannot independently take out as a noodles to the spoon because they are entangled .
#  9.831187109213937
#
# So , chains come together so when you take out a noodles you get a junk of polymer or no no pieces of noodles which you take out .
#  8.338895422341674
#
# They must have at least or functionality of two to that means they can be , no , reacted at least from two sides for example , we talked about styrene molecules or ethylene molecules which means they can be extended from two sides .
#  12.683668133822819
#
# If you have a molecules which have only one functionality for example , instead of ethylene glycol you have a phenol molecules , then once this weights of phenol is reacted you , the chain does not goes , you you cannot make a polymers .
#  9.660550445986635
#
# This is styrene and when it polymerized its gives you polystyrene .
#  8.040241541900551
#
# Now , before going forward let us clarify one thing in a more often or not you know in commonly polymers are referred as plastics .
#  11.130452432884416
#
# Now , there is certain difference between the term plastics and polymer .
#  6.102325444960395
#
# Polymers are most cases thermal insulator which makes it or enables polymers to use in electronic industry and unlike the conventional materials like wood , metal they are optically clear which enables application of polymers in media , and optical devices and one more important that there are so many polymers available in market that you can choose a definite polymer for your particular applications .
#  9.648207223217538
#
# Now , where how do you get these polymers ?
#  15.219055889651798
#
# How this , how the polymer industry works ?
#  8.003513667597804
#
# They also do this step , this step compounding step them self .
#  7.52155560150211
#
# There are some smaller industries which make custom polymer products .
#  3.724785900544635
#
# There is a focus also make this polymerization process green and environmental friendly where you avoid use of this toxic chemicals and gases like solvents and other things .
#  5.09670441972169
#
# Polymers are large molecules , which is made from repetition of structural units .
#  10.408479548786378
#
# That is you have to have one of the substrate in a very large excess concentration .
#  8.297684723141964
#
# In a living cell the concentration of the two substrates that are to interact with the enzyme may be almost in an equal or near by concentration levels .
#  14.171759717495688
#
# But in general the action of enzymes on a reaction involving two substrates A and B giving rise to products X and Y is expressed here .
#  12.834917026493903
#
# That means both the substrates are in large quantity and they are able to saturate the enzyme which in concentration terms is much , much smaller than the A or B .
#  14.226916954188852
#
# There might be some confusion about KA and K ’ A .
#  6.28145906176901
#
# Although they are related it also involves the concentration term of the other substrate which is B and a similar relationship like this when you consider constant concentration of A and the apparent Km for B .
#  16.902728337890334
#
# It is with respect to first substrate binding .
#  20.23622058912091
#
# If you consider the single substrate reaction the dissociation constant of substrate with the enzyme is analogous to Km value , whereas in the case of bi - substrate reaction that situation is not true .
#  17.377820624017822
#
# At any other V value of B the rate profile will be a hyperbolic profile analogous to that of Michaelis Menten constant .
#  10.002888192812009
#
# If B increases you will get a slope of KA + K ’ A.KB / B Vm The intercept on this factor will be 1 + KB / B Vm So you will notice that both slope as well as intercept of the profiles will decrease as you increase the value of B and ultimately when this B become saturating it will be a typical K value for the substrate A .
#  12.939898873037237
#
# Experimentally the magnitude of KA , KB , K ’ A and Vm can be determined by double reciprocal plot analysis .
#  4.391724158491502
#
# In specific cases they may be equal also .
#  3.4990480940716795
#
# The process in this direction is not feasible .
#  9.767431758367566
#
# We can only react with enzyme only when A has bound to it to form and one of the products is released and the modified enzyme substrate complex is generated .
#  11.771847811086777
#
# The second substrate has to interact with the binary complex before the first product can arrive at but the stable intermediates are only EA and EY .
#  9.392774262966341
#
# The kind of system we will take for simplicity will be a two enzyme substrate complex formation ES going to ET going to E plus P .
#  12.440485290137897
#
# To illustrate the procedure followed I chose this reaction mechanism .
#  9.358806873722186
#
# They are only the steps which are involved in formation of E .
#  14.642387054973778
#
# Now , we had discussed this , these molecules and their reactivity , now as we are discussing that if the more stable radical will have a tendency to react or undergo transfer reaction compared to the less stable one .
#  21.14238662591734
#
# So , this stability would be similar to stability of this radical .
#  7.360156196716261
#
# If for example , if the monomer is electron donor it will have more tendency to react with a solvent which is electron acceptor , whereas if the monomer is a electron acceptor it will have a tendency to react with electron donating solvent , for let us compare between two monomer and two solvent and see whether , we can justify or we can have this verified from the experimental data .
#  15.238631411737567
#
# So , you can justify the values for methyl methacrylate , which is again a electron accepting monomer .
#  10.693751493978109
# That means , this solvents are very poor solvents if you want to build higher molecular weight in the radical polymerization .
#  9.565202434836607
#
# Now , this is a typical example how this common monomers are shift or store , because most monomers when there are shift from between different countries are locally there are stabilized with small amount of this inviters .
#  7.997657972467989
#
# So , it is a example of a retardation there would be four possible , which is a combination of inhibition and retardation something like this a starts at a sometimes as well as the reaction is slower , this happens if we add 0.2 percent nitro benzene .
#  9.561575275672533
#
# Now , we get it once s more time this the expression for k p is just for your reminder that this is this .
#  12.428001753960245
#
# So , we know this now from the experiment and we can find out the concentration of aim as well , so this k p and M dot are the two unknown quantities .
#  9.280741838811583
#
# Now , we know R I is minus d I by d t .
#  14.1931463869741
#
# So , basically there is auto acceleration the rates zooms the rate of polymerization becomes to much accelerated as a results you get a gel at the end .
#  5.62218243217365
#
# So , the kinetic chains have mobility .
#  7.4764124001666685
#
# So , you if you draw T g with mole fraction you are going to get like this , so this your glassy part .
#  10.754069220800323
#
# Substrate binding sites are one of them .
#  11.32092037920124
#
# If one of the amino acids is transferred or removed the whole folding will change and primarily involved means those which are physically present on the active site .
#  5.276288781771179
#
# In the case of A and B acting in the absence of any catalyst , in our case we are considering enzyme as catalyst , when the transition state compound is formed there is a loss of entropy .
#  7.3953415906905295
#
# This A and B both have to colloid and make an unstable compound .
#  4.714167328019693
#
# Whereas from the enzyme substrate complex to transition state is a totally different phenomenon and the energy required to go from an enzyme substrate complex to transition state is the amount of activation energy required for the reaction .
#  13.932991612141851
#
# This effect of entropic contribution to the energy of activation is called approximation effect or propinquity effect .
#  6.138747057158342
#
# Not all the collisions result into product .
#  2.6018169589170315
#
# When you consider the strain or the distortion of the substrate molecule before it can go into the active site for binding purposes , if the desired bond which has to be broken during the reaction is partially strained or distorted then part of the job is already done .
#  9.106303692606582
#
# That means that this bond is already now partially broken and if this molecule then goes to transition state the energy of activation required will be much less .
#  25.110859505498475
#
# Enthalpic contribution might reduce energy by 2 kcals .
#  3.1079721620347582
#
# Lysozyme is an enzyme which breaks down bacterial polysaccharide by virtue of acid base catalysis predominantly .
#  10.5147468918136
#
# They have a covalent bond .
#  8.344378271754254
#
# The resulting highly reacting enzyme substrate complex is then attacked by water in the normal cases if it is a hydrolytic reaction .
#  8.62293493791116
#
# In some of the examples in this table you will notice that on the first column you have side chain serine , cysteine , histidine , lysine , aspartic acid and glutamic acid .
#  6.766951947641899
#
# A not very frequently encountered effect for reducing the energy of activation is attributed to environmental effects .
#  6.0676500273693454
#
# Now , the nature of the additives we must use or we use , must be depended on several parameter ; for example , composition on the polymer .
#  7.7214561599185325
#
# And , generally , this small organic additives , they worked by sacrifices , sacrificial mechanism ; by meaning , by terms sacrificial mechanism meaning , that they do destroy themselves and protect the polymer , the main polymer which you want to maintain or retain .
#  10.908528059862396
#
# So , that , they , we can classify the polymers in several ways .
#  6.204801297235238
#
# And , these sides serve as chlorine radical source , which basically initiate the degradation .
#  13.257027279903989
#
# One example , there are many , many additives can be used ; one additives , one type of additives are shown here .
#  14.768989230648252
#
# They convert these unstable arylic , allyl chlorides to non allic , non allyl sites ; and example dibutyl tin disulfides , and their chemical reaction with the allylic double bond is shown here .
#  5.818599207141262
#
# The other additives used for PVC stabilizations , like soaps of cadmium , zinc , barium salts ; and , they act as acid scavengers .
#  10.268866049132427
#
# So , you have a initiator forming a initiator radical which might abstract hydrogen from polymer backbone , forming a radical in the backbone .
#  6.853568005636905
#
# So , we can add the additives which can trap this radical R dot or proxy radicals , which is done by adding primary anti oxidant ; we can increase the rate of termination reaction , which is done by adding hinder diamine .
#  8.503968056910288
#
# There are many many phenolic anti oxidants available in the market .
#  3.3376210598422915
#
# Secondary anti oxidants , they are hydro peroxide decomposers ; react with hydro peroxides and produce non radical products .
#  7.134241555994516
#
# They are proven to hydrolyze .
#  2.348830562317757
#
# And , these are the one example of the hydrolysis happening during the processing condition at higher temperature , at higher shear rate .
#  10.81236777234613
#
# This 2 path is shown here .
#  6.478402166384763
#
# Titanium oxides , it is another UV absorber , which absorbs highly below 370 nano meter .
#  3.928678924115675
#
# I will , in the next lecture , which we will be going to be the last lecture of this course .
#  13.402188033702576
#
# You have a whole range of small applications in different sectors probably the most prominent among the miscellaneous groups I will like to place is biological …… treatment .
#  7.657386579963132
#
# Finally regenerability of the carrier is a factor you will notice in one of the examples which I have given today that although the carrier is very expensive the cost factor here as we have mentioned may be high but if it is regenerable the cost can be taken care and does not contribute very significantly to the overall cost of the process .
#  10.48577029845124
#
# If you notice here some of the experimental conditions , amino acylase was immobilized by ionic binding to DEAE sephadex “0.2M ” concentration of substrate was used containing 5x 10 - 4 M cobalt salt which acts as stabilizing agents , stabilizer for enzymes and reaction temperature was 50 deg C .
#  8.220272274861253
#
# This is the comparison and this is the fraction of the relative cost .
#  12.776319197248549
#
# The cost of production per unit quantity of the product comes down by over sixty nine point of total cost .
#  3.608314021917943
#
# The recovery has improved so per unit cost as a result of raw material consumption has decreased .
#  4.110658161592694
#
# So the labor and the enzyme cost are the major factors .
#  23.78064038992975
#
# I think you may like to go through and I suggest some of the references ; you just go through them ; you will find the experimental details as to how they arrived at the final decisions .
#  14.958389563850305
#
# Here we have 29 % but still 29 % is the highest and probably one has to accept it .
#  13.30811385992476
#
# When you take lower substrate concentration , 0.2M the activity loss is much , much higher and over the same period of time instead of 50 % it reaches to about 25 % and this is the case where if you recall we discussed the substrate dependent enzyme decay .
#  9.136021234397694
#
# We discussed two cases of enzyme deactivations during continuous operation of the reactor one was substrate independent where in the earlier case of aminoacylase substrate concentration plays no role and the deactivation constant is predominant but in the case of the aspartase , it is substrate dependent deactivation and higher the concentration of the substrate the operational life is comparatively better .
#  11.230237110926327
# In fact most of the products for example the beverages particularly Pepsi and Coke they are based on glucose fructose syrup ; they don ’ t use sucrose as a sweetener because of the use of glucose and fructose syrup in their parent countries their processes need glucose and fructose syrup .
#  7.682073004944973
#
# And , in this lecture , this tenth lecture , I will try to complete the discussion on the different type of radical initiator , which we began in the last lecture , and briefly talk about the initiator efficiency .
#  17.029300202142707
#
# For example , I have molecule like this , or you can have benzyl ketals , benzyl ketals where you have structure of that like this .
#  6.20429087618215
#
# These are the main type of photo initiator or photo chemical initiator used in commercial applications .
#  4.603424939636411
#
# So , it is , it is very , very useful to application , like film , where you can cover a part of the film , and you can keep part of the film uncovered ; where if you sign light , that part will get polymerized , leaving the part where , which is covered as unpolymerized medium .
#  8.900929074029095
#
# So , if this photo polymerization method or the radical polymerization by photo initiators sometimes can be used , has a advantage ; this can be used or it is used to apply or used to make polymers in a local or in a , whatever targeted part .
#  16.711903513391665
#
# The other type of possible initiation is the thermally induced self initiation ; that means , the monomer itself , on thermal or on heating can gives rise to , or they can generate radical , but this not a very common way of generating radical ; this is , has been proved only for , in the case of styrene .
#  10.039189419104535
#
# For example , if you take AIBN , you have seen that AIBN on dissociating to this , this species ; now , they can again recombine by reacting with themselves and form these molecule .
#  6.1694954146498695
#
# In this case , part of the radicals which were generated by homiletic cleavage of AIBN , they are getting destroyed ; in the sense , they are becoming inefficient , inefficient or dead , non radical species by reacting with themselves .
#  8.201678263005624
#
# And , we will talk about induced decomposition of initiator ; or , if I have a propagating radical ; now , if give example of benzyl peroxide , it can , the propagating radical can react with initiator molecules and form a another radical .
#  8.610980079263621
#
# So , M is also taken out .
#  5.569556498344993
#
# So , M dot is ; this is the summation of the concentration of all the radicals present ; all the propagating radicals present in the reaction medium .
#  6.810590909149921
#
# So , these ; so , R p now given up , given by k p rate constant for all those individual steps , monomer concentration , and this is the summation of the concentration of all the propagating radicals of the , all the chain radicals ; this is the sum of all those things .
#  9.443071204543976
#
# Disproportionation , 2 of these .
#  6.892643986940478
#
# So , here also we write 2 .
#  7.55628876240133
#
# What is , it would look like , for a redox initiator ?
#  12.410773818356892
#
# Now , that indicates that , now that indicates that ; see if we , if the rate of polymerization dependent not directly , not to the power 1 , but more than 1 select 3 by 1.5 ; which means , that this monomer also taking part in generating radicals .
#  10.318561157805107
#
# So , and which will depend upon the temperature .
#  6.788822095479978
#
# If it is gets terminated by the disproportionation reactions , we seen earlier ; then average degrees of polymerization is nu , because the number of monomers , average numbers of monomers per radical is the size of this chain .
#  9.417885108218151
#
# The most absolute specificity in terms of an enzyme , with which some of you may be familiar , is oxidation of ﬂ - D - glucose to glucono lactone by glucose oxidase a fungal enzyme which is produced by Aspergillus niger .
#  7.393068995347584
#
# Then we have a number of enzymes which show stereo chemical specificity .
#  7.394285959621943
#
# The specificity can have a very large variety and one must also appreciate that the specificity of these enzymes in terms of their catalytic action is attributed to the active sites .
#  12.689584896619397
#
# But as far as the binding is concerned , it has to be specific in terms of bringing the functional group on which the reaction has to take place .
#  11.315216510559955
#
# The one which binds methyl group will be hydrophobic in nature and this will be bound predominantly by electrostatic interactions .
#  9.76318594342456
#
# Here you have the active site , the sites on which the binding groups available on the substrate binds and this portion shows the substrate which is analogous to the key .
#  17.144020359120237
#
# Your hand is analogues to substrate .
#  15.18443123497781
#
# But in case where two substrates are involved as in the case of hexose phosphorylation , the role of hexose and ATP both participating at the binding site for the reaction to occur could be explained using induced fit mechanism .
#  11.976232382217633
#
# None of them is able to provide a suitable explanation for the catalytic function .
#  16.366588616328002
#
# This binding process brings in the specificity and the nature of the binding site or the active site on the enzyme molecule is slightly complementary or of the similar type but not exactly complementary and the complementarity comes only after binding has taken place which results in the distortion of the reacting group and then the complementary comes in .
#  15.02377215625213
#
# The strain effects have been discussed when we were talking about the ways in which the enzyme reduces energy of activation .
#  3.959847498173116
#
# Because the active site is not exactly complementary , after the substrate approaches the binding sites it forces the reacting group to develop a strain so as to bring in complementary to the catalytic sites .
#  11.759867126192525
#
# Just coming in proximity could provide you an effect what we discussed like high substrate concentration in the proximity of the active site but does not explain you how the energy of activation is induced .
#  6.038961193886936
#
# There are many other unfavorable interactions available at the active site and these interactions tend to distort the substrate in such a way so that it favors the formation of a complex which is analogues to structure in transition state .
#  8.863929778439097
#
# What is the order of specificity , to what extent it would be specific , what are the impurities which can interfere in the specificity they are all related to the results of reaction that is the rate of formation of product .
#  14.20733700851335
#
# So obviously you have to produce them on a very small scale and producing on small scale will lead to high cost of production .
#  12.311980597862332
#
# The specificity must be looked in from both the angle and in many cases today people are applying the development of molecular biology particularly in sense of protein engineering to modify the substrate specificity both when we want the absence of side products to make it more specific as well as when we want broad specificity so that the same enzyme can be applied to a large variety of substrates .
#  17.032992490442652
#
# Now , before we start getting the expression for enthalpy of mixing , just one point just to highlight that this is the expression we received or deduced for entropy of mixing for a polymer solvent .
#  6.722713483607136
#
# This is what it does .
#  4.096757349778432
#
# If you go back here , each polymer segment , if all of these are , say for argument , all these neighboring cells has solvent molecules , and then it will have z contacts .
#  7.787647286652748
#
# So , that is , what is the chance that each segment would be giving up a polymer solvent contact .
#  5.189597815530188
#
# So , we can write del h m is chi n 1 phi 2 into k T .
#  10.762775260687523
#
# Parameter is basically gives you the difference when a solvent molecule is taken out from a solvent environment and put in a polymer environment .
#  13.502393678791911
#
# One will be transport of the substrate from the bulk to the surface ; from surface the substrate has to transport to the site of the enzymatic reaction which means the enzyme molecules that are located throughout the immobilized enzyme particle and then the reverse process that means the product produced as a result of biochemical reaction has to transport back from the carrier interior to the surface .
#  12.852272510108133
# An important feature of the performance of immobilized enzyme reactor is that one needs to identify the limiting rate , the step which has a limiting rate the lowest reaction rate .
#  24.319047632942695
#
# That means the kind of reactants we have used in immobilization , the kind of matrix we have used in immobilization and whatever the interaction between the matrix and the enzyme under the conditions of immobilization , whatever conformational changes have taken place , whatever kinetic parameters have been modified as a result of this interaction are considered in the inherent parameters and we define them as ví = kí2E0S / Kím + S The parameters are just given prime and the inherent parameters have no role to play or not much can be done during the reactor design or reactor operation .
#  11.708061069572418
#
# l . When you say F is equal to one , there is no effect on the kinetic parameter Km or there is no diffusional limitation in other words .
#  7.329347294664706
#
# l . Under what conditions ?
#  8.094623080245642
#
# When ? l magnitude is greater than two you can safely take that the reaction is diffusional limited and Kappm equal to Kappm = Kím .
#  11.738300056934797
#
# That means at high substrate concentration when you are talking of ?
#  13.61721813156456
#
# F is one .
#  5.58901679086684
#
# Another way is to look at the Lineweaver - Burk plot .
#  4.799275105958121
#
# 1081 , 1974 .
#  1.5731941971666166
#
# Consider another situation in which at the low substrate concentration when ?
#  4.6780007429414665
#
# So a change in the activation energy over a range of temperature also indicates the diffusional limitation behavior .
#  9.433848374017279
#
# Therefore we have three distinct approaches to monitor by experimental methods the effect of diffusional limitation in the case of immobilized enzyme particles .
#  11.8454688027145
#
# kl is the mass transfer coefficient cm / sec .
#  2.872860395085283
#
# The slope of this straight line will be , at low substrate concentration , 1 / klam + Kím / kí2E0 .
#  7.763585038492222
#
# On the other hand the slope here will be Kím / kí2E0 .
#  9.429053928674952
#
# By knowing the two slopes one can calculate klam .
#  3.968073024737639
#
# The difference between the two slopes is the 1 / klam .
#  2.670731678869173
#
# And we just started giving examples , which chain transfer with monomeric species and what we will do .
#  4.821561080895309
#
# But for the examples , monomers like styrene , it will be only one double bond possible because in case of styrene you have only one possibilities of beta transfer .
#  10.048990975757489
#
# Similarly , in this case , this can again reinitiate a cationic polymerization .
#  5.037531169716406
#
# Now , there could be some agents , reagents present , like in case of radical chain polymerizations where this reagent actually can slow down the cationic chain polymerization considerably .
#  4.551544298285971
#
# We are not considering for this kinetic expression , the other time transfer reaction , so we can write k t IZ .
#  6.8519081551491565
#
# It , the activation general propagation will of course , depends on the initiator or coinitiator and the solvent .
#  6.2436083722077305
#
# Now , typically E transfer is higher than E p , so which means , that with T , with increase in , decrease in temperature C also goes down , which means , X n goes up .
#  16.403205529349943
#
# If it is negative , then with decreasing temperature you get increase in polymerization rate , but if it positive , then with decrease in temperature you get reduction in the polymerization rate .
#  6.485574359724383
#
# And as we know , that the reactivities of the free counterions or the solvent separated counterions are much different than tight iron - pairs .
#  9.209506751453313
#
# Now , you have to maintain moisture free environment and if you , and if you are actually using H 2 as a cocatalyst , then we should add H 2 O in the symmetric amount with respect to the catalyst because moisture or H 2 is present in excess than what you desired as a cocatalyst .
#  12.396473664681752
#
# And generally , E R , the activation of is positive , small positive .
#  6.0167445971467295
#
# Most important is using alkyl lithium .
#  6.3180384079874035
#
# Other initiations possible by electron transfer , electron transfer , for example , reaction between sodium and naphthalene .
#  4.053489135954209
#
# This is the example of how initiation is done with electron transfer .
#  7.977179344213164
#
# So that means it is active .
#  10.35569587554715
#
# Similarly in case of enzyme loading we talk of international units per gram of carrier or if you take into account the bulk density of the carrier you can also say international units per ml of carrier bed that means you pack the carrier into a bed , packed bed , and then consider the volume .
#  13.331985632586937
#
# Very often even after the immobilized enzyme preparation has been exhausted during use the carrier can be recovered and reused .
#  5.59969240206151
#
# Weak binding in the sense while during use , the enzyme can also dissolve slowly over a long period of time and if the carrier characteristics are sturdy they can be regenerated and reused .
#  6.256452404471176
#
# If the enzyme is stable at 70ºC , 70ºC is acceptable and can be considered as mild .
#  6.416222073152741
#
# Again when I say the term high it refers in the comparative form and the comparison here is with covalent binding .
#  8.915186102702897
#
# Either the enzymes are supported on membrane or they are supported on certain particulate matters and therefore the methods based on adsorption are usually very analogues similar to those that are found in the living system .
#  12.537580540417895
#
# You have to give another shot to keep the enzyme activity available in the blood stream .
#  6.322929546483815
#
# Conversion is related to the enzyme activity .
#  9.84770925744699
#
# The enzyme at this stage is counter charged at a particular condition .
#  10.223604973713154
#
# It is not a covalent linkage ; it is a physical interaction and there by the enzyme is held but has been very successful method from the practical point of view .
#  11.151834219031437
#
# Most of the adsorption methods can be characterized by the classical adsorption isotherms .
#  14.929421626494067
#
# Each point represents a particular enzyme to carrier ratio .
#  8.258270192708542
#
# ...
#  11.484344215680458
#
# They have tried to mimic the activity of chymotrypsin ; they have named it also benzyme and some of the functional groups are covalently coupled which are functional in the case of catalysis and such a complex is called a synthetic enzyme .
#  10.35393194210168
#
# Hence K s c would be given by e to the power del S 0 p p by R .
#  7.595144933208081
#
# So , we can simply write from these two , V is V 0 plus V i e to the power minus A s L dash by 2 .
#  7.412198088269773
#
# So , the output signal in this detector is proportional to the concentration and if we assume that detector response is proportional to the concentration in the range we are working , and also this response does not depend on molecular weight .
#  8.86602550380846
#
# So , this is the weight fraction between the polymer which eluted and they can be written like this where a is the area under this curve ; and if we do interrogation and followed by normalization we can get this weight fraction molecular weight distribution in the form .
#  14.393333785295773
#
# So , the polymer which are same type used and calibration .
#  6.898601423134829
#
# So , preferably we use longer column ; typically in normal sense , we actually use few column in series and some cases to make the process faster ; we mix bed type columns are used where you have the columns are made with different pore size and you can use two such or three such mix bed columns in series or a single different pore size columns also in series .
#  9.756840358570187
#
# So , it is preferable that the column is kept in a constant temperature ; obviously , the sample loading is small from a very dilute solution ; specially , when you are using detectors like light scattering and viscosity there we are assumption the solution is very dilute .
#  14.318001632537442
#
# So , that we can consider the specific viscosity divide by c as an intrinsic viscosity and the molecular obtained by light scattering ; there will be less error .
#  8.654214156514842
#
# So , what is the modification done to get the mass spectroscopy polymers ; one soft ionization mechanism is used where will come in a minute using matrix assisted laser desorption ionization or MALDI by which the polymers are vaporized with the help of a matrix without degradation and we also use the second technique called time of flight mass spectroscopy ; and in combination of these two techniques we get MALDI TOF MS matrix assisted laser desorption ionization , time of flight mass spectroscopy which is nowadays very important or very common for polymer samples .
#  7.465946947008074
#
# So , this name MALDI comes from there .
#  9.991908393297306
#
# So , in MALDI , choosing of matrix is very critical and it needs to optimize for every polymer samples .
#  5.195536377634965
#
# For oliphinic polymers like polyethylene , polypropylene , it is very difficult to find a cation which might complex with these oliphinic polymers ; it is very difficult to cationize and then analyze this polymers by MALDI ; and water soluble polymers already which does not soluble in a solvent is also very difficult .
#  11.193516921956029
#
# So , this keeps the entire distribution ; this is the normalized intensity and if you look at the gaps between the molecular ions you can see the gaps is 100 Dalton which is exactly the mass for a MMA repeating unit .
#  8.052781853124026
# And from this distribution the different molecular weight like number average molecular weight , weight average molecular weight and other molecules can be directly obtained .
#  9.655201066769592
#
# So , just all this benefits , but the only disadvantage is that the price of MALDI TOF is very high .
#  5.591961093417286
#
# The two factors on which the classification of enzyme reactors can be based are on the mode of charging and discharging of substrate and product stream and also physical configuration .
#  17.279155074381556
#
# There are options where even soluble enzymes can be used in a continuous reactor but for practically most applications the use of soluble enzyme is usually with the batch reactors .
#  7.981614423708672
#
# In the example I cited a little ago on the hydrolysis of penicillin to 6 - APA because of simultaneous acid production you need to control the pH otherwise the enzyme gets inactivated and a very precise control of pH is needed and therefore addition of the alkali simultaneously is a must and which can be carried out very easily in a stirred batch reactor and with a control system you can control the pH .
#  10.098766250301695
#
# For a perfect total recycled reactor to be considered as a batch reactor operation the requirement should be that the total recycled time must be very small or negligible compared to the total batch cycle ; that is the recycling has to be very fast .
#  10.690233914766985
#
# The concentration profile of the feed at any given cross section of the reactor is flat .
#  6.912756949515147
#
# This will be a function of the particle shape and size .
#  9.079564338557304
#
# That is the reactor output instead of going directly to the product stream passes through ultra filtration unit in which the product stream is filtered out and can be taken out of the product stream while the retentate which contains mainly the enzyme is recycled back into the reactor .
#  11.316308045862451
#
# That means the substrate can go into the vicinity of the enzyme and product can go out and ultimately the product stream can be taken out but the enzyme cannot go out of the ultra filtration tubes and such a reaction system has an advantage that you can use such a system as a continuous plug flow reactors even using the soluble enzymes .
#  19.923449040265236
#
# When you say when you are immobilizing on the walls of the tube then they don ’ t operate really on the hollow fiber reactor .
#  7.640253773439903
#
# It is retained in the semi permeable hollow fiber tubes so that it is not able to go out almost similar to microencapsulation where the enzyme is contained in the forms of tubes .
#  10.076661131001185
#
# So the combined CSTR coupled with the ultra filtration reactor can be easily used .
#  8.173043920115083
#
# during continuous use .
#  4.025617000490843
#
# Before we go into the reactor performance of different types of reactor for the immobilized enzyme systems , we cannot normally consider all the parameters like non - ideal fluid dynamics , the mass transfer constraints and along with the biochemical reaction we cannot really combine at one stage .
#  10.226996285092321
#
# The first one is “tau ” which is the reactor space time in terms of V / Q .
#  11.833241334708573
#
# When I say E0 , I think it will be desirable to also have the magnitude of kd , the deactivation constant .
#  12.951348766962829
#
# Then pH ; pH here is not only monitoring but more important is the control of pH .
#  5.036892396219336
#
# That means the concentration difference ; substrate concentration between the inlet and the outlet stream , the ratio of the two .
#  6.810164107086094
#
# So , I can write q for m 1 q for m 2 for 1 , 1 , 1 e m 2 , you can get the expression from k 1 1 for k 1 1 k 2 and so the ratio you get these two , this because is the same radical 1 and 1 .
#  20.64705030191474
#
# So , if I can write , similarly for r 2 Q now because Q is always talking about related to monomer .
#  6.547903496041586
#
# So , r 1 , r 2 will be given by if we can multiply these two given by exponential minus e 1 minus e 2 square .
#  6.155764189602588
#
# Now , obvious this is Q is measure of reactivity as we have seen and e is measure of electrostatic charge .
#  3.8291120634116886
#
# So , brittle that if this copolymer does not have a significant improvement over , over the polystyrene molecule homo polymer in terms of brittleness .
#  6.656691767947426
#
# The other examples , but I am not spending much time on discussing those applications here .
#  5.800780950562465
#
# Now , the feasibility of this polymerization from a ring to linear product linear monomer to polycyclic monomer to a linear product , like all other reactions depends both on thermodynamic and thermo dynamic and last kinetic factor .
#  11.566585871520907
#
# Basically this is saturated ring and there is no place where u can carry out a electrophilic or neutrophillic character by external and open the ring , and then carry out the polymerization .
#  6.305702009416623
#
# So , basically all have a hetero atom in the ring , whether it is a or ester or amides whatever is the case .
#  9.094567123995565
#
# Now , poly ester poly amides are typically synthesized we have discussed earlier they are synthesized by stiff polymerization , but in this case we are making the same types of polymers , which we knew till now that they are typically synthesized by step growth polymerization .
#  12.48575785574742
#
# So , the chain keep on propagating there is no reaction between two monomers or there is no reaction between two high molecular polymer chain as well .
#  11.259132781909457
#
# So , you can make block of polymers of functional polymers at the end of the reaction , and in this case unlike a linear polymerization of the vinyl molecules , polymerization de polymerization equilibrium is very important .
#  13.3453354069587
#
# If you want to terminate the reaction you can exchange these with a say adding some water or alcohol , and then you can exchange like other we discussed earlier .
#  10.815580867771992
#
# Similarly , if we have little bit of moisture present in the medium or if you have water molecules , then this will easily compete with your monomer with oxinium ion and then terminate the or disrupt the reaction immediately .
#  11.874089572344953
#
# Ultimately it can reach the same kind of saturation behavior but the initial profile will be different in the case of a sigmoidal profile .
#  8.540766780825223
#
# Similarly in the case of hydrolysis of sucrose by invertase also by one of the possible mechanistic models when one substrate molecule binds , the enzyme substrate complex leads to a product formation .
#  8.397276776809088
#
# Notice the two terms which I have highlighted here .
#  4.99005254871341
#
# Identical means the catalytic sites have identical free energy change of binding .
#  10.104205095665213
#
# They don ’ t influence the binding to other site .
#  3.760388084571189
#
# The only difference is here the definition of Vm must be taken as 2K2 .E0 or in another words if it is a multimeric protein or enzyme where n binding sites are there , it can become n.K2.E0 Otherwise the treatment can be identical as in the case of a hyperbolic profile .
#  18.340761184238154
#
# The first binding site is free for all the substrate molecule and once this is bound if it makes a change on the confirmation of the other binding sites such that the affinity of the substrate to the binding site gets altered , if you want a positive favorable effect , the affinity must increase or the Km value must decrease , dissociation constant must decrease .
#  13.622865360570211
#
# All of you know probably with your background in the biochemical metabolism that with each metabolic path way you have certain regulatory enzymes which behave in allosteric manner .
#  5.660362076022667
#
# For the two enzymes to act , in the early phases when substrate concentration increases from zero to three arbitrary units whatever are the units , in the case of sigmoidal kinetics the reaction velocity is only 0.1 in some arbitrary units .
#  12.87256915162473
#
# In the case of living cells the intercellular concentration of substrate does not change over a very large range .
#  6.935770244602139
#
# This is something like an extension to that and which means that when the substrate molecule binds on one of the binding sites of the enzyme it immediately triggers off a conformational change whereby the affinity for the next binding site becomes much higher and they expressed it with an interaction factor .
#  13.572022881064457
# The conformational change leads to the dissociation constant or Michaelis Menten constant for the second binding site and then second binding site also gets bound .
#  8.07894143833982
#
# This K ’ is different than the Michaelis Menten constant .
#  6.166973700818084
#
# Or S0.5 substrate concentration for 50 % maximum reaction velocity is nvK ’ .
#  3.6856212471936685
#
# Now , how to get more information with we can deduce from this .
#  4.95723060871133
#
# So , this curve now is for theta is equals to 0 and this is for c equals to 0 .
#  8.272358468685004
#
# Why we extrapolate ?
#  2.189647285803901
#
# So , this is known as zimm plot ; this is very unique way of plotting this three dimension 3 d data into two dimensional using the help of a arbitrarily chosen constant and we can get this information from this zimm plot .
#  5.631431060600244
#
# One is the solvent and the solute solution all the polymer solution should be absolutely dust free ; otherwise , the dust particles will scatter light that will interfere and give error in the your final result .
#  14.566945841600628
#
# Now , it is the lambda we are using , because what happened if the size of the scatterer or the polymer molecule or the other scatterer is very high and the respective interference between the scattered light from different part of the solute becomes so much that even at a little higher theta , this becomes 0 ; the value of P theta becomes 0 .
#  14.072291186822103
#
# So , it is very difficult to get accurate measurements of i theta for those cases .
#  4.308400933059501
#
# So , here we detect the scattering from very small volume at very small time intervals ; this is what we do ; delta T which varies from microseconds to milliseconds and then correlate the scattering intensity fluctuations with time .
#  8.237312537521987
#
# Today we will be discussing some of the characteristic features of enzymes particularly as proteins and their chemical nature .
#  6.103391690377557
#
# One could determine by any method that is known to us and I will talk about it a little later .
#  13.287999960374314
#
# The other way could be and which is probably more important for assay of an enzyme is its catalytic function .
#  13.775023867004688
#
# One of the limitations is that this is not a SI unit which is an internationally accepted system of units .
#  7.392181818852733
#
# The most simple system probably you are familiar is by ultra violent absorption .
#  7.271108061467145
#
# Another method is biuret method which is based on the reduction with alkaline Copper sulphate solution which contains sodium potassium tartrate and the cupric ions form a co - ordination complex with the amino groups or the - NH group present in the peptide bond .
#  7.997223808582828
#
# At a low pH the molecule will act like a cation and as we increase the pH it will be negatively charged and it will behave like anion and some where in between there will be a zero net charge that means it will have both positive and negative charge of equal magnitude , what we call as zwitterion in the case of amino acids .
#  9.40499015652386
#
# The molecule is very compact .
#  6.744654166303077
#
# Most important non covalent interaction which involves in the conformation of the protein molecule is hydrogen bonds , very large number of hydrogen bonds .
#  8.826100963751646
#
# That means when you consider the wet side , on the surface there will be most of the charged groups and most of the non polar side chains will be located inside the three dimensional molecules .
#  14.894890951453439
#
# It doesn ’ t mean that on the surface there are no hydro phobic patches .
#  4.506860636810233
#
# Then this chain can fold itself locally in the shape of either an alpha helix or a pleated sheet so as to give a secondary structure .
#  13.17622667935121
#
# This alpha helix and other type of conformation which many proteins will have will be again as the result of hydrogen bonding will be in the form of beta pleated sheet .
#  11.948841597674896
#
# The disruption of the non covalent interaction is good enough to lead to denaturation .
#  8.163168303170112

# %%
with open('tech_corpus_kn.pkl', 'wb') as f:
    pickle.dump(tech_corpus_kney, f)
    
with open('tech_corpus_wb.pkl', 'wb') as f:
    pickle.dump(tech_corpus_wb, f)

# %%
with open('tech_corpus_kn.pkl', "rb") as input_file:
    tech_corpus_kn = pickle.load(input_file)
    
with open('tech_corpus_wb.pkl', "rb") as input_file:
    tech_corpus_wb = pickle.load(input_file)

# %% [markdown]
# ### Avg Vals

# %%
kn_avg = 0

for i in tech_corpus_kn:
    kn_avg += i[1]

kn_avg/1000
# Out:
# 10.436678603971208

# %%
wb_avg = 0

for i in tech_corpus_wb:
    wb_avg += i[1]

wb_avg/1000
# Out:
# 13.19003452960443

# %%
with open('tech_corpus_kn.pkl', "rb") as input_file:
    tech_corpus_kn = pickle.load(input_file)
    
with open('tech_corpus_wb.pkl', "rb") as input_file:
    tech_corpus_wb = pickle.load(input_file)
    
    
with open('health_corpus_kn.pkl', "rb") as input_file:
    health_corpus_kn = pickle.load(input_file)
    
with open('health_corpus_wb.pkl', "rb") as input_file:
    health_corpus_wb = pickle.load(input_file)

# %%
def find_avg_perp(l):
    temp = 0

    for i in l:
        
        if i[1] != np.float('inf'):
            temp += i[1]

    return temp/len(l)

# %%
find_avg_perp(health_corpus_kn)
find_avg_perp(health_corpus_wb)
# Out:
# 7.2160953379390955

# %%
find_avg_perp(tech_corpus_kn)
find_avg_perp(tech_corpus_wb)
# Out:
# 9.657405143189328

# %%
f = open("2019201017-LM3-test-perplexity.txt", "w")  

for i in tech_corpus_kn:
    string = i[0].split('\n')[0]
    
    if i[1] == np.float('inf'):
        perp = 'inf'
    else:
        perp = str(i[1])
    
    final = string + '\t' + perp + '\n'
    f.write(final)
    
    print(final)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-7385b6dd1a9f> in <module>
#       4     string = i[0].split('\n')[0]
#       5
# ----> 6     if i[i] == np.float('inf'):
#       7         perp = 'inf'
#       8     else:
#
# TypeError: list indices must be integers or slices, not list
